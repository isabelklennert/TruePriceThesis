# %% [markdown]
# # Analysis of dynamic network ABM with social comparison

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import networkx as nx
import cProfile
import pstats
import mesa
pd.set_option('display.max_colwidth', 10000)
import joblib
import matplotlib.pyplot as plt
from collections import Counter
from tqdm import tqdm
from SALib.sample import saltelli
from SALib.analyze import sobol
from SALib.test_functions import Ishigami
import matplotlib.ticker as mtick

# %%
from model_dynamicnetwork_newdata import ConsumatModel

# %%
base_config = {
    'TP_percentage': 0.4,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'kde_models_dir': '/Applications/UNI/Thesis/saved_data/',
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['budget'],
    'seed': 42  
}

watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})

network_configs = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

# %%
tp_percentages = np.arange(0, 1.05, 0.05)
num_steps = 10
all_results = {network: {} for network in network_configs}
final_adoption_rates = {network: [] for network in network_configs}

def collect_simulation_data(model, num_steps):
    collected_data = {
        'Step': [],
        'Adoption Rate': [],
        'Avg_F_Satisfaction': [],
        'Avg_S_Satisfaction': [],
        'Avg_P_Satisfaction': [],
        'Avg_F_Uncertainty': [],
        'Avg_S_Uncertainty': [],
        'Avg_P_Uncertainty': []
    }

    for step in tqdm(range(num_steps), desc='Simulation Progress'):
        model.step()
        collected_data['Step'].append(step)
        collected_data['Adoption Rate'].append(model.calculate_true_price_adoption_rate())
        collected_data['Avg_F_Satisfaction'].append(np.mean([agent.F_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_S_Satisfaction'].append(np.mean([agent.S_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_P_Satisfaction'].append(np.mean([agent.P_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_F_Uncertainty'].append(np.mean([agent.F_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_S_Uncertainty'].append(np.mean([agent.S_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_P_Uncertainty'].append(np.mean([agent.P_uncertainty for agent in model.schedule.agents]))

    model_data = pd.DataFrame(collected_data)
    return model_data

def plot_metric(data, metric, ylabel, filename, scale_as_percentage=False):
    plt.figure(figsize=(15, 8))
    colors = plt.cm.viridis(np.linspace(0, 1, len(data)))

    for color, (tp, df) in zip(colors, data.items()):
        tp_percentage_label = f'{tp * 100:.1f}%'  # Convert TP to percentage for the legend
        if scale_as_percentage:
            plt.plot(df['Step'], df[metric], label=tp_percentage_label, color=color, marker='o')
        else:
            plt.plot(df['Step'], df[metric], label=tp_percentage_label, color=color, marker='o')

    plt.xlabel('Step', fontsize=14)
    plt.ylabel(ylabel, fontsize=14)
    plt.legend(title='TP Percentage', fontsize=12)
    plt.grid(True)

    if scale_as_percentage:
        plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())

    
    plt.savefig(f'{filename}.png')
    plt.close()

for network_type, config in network_configs.items():
    for tp in tp_percentages:
        config['TP_percentage'] = tp
        model = ConsumatModel(config)
        model_data = collect_simulation_data(model, num_steps)
        all_results[network_type][tp] = model_data
        final_adoption_rate = model_data['Adoption Rate'].iloc[-1]
        final_adoption_rates[network_type].append(final_adoption_rate)

metrics = [
    ('Adoption Rate', 'Adoption Rate (%)'),
    ('Avg_F_Satisfaction', 'Average Financial Satisfaction'),
    ('Avg_S_Satisfaction', 'Average Social Satisfaction'),
    ('Avg_P_Satisfaction', 'Average Personal Satisfaction'),
    ('Avg_F_Uncertainty', 'Average Financial Uncertainty'),
    ('Avg_S_Uncertainty', 'Average Social Uncertainty'),
    ('Avg_P_Uncertainty', 'Average Personal Uncertainty')
]

for network_type, data in all_results.items():
    for metric, ylabel in metrics:
        plot_metric(data, metric, ylabel, f'{network_type.lower().replace(" ", "_")}_{metric.lower().replace(" ", "_")}', False)

# Additional plot for final adoption rates
for network_type, rates in final_adoption_rates.items():
    plt.figure(figsize=(12, 10))
    plt.plot(tp_percentages*100, rates, marker='o')
    plt.xlabel('TP introduction percentage (%)', fontsize=14)
    plt.ylabel('Final True Price Adoption Rate (%)', fontsize=14)
    plt.ylim(0, 100)
    plt.grid(True)
    plt.savefig(f'final_true_price_adoption_rate_{network_type.lower().replace(" ", "_")}.png')
    plt.close()
# Out:
# Simulation Progress: 100%|██████████| 10/10 [00:37<00:00,  3.80s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:44<00:00,  4.42s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:48<00:00,  4.82s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:44<00:00,  4.48s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:52<00:00,  5.23s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:52<00:00,  5.24s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:48<00:00,  4.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:46<00:00,  4.62s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:47<00:00,  4.77s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:52<00:00,  5.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:51<00:00,  5.16s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:43<00:00,  4.39s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:43<00:00,  4.35s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:48<00:00,  4.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:44<00:00,  4.49s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:45<00:00,  4.52s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:46<00:00,  4.68s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:49<00:00,  4.91s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:45<00:00,  4.54s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:47<00:00,  4.73s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:45<00:00,  4.53s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:46<00:00,  4.63s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:46<00:00,  4.68s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:46<00:00,  4.70s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:47<00:00,  4.78s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:40<00:00,  4.03s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:48<00:00,  4.84s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:51<00:00,  5.15s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:47<00:00,  4.71s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:48<00:00,  4.83s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:49<00:00,  4.94s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:47<00:00,  4.73s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:47<00:00,  4.80s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.56s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.13s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:22<00:00,  2.23s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:24<00:00,  2.46s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:25<00:00,  2.54s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:28<00:00,  2.80s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:25<00:00,  2.56s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:24<00:00,  2.49s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:23<00:00,  2.39s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:22<00:00,  2.28s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.09s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.05s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.07s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.10s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.03s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.12s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.06s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:23<00:00,  2.31s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.15s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.07s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.18s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.18s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.08s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.16s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:22<00:00,  2.22s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:24<00:00,  2.45s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:22<00:00,  2.23s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:23<00:00,  2.38s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:26<00:00,  2.64s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:24<00:00,  2.48s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:25<00:00,  2.59s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:24<00:00,  2.44s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:25<00:00,  2.50s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:27<00:00,  2.75s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:24<00:00,  2.40s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:24<00:00,  2.41s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:24<00:00,  2.48s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:25<00:00,  2.54s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:25<00:00,  2.52s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:26<00:00,  2.63s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:24<00:00,  2.46s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:22<00:00,  2.23s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:23<00:00,  2.34s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:25<00:00,  2.55s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:23<00:00,  2.31s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:25<00:00,  2.53s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:25<00:00,  2.59s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:26<00:00,  2.61s/it]

# %% [markdown]
# # Old code

# %%
def run_simulation(model, num_steps):
    adoption_rates = []

    for _ in tqdm(range(num_steps), desc='Simulation Progress'):
        model.step()
        current_adoption_rate = model.calculate_true_price_adoption_rate()
        adoption_rates.append(current_adoption_rate)

    model_data = model.datacollector.get_model_vars_dataframe()
    agent_data = model.datacollector.get_agent_vars_dataframe()
    model_data['Adoption Rates'] = adoption_rates

    return model_data, agent_data

def run_multiple_simulations(config, num_steps, num_simulations):
    all_simulation_data = []
    
    for _ in range(num_simulations):
        model = ConsumatModel(config)
        model_data, agent_data = run_simulation(model, num_steps)
        all_simulation_data.append(model_data)
        
    return all_simulation_data

def plot_adoption_rates(simulation_data, config_name):
    plt.figure(figsize=(10, 6))
    for sim_data in simulation_data:
        plt.plot(sim_data['Adoption Rates'],  marker='o')  
    plt.title(f'True Price Adoption Rate Over Iterations for {config_name}')
    plt.xlabel('Iteration')
    plt.ylabel('True Price Adoption Rate (%)')
    plt.ylim(0,100)
    plt.grid(True)
    plt.show()

def plot_network_metrics(aggregated_data, config_name):
    plt.figure(figsize=(10, 5))
    if 'Average Degree' in aggregated_data.columns:
        plt.plot(aggregated_data['Average Degree'], label='Average Degree')
    if 'Variance of Degree' in aggregated_data.columns:
        plt.plot(aggregated_data['Variance of Degree'], label='Variance of Degree')
    if 'Average Clustering' in aggregated_data.columns:
        plt.plot(aggregated_data['Average Clustering'], label='Average Clustering')
    if 'Average Path Length' in aggregated_data.columns:
        plt.plot(aggregated_data['Average Path Length'], label='Average Path Length', linestyle='--')
    plt.xlabel('Step')
    plt.ylabel('Metric Value')
    plt.title(f'Network Metrics Over Time for {config_name}')
    plt.legend()
    plt.show()

def run_all_simulations(configurations, num_steps, num_simulations):
    results = {}
    for config_name, config in configurations.items():
        print(f"Running simulations for {config_name} network...")
        simulation_data = run_multiple_simulations(config, num_steps, num_simulations)
        results[config_name] = simulation_data
        
    return results

# %%
network_configurations = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

num_simulations = 1
num_steps = 10

results = run_all_simulations(network_configurations, num_steps, num_simulations)
# Out:
# Running simulations for Watts-Strogatz network...
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.22s/it]
# Running simulations for Barabasi-Albert network...
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.36s/it]
# Running simulations for Random Regular network...
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.95s/it]
# Running simulations for Holme-Kim network...
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.28s/it]

# %%
for config_name, simulation_data in results.items():
    plot_adoption_rates(simulation_data, config_name)

# %% [markdown]
# ## Vary TP percentage

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

tp_percentage_values = np.arange(0, 1.00, 0.05)

tp_percentages_percent = tp_percentage_values * 100


def run_simulations_for_tp_percentages(tp_percentage_values, base_network_config, num_steps, num_simulations):
    results = {}
    for config_name, base_config in base_network_config.items():
        results[config_name] = {}
        for tp_percentage in tp_percentage_values:
            config = base_config.copy()
            config['TP_percentage'] = tp_percentage
            simulation_data = run_multiple_simulations(config, num_steps, num_simulations)
            results[config_name][tp_percentage] = simulation_data
    return results

def plot_adoption_rates_for_different_tp(results):
    for config_name, tp_results in results.items():
        plt.figure(figsize=(12, 8))
        for tp_percentage, simulation_data in tp_results.items():
            avg_adoption_rates = []
            for sim_data in simulation_data:
                avg_adoption_rates.append(sim_data['Adoption Rates'].values)
            avg_adoption_rates = np.mean(avg_adoption_rates, axis=0)
            plt.plot(avg_adoption_rates, label=f'TP_percentage = {tp_percentage}', marker='o')
        plt.title(f'True Price Adoption Rate Over Time for {config_name} Network')
        plt.xlabel('Iteration')
        plt.ylabel('True Price Adoption Rate (%)')
        plt.ylim(0, 100)
        plt.legend()
        plt.grid(True)
        plt.show()

results_tp = run_simulations_for_tp_percentages(tp_percentage_values, network_configurations, num_steps, num_simulations)

plot_adoption_rates_for_different_tp(results_tp)
# Out:
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.20s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.21s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.22s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.18s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.21s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.20s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.21s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.24s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.19s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.35s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.32s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.42s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.28s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.19s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.20s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.26s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.35s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.29s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.20s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.30s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.31s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.39s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.35s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.39s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.35s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.40s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.31s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.33s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.35s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.35s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.33s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.34s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.36s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.42s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.37s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.34s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.46s/it]
# Simulation Progress: 100%|██████████| 10/10 [18:12<00:00, 109.26s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.59s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:30<00:00,  3.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.99s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:30<00:00,  3.00s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.90s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.99s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.94s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:30<00:00,  3.01s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.12s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:30<00:00,  3.00s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:40<00:00,  4.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:42<00:00,  4.29s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.55s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:39<00:00,  3.93s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:37<00:00,  3.77s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.60s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.52s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:36<00:00,  3.61s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:42<00:00,  4.20s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:43<00:00,  4.38s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:41<00:00,  4.14s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:42<00:00,  4.20s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:40<00:00,  4.09s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:41<00:00,  4.19s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.41s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.32s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:37<00:00,  3.78s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.43s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:36<00:00,  3.69s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:36<00:00,  3.65s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:43<00:00,  4.32s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:38<00:00,  3.90s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.45s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:38<00:00,  3.87s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.53s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.42s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.33s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:37<00:00,  3.79s/it]

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_final_adoption_rates_by_tp(results, tp_percentage_values, save_dir='./'):
    tp_percentages_percent = tp_percentage_values * 100
    
    for config_name, tp_results in results.items():
        final_adoption_rates = []
        for tp_percentage, simulation_data in tp_results.items():
            avg_final_adoption_rate = []
            for sim_data in simulation_data:
                avg_final_adoption_rate.append(sim_data['Adoption Rates'].values[-1])  # Get final adoption rate
            final_adoption_rates.append(np.mean(avg_final_adoption_rate))  # Average over simulations

        plt.figure(figsize=(8, 6))
        plt.plot(tp_percentages_percent, np.array(final_adoption_rates), marker='o')
        plt.axvline(x=50, color='red', linestyle='--', linewidth=1, label='x = 50')
        plt.xlabel('TP percentage (%)')
        plt.ylabel('Final True Price Adoption Rate (%)')
        plt.grid(True)
        plt.tight_layout()
        filename = f"{save_dir}final_adoption_rate_{config_name}_budget.png"
        plt.savefig(filename)
        plt.show()
        plt.clf()

tp_percentage_values = np.arange(0, 1.00, 0.05)

plot_final_adoption_rates_by_tp(results_tp, tp_percentage_values)

# %%
base_config = {
    'TP_percentage': 0.4,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'kde_models_dir': '/Applications/UNI/Thesis/saved_data/',
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['preference_sustainability'],
    'seed': 42  
}

watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})

network_configurations = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

num_simulations = 1
num_steps = 10


tp_percentage_values = np.arange(0, 1.00, 0.05)

tp_percentages_percent = tp_percentage_values * 100


def run_simulations_for_tp_percentages(tp_percentage_values, base_network_config, num_steps, num_simulations):
    results = {}
    for config_name, base_config in base_network_config.items():
        results[config_name] = {}
        for tp_percentage in tp_percentage_values:
            config = base_config.copy()
            config['TP_percentage'] = tp_percentage
            simulation_data = run_multiple_simulations(config, num_steps, num_simulations)
            results[config_name][tp_percentage] = simulation_data
    return results

def plot_adoption_rates_for_different_tp(results):
    for config_name, tp_results in results.items():
        plt.figure(figsize=(12, 8))
        for tp_percentage, simulation_data in tp_results.items():
            avg_adoption_rates = []
            for sim_data in simulation_data:
                avg_adoption_rates.append(sim_data['Adoption Rates'].values)
            avg_adoption_rates = np.mean(avg_adoption_rates, axis=0)
            plt.plot(avg_adoption_rates, label=f'TP_percentage = {tp_percentage}', marker='o')
        plt.title(f'True Price Adoption Rate Over Time for {config_name} Network')
        plt.xlabel('Iteration')
        plt.ylabel('True Price Adoption Rate (%)')
        plt.ylim(0, 100)
        plt.legend()
        plt.grid(True)
        plt.show()

results_tp = run_simulations_for_tp_percentages(tp_percentage_values, network_configurations, num_steps, num_simulations)

plot_adoption_rates_for_different_tp(results_tp)
# Out:
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.30s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.42s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.36s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.41s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.38s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.31s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:38<00:00,  3.83s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.21s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.59s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:37<00:00,  3.76s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:37<00:00,  3.73s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.25s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.22s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.30s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.23s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.19s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.18s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.56s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:38<00:00,  3.84s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:41<00:00,  4.17s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:42<00:00,  4.22s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:40<00:00,  4.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:40<00:00,  4.00s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.59s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.42s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.49s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:36<00:00,  3.67s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.47s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.39s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:39<00:00,  3.98s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.59s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:36<00:00,  3.61s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.60s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:36<00:00,  3.68s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:38<00:00,  3.87s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.45s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.58s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:30<00:00,  3.05s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:30<00:00,  3.06s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.24s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.18s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.17s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.15s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.41s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.16s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.13s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.99s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.95s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.95s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:28<00:00,  2.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.91s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:28<00:00,  2.90s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:28<00:00,  2.90s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:29<00:00,  2.90s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.26s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.26s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.28s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.29s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.28s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.26s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.28s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.33s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.28s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.26s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.26s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.29s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.30s/it]

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_final_adoption_rates_by_tp(results, tp_percentage_values, save_dir='./'):
    tp_percentages_percent = tp_percentage_values * 100
    
    for config_name, tp_results in results.items():
        final_adoption_rates = []
        for tp_percentage, simulation_data in tp_results.items():
            avg_final_adoption_rate = []
            for sim_data in simulation_data:
                avg_final_adoption_rate.append(sim_data['Adoption Rates'].values[-1])  # Get final adoption rate
            final_adoption_rates.append(np.mean(avg_final_adoption_rate))  # Average over simulations

        plt.figure(figsize=(8, 6))
        plt.plot(tp_percentages_percent, np.array(final_adoption_rates), marker='o')
        plt.axvline(x=50, color='red', linestyle='--', linewidth=1, label='x = 50')
        plt.xlabel('TP percentage (%)')
        plt.ylabel('Final True Price Adoption Rate (%)')
        plt.grid(True)
        plt.tight_layout()
        filename = f"{save_dir}final_adoption_rate_{config_name}_sustainability.png"
        plt.savefig(filename)
        plt.show()
        plt.clf()

tp_percentage_values = np.arange(0, 1.00, 0.05)

plot_final_adoption_rates_by_tp(results_tp, tp_percentage_values)

# %%
base_config = {
    'TP_percentage': 0.4,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'kde_models_dir': '/Applications/UNI/Thesis/saved_data/',
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['preference_conformity'],
    'seed': 42  
}

watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})

network_configurations = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

num_simulations = 1
num_steps = 10


tp_percentage_values = np.arange(0, 1.00, 0.05)

tp_percentages_percent = tp_percentage_values * 100


def run_simulations_for_tp_percentages(tp_percentage_values, base_network_config, num_steps, num_simulations):
    results = {}
    for config_name, base_config in base_network_config.items():
        results[config_name] = {}
        for tp_percentage in tp_percentage_values:
            config = base_config.copy()
            config['TP_percentage'] = tp_percentage
            simulation_data = run_multiple_simulations(config, num_steps, num_simulations)
            results[config_name][tp_percentage] = simulation_data
    return results

def plot_adoption_rates_for_different_tp(results):
    for config_name, tp_results in results.items():
        plt.figure(figsize=(12, 8))
        for tp_percentage, simulation_data in tp_results.items():
            avg_adoption_rates = []
            for sim_data in simulation_data:
                avg_adoption_rates.append(sim_data['Adoption Rates'].values)
            avg_adoption_rates = np.mean(avg_adoption_rates, axis=0)
            plt.plot(avg_adoption_rates, label=f'TP_percentage = {tp_percentage}', marker='o')
        plt.title(f'True Price Adoption Rate Over Time for {config_name} Network')
        plt.xlabel('Iteration')
        plt.ylabel('True Price Adoption Rate (%)')
        plt.ylim(0, 100)
        plt.legend()
        plt.grid(True)
        plt.show()

results_tp = run_simulations_for_tp_percentages(tp_percentage_values, network_configurations, num_steps, num_simulations)

plot_adoption_rates_for_different_tp(results_tp)
# Out:
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.01s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.06s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.05s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.06s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.01s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:22<00:00,  2.25s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:22<00:00,  2.21s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.11s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.09s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.18s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.07s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.08s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.10s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.07s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.08s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.15s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:22<00:00,  2.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.15s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.93s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.03s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.93s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.98s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.96s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.00s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.03s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.98s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.05s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.93s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.71s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:16<00:00,  1.68s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.72s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.72s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.73s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.83s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.80s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.70s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.70s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.70s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.79s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.79s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.70s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.81s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.72s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:16<00:00,  1.69s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:16<00:00,  1.66s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:16<00:00,  1.68s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.91s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.90s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.88s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.88s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.90s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.88s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.12s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.97s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.93s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.91s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_final_adoption_rates_by_tp(results, tp_percentage_values, save_dir='./'):
    tp_percentages_percent = tp_percentage_values * 100
    
    for config_name, tp_results in results.items():
        final_adoption_rates = []
        for tp_percentage, simulation_data in tp_results.items():
            avg_final_adoption_rate = []
            for sim_data in simulation_data:
                avg_final_adoption_rate.append(sim_data['Adoption Rates'].values[-1])  # Get final adoption rate
            final_adoption_rates.append(np.mean(avg_final_adoption_rate))  # Average over simulations

        plt.figure(figsize=(8, 6))
        plt.plot(tp_percentages_percent, np.array(final_adoption_rates), marker='o')
        plt.axvline(x=50, color='red', linestyle='--', linewidth=1, label='x = 50')
        plt.xlabel('TP percentage (%)')
        plt.ylabel('Final True Price Adoption Rate (%)')
        plt.grid(True)
        plt.tight_layout()
        filename = f"{save_dir}final_adoption_rate_{config_name}_conformity.png"
        plt.savefig(filename)
        plt.show()
        plt.clf()

tp_percentage_values = np.arange(0, 1.00, 0.05)

plot_final_adoption_rates_by_tp(results_tp, tp_percentage_values)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from tqdm import tqdm

def collect_simulation_data(model, num_steps):
    collected_data = {
        'Step': [],
        'Adoption Rate': [],
        'Avg_F_Satisfaction': [],
        'Avg_S_Satisfaction': [],
        'Avg_P_Satisfaction': [],
        'Avg_F_Uncertainty': [],
        'Avg_S_Uncertainty': [],
        'Avg_P_Uncertainty': []
    }

    for step in tqdm(range(num_steps), desc='Simulation Progress'):
        model.step()
        collected_data['Step'].append(step)
        collected_data['Adoption Rate'].append(model.calculate_true_price_adoption_rate())
        collected_data['Avg_F_Satisfaction'].append(np.mean([agent.F_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_S_Satisfaction'].append(np.mean([agent.S_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_P_Satisfaction'].append(np.mean([agent.P_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_F_Uncertainty'].append(np.mean([agent.F_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_S_Uncertainty'].append(np.mean([agent.S_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_P_Uncertainty'].append(np.mean([agent.P_uncertainty for agent in model.schedule.agents]))

    model_data = pd.DataFrame(collected_data)
    return model_data

def aggregate_simulation_results(simulation_data):
    aggregated_data = simulation_data[0].copy()
    for df in simulation_data[1:]:
        aggregated_data += df

    aggregated_data /= len(simulation_data)
    return aggregated_data

def plot_metric(all_results, metric, ylabel, filename, scale_as_percentage=False):
    plt.figure(figsize=(15, 8))
    colors = plt.cm.viridis(np.linspace(0, 1, len(all_results)))

    for tp, color in zip(all_results.keys(), colors):
        data = all_results[tp]
        if scale_as_percentage:
            plt.plot(data['Step'], data[metric] * 100, label=f'TP_percentage={tp * 100:.0f}%', color=color)
        else:
            plt.plot(data['Step'], data[metric], label=f'TP_percentage={tp * 100:.0f}%', color=color)

    plt.xlabel('Step', fontsize=14)
    plt.ylabel(ylabel, fontsize=14)
    plt.legend(title='TP_percentage')
    plt.grid(True)

    if scale_as_percentage:
        plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())

    plt.savefig(filename)
    plt.close()

def run_simulations_for_tp_percentages_and_networks(tp_percentage_values, base_network_config, num_steps, num_simulations):
    results = {}
    for config_name, base_config in base_network_config.items():
        results[config_name] = {}
        for tp_percentage in tp_percentage_values:
            config = base_config.copy()
            config['TP_percentage'] = tp_percentage
            simulation_data = run_multiple_simulations(config, num_steps, num_simulations)
            aggregated_data = aggregate_simulation_results(simulation_data)
            results[config_name][tp_percentage] = aggregated_data
    return results

def run_multiple_simulations(config, num_steps, num_simulations):
    all_simulation_data = []
    
    for _ in range(num_simulations):
        model = ConsumatModel(config)
        model_data = collect_simulation_data(model, num_steps)
        all_simulation_data.append(model_data)
        
    return all_simulation_data

network_configurations = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

tp_percentages = np.arange(0, 1.00, 0.1)
num_steps = 10
num_simulations = 1

results = run_simulations_for_tp_percentages_and_networks(tp_percentages, network_configurations, num_steps, num_simulations)

for config_name, all_results in results.items():
    plot_metric(all_results, 'Avg_F_Satisfaction', 'Average Financial Satisfaction', f'dynamic_avg_financial_satisfaction_{config_name}.png')
    plot_metric(all_results, 'Avg_S_Satisfaction', 'Average Social Satisfaction', f'dynamic_avg_social_satisfaction_{config_name}.png')
    plot_metric(all_results, 'Avg_P_Satisfaction', 'Average Personal Satisfaction', f'vavg_personal_satisfaction_{config_name}.png')
    plot_metric(all_results, 'Avg_F_Uncertainty', 'Average Financial Uncertainty', f'dynamic_avg_financial_uncertainty_{config_name}.png')
    plot_metric(all_results, 'Avg_S_Uncertainty', 'Average Social Uncertainty', f'dynamic_avg_social_uncertainty_{config_name}.png')
    plot_metric(all_results, 'Avg_P_Uncertainty', 'Average Personal Uncertainty', f'dynamic_avg_personal_uncertainty_{config_name}.png')
# Out:
# Simulation Progress: 100%|██████████| 10/10 [00:36<00:00,  3.63s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:36<00:00,  3.63s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:36<00:00,  3.70s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:42<00:00,  4.21s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.45s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.52s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.56s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:37<00:00,  3.72s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:45<00:00,  4.56s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:49<00:00,  4.93s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:43<00:00,  4.35s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:47<00:00,  4.74s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:39<00:00,  4.00s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:41<00:00,  4.16s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:44<00:00,  4.44s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:46<00:00,  4.69s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:46<00:00,  4.67s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:52<00:00,  5.25s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:50<00:00,  5.02s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:49<00:00,  4.94s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:47<00:00,  4.76s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:39<00:00,  3.98s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.21s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:38<00:00,  3.81s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:33<00:00,  3.31s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:31<00:00,  3.16s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:30<00:00,  3.03s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:37<00:00,  3.70s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:41<00:00,  4.16s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:39<00:00,  3.91s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:42<00:00,  4.27s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:50<00:00,  5.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:35<00:00,  3.53s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:43<00:00,  4.40s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:53<00:00,  5.38s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:47<00:00,  4.72s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:48<00:00,  4.85s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:44<00:00,  4.45s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:34<00:00,  3.47s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:32<00:00,  3.27s/it]

# %% [markdown]
# ## Vary epsilon

# %%
base_config = {
    'TP_percentage': 0.5,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['preference_sustainability'],
    'seed': 42  
}

watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})

network_configurations = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

epsilon_values = np.arange(0, 1.2, 0.2)
num_steps = 10
def run_simulations_for_epsilon_values(epsilon_values, base_network_config, num_steps, num_simulations):
    results = {}
    for config_name, base_config in base_network_config.items():
        results[config_name] = {}
        for epsilon in epsilon_values:
            config = base_config.copy()
            config['epsilon'] = epsilon
            simulation_data = run_multiple_simulations(config, num_steps, num_simulations)
            results[config_name][epsilon] = simulation_data
    return results



results_epsilon = run_simulations_for_epsilon_values(epsilon_values, network_configurations, num_steps, num_simulations)
# Out:
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.91s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.91s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.07s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.90s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:21<00:00,  2.12s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.09s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.93s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.93s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:16<00:00,  1.69s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.72s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:16<00:00,  1.69s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.70s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:16<00:00,  1.69s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.73s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.92s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.88s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.90s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.88s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.88s/it]

# %%
print(results_epsilon)
# Out:
# {'Watts-Strogatz': {0.0: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0          0.000            0.654033            0.767690
# 1     1          0.000            0.667713            0.767690
# 2     2          0.000            0.673157            0.767690
# 3     3         82.500            0.684668            0.495955
# 4     4         86.250            0.702747            0.686663
# 5     5         90.375            0.710173            0.699307
# 6     6         91.625            0.711302            0.709546
# 7     7         92.500            0.712250            0.714169
# 8     8         93.000            0.712103            0.718311
# 9     9         93.000            0.712397            0.718549
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.321495           0.607214           0.612604           0.625887
# 1            0.414839           0.586213           0.612604           0.612349
# 2            0.473692           0.578144           0.612604           0.590048
# 3            0.458271           0.600503           0.085521           0.534852
# 4            0.578510           0.593277           0.011795           0.540884
# 5            0.607312           0.589792           0.022547           0.537076
# 6            0.615505           0.589851           0.021179           0.533849
# 7            0.619215           0.589984           0.020141           0.533076
# 8            0.621267           0.589971           0.019999           0.532141
# 9            0.620939           0.590161           0.019829           0.531796  ], 0.2: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.654148            0.767690
# 1     1         0.0000            0.663853            0.767690
# 2     2         0.0000            0.668558            0.767690
# 3     3        82.9375            0.685999            0.492591
# 4     4        87.2500            0.703413            0.692719
# 5     5        90.6875            0.707099            0.709488
# 6     6        91.6250            0.708597            0.717763
# 7     7        92.0625            0.708939            0.719556
# 8     8        92.1875            0.708585            0.719908
# 9     9        92.1250            0.708821            0.719856
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.321101           0.606670           0.612604           0.626360
# 1            0.397264           0.595960           0.612604           0.586427
# 2            0.474152           0.588666           0.612604           0.571657
# 3            0.482921           0.606293           0.089896           0.533037
# 4            0.588996           0.598557           0.011241           0.536721
# 5            0.616659           0.596838           0.022139           0.532600
# 6            0.623462           0.596285           0.020030           0.529103
# 7            0.624825           0.596322           0.019477           0.528547
# 8            0.625582           0.596200           0.019034           0.528635
# 9            0.625544           0.596243           0.018368           0.528729  ], 0.4: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.653952            0.767690
# 1     1         0.0000            0.662452            0.767690
# 2     2         0.0000            0.667644            0.767690
# 3     3        83.2500            0.685289            0.492439
# 4     4        87.5000            0.698537            0.693465
# 5     5        90.6875            0.703642            0.707703
# 6     6        91.8125            0.704917            0.714989
# 7     7        92.3125            0.706182            0.718968
# 8     8        92.4375            0.706177            0.719797
# 9     9        92.5625            0.706033            0.720387
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.321108           0.606709           0.612604           0.630004
# 1            0.420809           0.590303           0.612604           0.605421
# 2            0.498403           0.583413           0.612604           0.578682
# 3            0.509586           0.600874           0.096667           0.530819
# 4            0.605709           0.594394           0.010191           0.533221
# 5            0.630248           0.591937           0.016122           0.528439
# 6            0.634742           0.592299           0.016241           0.525468
# 7            0.636885           0.592277           0.016435           0.525772
# 8            0.636724           0.592459           0.016287           0.524933
# 9            0.637250           0.592383           0.016356           0.524968  ], 0.6000000000000001: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.652721            0.767690
# 1     1         0.0000            0.665855            0.767690
# 2     2         0.0000            0.669013            0.767690
# 3     3        81.0625            0.680362            0.495321
# 4     4        84.5625            0.699780            0.686440
# 5     5        88.3750            0.705690            0.696298
# 6     6        89.6250            0.704627            0.704264
# 7     7        90.3125            0.706194            0.710244
# 8     8        90.8125            0.705408            0.711978
# 9     9        91.1250            0.705993            0.713093
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.319083           0.606220           0.612604           0.633778
# 1            0.398875           0.593006           0.612604           0.615329
# 2            0.473972           0.586203           0.612604           0.599644
# 3            0.482463           0.603101           0.095521           0.552447
# 4            0.582066           0.594685           0.013065           0.549029
# 5            0.610312           0.592144           0.021473           0.540928
# 6            0.618254           0.591325           0.019418           0.537705
# 7            0.621262           0.591567           0.019144           0.536335
# 8            0.622795           0.591377           0.019208           0.534669
# 9            0.624970           0.591214           0.020390           0.535111  ], 0.8: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.653805            0.767690
# 1     1         0.0000            0.666426            0.767690
# 2     2         0.0000            0.669497            0.767690
# 3     3        79.1875            0.680303            0.501928
# 4     4        83.1250            0.699011            0.683666
# 5     5        86.6250            0.704498            0.694829
# 6     6        88.3125            0.706636            0.703175
# 7     7        89.2500            0.707137            0.708606
# 8     8        90.0000            0.708413            0.713381
# 9     9        90.6875            0.709122            0.713776
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.322506           0.605525           0.612604           0.632040
# 1            0.390996           0.592735           0.612604           0.609150
# 2            0.478730           0.581523           0.612604           0.597424
# 3            0.486072           0.599501           0.101771           0.554556
# 4            0.582424           0.592656           0.014550           0.553881
# 5            0.610404           0.590027           0.018791           0.544841
# 6            0.621448           0.589095           0.018443           0.540555
# 7            0.626216           0.588776           0.020020           0.538254
# 8            0.627825           0.588447           0.019606           0.536737
# 9            0.630674           0.588525           0.019386           0.535157  ], 1.0: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.652648            0.767690
# 1     1         0.0000            0.664386            0.767690
# 2     2         0.0000            0.668941            0.767690
# 3     3        75.8125            0.685105            0.507712
# 4     4        80.9375            0.703959            0.674168
# 5     5        85.5625            0.706572            0.691464
# 6     6        86.5000            0.707002            0.700338
# 7     7        87.3750            0.707238            0.703881
# 8     8        87.8750            0.707719            0.706795
# 9     9        88.1875            0.708193            0.708425
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.323747           0.605053           0.612604           0.632677
# 1            0.379996           0.594384           0.612604           0.592366
# 2            0.447085           0.583099           0.612604           0.581678
# 3            0.448993           0.603783           0.102083           0.545210
# 4            0.568999           0.596576           0.011126           0.547932
# 5            0.602628           0.593361           0.017460           0.546418
# 6            0.607063           0.593562           0.016114           0.544431
# 7            0.609932           0.593180           0.015539           0.543442
# 8            0.612480           0.592967           0.015764           0.542261
# 9            0.613785           0.592759           0.015284           0.542014  ]}, 'Barabasi-Albert': {0.0: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.657140            0.767690
# 1     1         0.0000            0.664277            0.767690
# 2     2         0.0000            0.686434            0.767690
# 3     3        96.1250            0.692815            0.486016
# 4     4        95.9375            0.701769            0.729869
# 5     5        97.0000            0.702809            0.737583
# 6     6        97.0625            0.702582            0.739441
# 7     7        97.0625            0.702819            0.739774
# 8     8        97.1250            0.702584            0.739803
# 9     9        97.0625            0.702819            0.739703
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.320835           0.606800           0.612604           0.628806
# 1            0.442708           0.596023           0.612604           0.573426
# 2            0.627967           0.566526           0.612604           0.514557
# 3            0.605829           0.591780           0.050313           0.497292
# 4            0.659396           0.587365           0.007236           0.503832
# 5            0.665516           0.587021           0.017301           0.504586
# 6            0.664804           0.587122           0.016605           0.503910
# 7            0.665147           0.587164           0.016824           0.504052
# 8            0.665185           0.587121           0.016979           0.503957
# 9            0.665147           0.587164           0.016982           0.504052  ], 0.2: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.655342            0.767690
# 1     1         0.0000            0.674009            0.767690
# 2     2         0.0000            0.689238            0.767690
# 3     3        96.8750            0.695955            0.495211
# 4     4        97.0000            0.703857            0.740357
# 5     5        97.7500            0.704364            0.745564
# 6     6        97.8125            0.704129            0.747219
# 7     7        97.7500            0.704364            0.746824
# 8     8        97.8125            0.704129            0.747263
# 9     9        97.7500            0.704364            0.746890
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.318362           0.605039           0.612604           0.631205
# 1            0.450649           0.581706           0.612604           0.596823
# 2            0.643450           0.563560           0.612604           0.512198
# 3            0.613690           0.590524           0.045104           0.498689
# 4            0.663113           0.586671           0.006022           0.504625
# 5            0.667362           0.586470           0.013493           0.505125
# 6            0.667400           0.586427           0.013733           0.505031
# 7            0.667362           0.586470           0.013677           0.505125
# 8            0.667400           0.586427           0.013622           0.505031
# 9            0.667362           0.586470           0.013528           0.505125  ], 0.4: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.653517            0.767690
# 1     1         0.0000            0.668507            0.767690
# 2     2         0.0000            0.690751            0.767690
# 3     3        97.0625            0.697320            0.493922
# 4     4        96.7500            0.706285            0.736841
# 5     5        97.5000            0.706549            0.740657
# 6     6        97.5625            0.706313            0.743042
# 7     7        97.5000            0.706549            0.742868
# 8     8        97.5625            0.706313            0.743063
# 9     9        97.5000            0.706549            0.742802
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.319586           0.608418           0.612604           0.633139
# 1            0.442544           0.590701           0.612604           0.589938
# 2            0.653508           0.563072           0.612604           0.510513
# 3            0.610426           0.590819           0.044792           0.497459
# 4            0.661658           0.587501           0.007683           0.504687
# 5            0.666378           0.587343           0.016046           0.505073
# 6            0.666416           0.587300           0.016087           0.504979
# 7            0.666378           0.587343           0.015890           0.505073
# 8            0.666416           0.587300           0.015670           0.504979
# 9            0.666378           0.587343           0.015659           0.505073  ], 0.6000000000000001: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.653049            0.767690
# 1     1         0.0000            0.667081            0.767690
# 2     2         0.0000            0.688826            0.767690
# 3     3        96.8750            0.697638            0.492217
# 4     4        96.6875            0.703335            0.736756
# 5     5        97.6875            0.703187            0.743881
# 6     6        97.6875            0.703454            0.745218
# 7     7        97.7500            0.703209            0.745549
# 8     8        97.6875            0.703454            0.745434
# 9     9        97.7500            0.703209            0.745623
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.321317           0.608008           0.612604           0.632179
# 1            0.442579           0.591198           0.612604           0.570322
# 2            0.652336           0.563776           0.612604           0.508834
# 3            0.615800           0.590046           0.048958           0.496898
# 4            0.661640           0.587154           0.006418           0.503380
# 5            0.667111           0.586675           0.012719           0.503513
# 6            0.667537           0.586694           0.012818           0.503663
# 7            0.667575           0.586651           0.012990           0.503569
# 8            0.667537           0.586694           0.012322           0.503663
# 9            0.667575           0.586651           0.012762           0.503569  ], 0.8: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.653741            0.767690
# 1     1         0.0000            0.668124            0.767690
# 2     2         0.0000            0.690867            0.767690
# 3     3        97.2500            0.696058            0.497591
# 4     4        96.7500            0.702665            0.739976
# 5     5        97.7500            0.703038            0.744457
# 6     6        97.7500            0.703246            0.746197
# 7     7        97.8125            0.702992            0.746592
# 8     8        97.7500            0.703246            0.746287
# 9     9        97.8125            0.702992            0.746528
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.317625           0.605607           0.612604           0.636874
# 1            0.454573           0.584625           0.612604           0.589972
# 2            0.658151           0.561090           0.612604           0.509610
# 3            0.615427           0.589397           0.044271           0.498591
# 4            0.662475           0.586651           0.005708           0.503625
# 5            0.667152           0.586271           0.013703           0.504247
# 6            0.667870           0.586317           0.013043           0.504267
# 7            0.667400           0.586277           0.013065           0.504109
# 8            0.667870           0.586317           0.012877           0.504267
# 9            0.667400           0.586277           0.013208           0.504109  ], 1.0: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.653059            0.767690
# 1     1         0.0000            0.655925            0.767690
# 2     2         0.0000            0.690511            0.767690
# 3     3        97.4375            0.697470            0.492832
# 4     4        96.8750            0.705312            0.739284
# 5     5        97.8125            0.705205            0.743892
# 6     6        97.8125            0.705519            0.746066
# 7     7        97.8750            0.705270            0.746691
# 8     8        97.8125            0.705519            0.746345
# 9     9        97.8750            0.705270            0.746647
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.322988           0.606831           0.612604           0.631543
# 1            0.420595           0.600610           0.612604           0.601634
# 2            0.652423           0.562891           0.612604           0.510864
# 3            0.614474           0.589988           0.050729           0.498137
# 4            0.663039           0.587397           0.007491           0.503934
# 5            0.667351           0.586858           0.013675           0.504360
# 6            0.668258           0.586865           0.013642           0.504571
# 7            0.668042           0.586824           0.013074           0.504445
# 8            0.668258           0.586865           0.013052           0.504571
# 9            0.668042           0.586824           0.013207           0.504445  ]}, 'Random Regular': {0.0: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.658920            0.767690
# 1     1         0.0000            0.668753            0.767690
# 2     2         0.0000            0.677899            0.767690
# 3     3        92.3125            0.689550            0.477446
# 4     4        94.6250            0.704915            0.716697
# 5     5        96.3750            0.707716            0.732093
# 6     6        96.5000            0.707323            0.735453
# 7     7        96.4375            0.707554            0.735115
# 8     8        96.5000            0.707323            0.735599
# 9     9        96.4375            0.707554            0.735205
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.323746           0.606337           0.612604           0.628857
# 1            0.414545           0.593493           0.612604           0.595808
# 2            0.534107           0.578507           0.612604           0.554393
# 3            0.558784           0.596180           0.075833           0.504231
# 4            0.641446           0.589668           0.007638           0.508578
# 5            0.654112           0.588427           0.017954           0.507764
# 6            0.655872           0.588248           0.017035           0.506956
# 7            0.655580           0.588292           0.016957           0.507019
# 8            0.655872           0.588248           0.016644           0.506956
# 9            0.655580           0.588292           0.016722           0.507019  ], 0.2: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.657261            0.767690
# 1     1         0.0000            0.664125            0.767690
# 2     2         0.0000            0.678632            0.767690
# 3     3        94.7500            0.693859            0.479936
# 4     4        96.2500            0.704423            0.729416
# 5     5        97.3750            0.706841            0.741302
# 6     6        97.4375            0.706237            0.743386
# 7     7        97.3750            0.706467            0.743089
# 8     8        97.4375            0.706237            0.743450
# 9     9        97.3750            0.706467            0.743032
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.323749           0.605104           0.612604           0.632031
# 1            0.410471           0.594746           0.612604           0.600697
# 2            0.558286           0.575721           0.612604           0.542514
# 3            0.592447           0.594101           0.075937           0.498822
# 4            0.656262           0.589438           0.006830           0.504566
# 5            0.662817           0.588633           0.012913           0.505744
# 6            0.663050           0.588591           0.012266           0.505440
# 7            0.662758           0.588636           0.012031           0.505502
# 8            0.663050           0.588591           0.012031           0.505440
# 9            0.662758           0.588636           0.012188           0.505502  ], 0.4: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.653592            0.767690
# 1     1         0.0000            0.672244            0.767690
# 2     2         0.0000            0.679695            0.767690
# 3     3        96.5625            0.696665            0.485998
# 4     4        96.1875            0.704936            0.731143
# 5     5        97.1250            0.706563            0.736534
# 6     6        97.1875            0.706013            0.739040
# 7     7        97.1250            0.706243            0.738528
# 8     8        97.1875            0.706013            0.738879
# 9     9        97.1250            0.706243            0.738495
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.322796           0.605761           0.612604           0.630994
# 1            0.410963           0.586451           0.612604           0.594162
# 2            0.557255           0.571019           0.612604           0.539081
# 3            0.607461           0.590858           0.068542           0.498768
# 4            0.657553           0.587813           0.009810           0.502389
# 5            0.662092           0.587405           0.020123           0.503390
# 6            0.662713           0.587362           0.019442           0.503133
# 7            0.662421           0.587407           0.019833           0.503196
# 8            0.662713           0.587362           0.019833           0.503133
# 9            0.662421           0.587407           0.019911           0.503196  ], 0.6000000000000001: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.652768            0.767690
# 1     1         0.0000            0.665289            0.767690
# 2     2         0.0000            0.684307            0.767690
# 3     3        96.8750            0.698516            0.480892
# 4     4        97.3125            0.705456            0.740512
# 5     5        97.8125            0.705272            0.744596
# 6     6        97.8750            0.705063            0.745790
# 7     7        97.8125            0.705294            0.745477
# 8     8        97.8750            0.705063            0.745753
# 9     9        97.8125            0.705294            0.745392
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.322740           0.606377           0.612604           0.632160
# 1            0.422956           0.593356           0.612604           0.582518
# 2            0.590950           0.573418           0.612604           0.527132
# 3            0.610715           0.590929           0.075208           0.497436
# 4            0.662178           0.587943           0.004978           0.503272
# 5            0.664472           0.587656           0.013795           0.503610
# 6            0.665152           0.587592           0.012846           0.503595
# 7            0.664860           0.587636           0.012690           0.503657
# 8            0.665152           0.587592           0.012924           0.503595
# 9            0.664860           0.587636           0.012924           0.503657  ], 0.8: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.652589            0.767690
# 1     1         0.0000            0.669315            0.767690
# 2     2         0.0000            0.681072            0.767690
# 3     3        96.6250            0.694606            0.484703
# 4     4        96.6875            0.702284            0.734250
# 5     5        97.6250            0.702824            0.741670
# 6     6        97.6875            0.702589            0.743657
# 7     7        97.6250            0.702824            0.743499
# 8     8        97.6875            0.702589            0.743657
# 9     9        97.6250            0.702824            0.743399
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.323211           0.606573           0.612604           0.631414
# 1            0.397952           0.595392           0.612604           0.608610
# 2            0.556546           0.575229           0.612604           0.547498
# 3            0.606654           0.590362           0.070729           0.498993
# 4            0.659889           0.587349           0.007504           0.502953
# 5            0.665515           0.587019           0.013013           0.503814
# 6            0.665553           0.586976           0.013839           0.503719
# 7            0.665515           0.587019           0.013292           0.503814
# 8            0.665553           0.586976           0.013839           0.503719
# 9            0.665515           0.587019           0.013527           0.503814  ], 1.0: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.653403            0.767690
# 1     1         0.0000            0.668203            0.767690
# 2     2         0.0000            0.683150            0.767690
# 3     3        96.9375            0.694684            0.486419
# 4     4        96.5625            0.701604            0.735379
# 5     5        97.6875            0.702241            0.741879
# 6     6        97.6250            0.702493            0.743250
# 7     7        97.6875            0.702241            0.743528
# 8     8        97.6250            0.702493            0.743250
# 9     9        97.6875            0.702241            0.743458
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.320977           0.605306           0.612604           0.631534
# 1            0.404338           0.592812           0.612604           0.608404
# 2            0.585339           0.571600           0.612604           0.536131
# 3            0.609564           0.590278           0.067187           0.498331
# 4            0.660502           0.587353           0.007121           0.502169
# 5            0.665954           0.586900           0.014241           0.503354
# 6            0.666297           0.586940           0.013817           0.503496
# 7            0.665954           0.586900           0.014051           0.503354
# 8            0.666297           0.586940           0.013817           0.503496
# 9            0.665954           0.586900           0.014208           0.503354  ]}, 'Holme-Kim': {0.0: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.656474            0.767690
# 1     1         0.0000            0.673539            0.767690
# 2     2         0.0000            0.688862            0.767690
# 3     3        96.8125            0.698287            0.493096
# 4     4        96.5625            0.705915            0.737392
# 5     5        97.6250            0.706601            0.743997
# 6     6        97.5625            0.706318            0.745056
# 7     7        97.5625            0.706304            0.744981
# 8     8        97.5625            0.706318            0.745009
# 9     9        97.5625            0.706304            0.745054
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.321206           0.606009           0.612604           0.630373
# 1            0.451493           0.590032           0.612604           0.577385
# 2            0.638821           0.565238           0.612604           0.513466
# 3            0.605388           0.591261           0.045208           0.497656
# 4            0.658210           0.588037           0.007881           0.504356
# 5            0.664139           0.587496           0.014820           0.505160
# 6            0.664746           0.587370           0.014769           0.504852
# 7            0.664492           0.587372           0.015263           0.504821
# 8            0.664746           0.587370           0.015415           0.504852
# 9            0.664492           0.587372           0.014707           0.504821  ], 0.2: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.654981            0.767690
# 1     1         0.0000            0.668812            0.767690
# 2     2         0.0000            0.682977            0.767690
# 3     3        95.9375            0.699143            0.489056
# 4     4        96.4375            0.707838            0.734617
# 5     5        97.4375            0.708689            0.742405
# 6     6        97.3750            0.708502            0.743524
# 7     7        97.3750            0.708488            0.743316
# 8     8        97.5000            0.708267            0.743814
# 9     9        97.5625            0.708193            0.744085
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.317251           0.608762           0.612604           0.626682
# 1            0.422196           0.598417           0.612604           0.580418
# 2            0.624429           0.569744           0.612604           0.513928
# 3            0.606246           0.591587           0.061458           0.497571
# 4            0.657926           0.588297           0.007584           0.504250
# 5            0.663863           0.587750           0.016084           0.504888
# 6            0.664093           0.587660           0.015424           0.505024
# 7            0.663839           0.587663           0.016240           0.504992
# 8            0.664197           0.587795           0.015612           0.504822
# 9            0.663869           0.587840           0.014756           0.504794  ], 0.4: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.650510            0.767690
# 1     1         0.0000            0.669796            0.767690
# 2     2         0.0000            0.690918            0.767690
# 3     3        97.1875            0.696815            0.501270
# 4     4        96.8125            0.702506            0.739093
# 5     5        97.7500            0.703319            0.744855
# 6     6        97.6875            0.702814            0.745965
# 7     7        97.6875            0.702802            0.745847
# 8     8        97.6875            0.702814            0.745947
# 9     9        97.6875            0.702802            0.745914
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.320844           0.605232           0.612604           0.631749
# 1            0.453916           0.589789           0.612604           0.583146
# 2            0.659046           0.562661           0.612604           0.508838
# 3            0.621118           0.589866           0.041250           0.498961
# 4            0.664205           0.587147           0.008297           0.504211
# 5            0.668847           0.586798           0.015317           0.505008
# 6            0.668762           0.586760           0.014995           0.504962
# 7            0.668635           0.586761           0.015643           0.504946
# 8            0.668762           0.586760           0.015628           0.504962
# 9            0.668635           0.586761           0.015115           0.504946  ], 0.6000000000000001: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.652115            0.767690
# 1     1         0.0000            0.674140            0.767690
# 2     2         0.0000            0.691549            0.767690
# 3     3        97.1250            0.695170            0.509011
# 4     4        96.9375            0.701931            0.740009
# 5     5        97.6875            0.702405            0.744705
# 6     6        97.6875            0.702414            0.745988
# 7     7        97.6875            0.702405            0.745723
# 8     8        97.6875            0.702414            0.745924
# 9     9        97.6875            0.702405            0.745857
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.321106           0.607014           0.612604           0.633463
# 1            0.446516           0.584009           0.612604           0.577809
# 2            0.656677           0.562459           0.612604           0.508542
# 3            0.623749           0.589753           0.040521           0.498319
# 4            0.662981           0.587165           0.006481           0.502594
# 5            0.667913           0.586922           0.013930           0.503160
# 6            0.667913           0.586921           0.013784           0.503160
# 7            0.667913           0.586922           0.014213           0.503160
# 8            0.667913           0.586921           0.014319           0.503160
# 9            0.667913           0.586922           0.013888           0.503160  ], 0.8: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.651617            0.767690
# 1     1         0.0000            0.671539            0.767690
# 2     2         0.0000            0.691817            0.767690
# 3     3        97.1875            0.697278            0.492458
# 4     4        97.3750            0.704171            0.744132
# 5     5        98.0000            0.704367            0.748788
# 6     6        98.0000            0.704346            0.749989
# 7     7        98.0625            0.704354            0.750372
# 8     8        98.0625            0.704368            0.750519
# 9     9        98.0625            0.704354            0.750436
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.319488           0.606110           0.612604           0.634899
# 1            0.481030           0.584542           0.612604           0.575581
# 2            0.662286           0.561309           0.612604           0.507334
# 3            0.621194           0.589600           0.055313           0.497513
# 4            0.666912           0.586813           0.002940           0.503156
# 5            0.670352           0.586701           0.007847           0.503624
# 6            0.670163           0.586736           0.007449           0.503432
# 7            0.670373           0.586714           0.007536           0.503457
# 8            0.670628           0.586712           0.007298           0.503489
# 9            0.670373           0.586714           0.007253           0.503457  ], 1.0: [   Step  Adoption Rate  Avg_F_Satisfaction  Avg_S_Satisfaction  \
# 0     0         0.0000            0.651439            0.767690
# 1     1         0.0000            0.677500            0.767690
# 2     2         0.0000            0.690820            0.767690
# 3     3        97.5000            0.698245            0.491411
# 4     4        97.2500            0.704274            0.742366
# 5     5        98.0625            0.704338            0.746657
# 6     6        98.0000            0.704588            0.747628
# 7     7        98.0625            0.704338            0.747964
# 8     8        98.0000            0.704588            0.747577
# 9     9        98.0625            0.704338            0.747932
#
#    Avg_P_Satisfaction  Avg_F_Uncertainty  Avg_S_Uncertainty  Avg_P_Uncertainty
# 0            0.315228           0.607486           0.612604           0.630822
# 1            0.517943           0.581144           0.612604           0.564060
# 2            0.664389           0.561150           0.612604           0.507752
# 3            0.620995           0.589856           0.045417           0.498263
# 4            0.663323           0.587108           0.005417           0.504469
# 5            0.667304           0.586871           0.015805           0.505022
# 6            0.667520           0.586913           0.015139           0.505147
# 7            0.667304           0.586871           0.014948           0.505022
# 8            0.667520           0.586913           0.015649           0.505147
# 9            0.667304           0.586871           0.015059           0.505022  ]}}

# %%
import os

def plot_adoption_rates_for_different_epsilon(results, save_dir):
    os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist

    for config_name, epsilon_results in results.items():
        plt.figure(figsize=(12, 8))
        colors = plt.cm.viridis(np.linspace(0, 1, len(epsilon_results)))
        
        for color, (epsilon, simulation_data) in zip(colors, epsilon_results.items()):
            avg_adoption_rates = []
            for sim_data in simulation_data:
                avg_adoption_rates.append(sim_data['Adoption Rate'].values)
            avg_adoption_rates = np.mean(avg_adoption_rates, axis=0)
            plt.plot(avg_adoption_rates, label=f'epsilon = {epsilon:.1f}', marker='o', color=color)

        plt.xlabel('Iteration', fontsize=16)
        plt.ylabel('True Price Adoption Rate (%)', fontsize=16)
        plt.ylim(0, 100)
        plt.legend(title='Epsilon', fontsize=12)
        plt.grid(True)

        # Save the plot with a self-explanatory name
        filename = f'epsilontrue_price_adoption_rate_{config_name.lower().replace(" ", "_")}.png'
        plt.savefig(os.path.join(save_dir, filename))
        plt.close()


save_dir = '/Applications/UNI/ThesisNew/Networks/No homophily/New data'
plot_adoption_rates_for_different_epsilon(results_epsilon, save_dir)

# %%
base_config = {
    'TP_percentage': 0.5,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['preference_conformity'],
    'seed': 42  
}

watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})

network_configurations = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

epsilon_values = np.arange(0, 1.2, 0.2)
num_steps = 10
def run_simulations_for_epsilon_values(epsilon_values, base_network_config, num_steps, num_simulations):
    results = {}
    for config_name, base_config in base_network_config.items():
        results[config_name] = {}
        for epsilon in epsilon_values:
            config = base_config.copy()
            config['epsilon'] = epsilon
            simulation_data = run_multiple_simulations(config, num_steps, num_simulations)
            results[config_name][epsilon] = simulation_data
    return results



results_epsilon = run_simulations_for_epsilon_values(epsilon_values, network_configurations, num_steps, num_simulations)
# Out:
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.99s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.94s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.93s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.94s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.96s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.99s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.01s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.98s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.09s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.77s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.82s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.78s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.74s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.73s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.71s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.00s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.99s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  2.00s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.98s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.98s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.92s/it]

# %%
import os

def plot_adoption_rates_for_different_epsilon(results, save_dir):
    os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist

    for config_name, epsilon_results in results.items():
        plt.figure(figsize=(12, 8))
        colors = plt.cm.viridis(np.linspace(0, 1, len(epsilon_results)))
        
        for color, (epsilon, simulation_data) in zip(colors, epsilon_results.items()):
            avg_adoption_rates = []
            for sim_data in simulation_data:
                avg_adoption_rates.append(sim_data['Adoption Rate'].values)
            avg_adoption_rates = np.mean(avg_adoption_rates, axis=0)
            plt.plot(avg_adoption_rates, label=f'epsilon = {epsilon:.1f}', marker='o', color=color)

        plt.xlabel('Iteration', fontsize=16)
        plt.ylabel('True Price Adoption Rate (%)', fontsize=16)
        plt.ylim(0, 100)
        plt.legend(title='Epsilon', fontsize=12)
        plt.grid(True)

        # Save the plot with a self-explanatory name
        filename = f'epsilon_conformitytrue_price_adoption_rate_{config_name.lower().replace(" ", "_")}.png'
        plt.savefig(os.path.join(save_dir, filename))
        plt.close()


save_dir = '/Applications/UNI/ThesisNew/Networks/No homophily/New data'
plot_adoption_rates_for_different_epsilon(results_epsilon, save_dir)

# %%
base_config = {
    'TP_percentage': 0.5,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['budget'],
    'seed': 42  
}

watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})

network_configurations = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

epsilon_values = np.arange(0, 1.2, 0.2)
num_steps = 10
def run_simulations_for_epsilon_values(epsilon_values, base_network_config, num_steps, num_simulations):
    results = {}
    for config_name, base_config in base_network_config.items():
        results[config_name] = {}
        for epsilon in epsilon_values:
            config = base_config.copy()
            config['epsilon'] = epsilon
            simulation_data = run_multiple_simulations(config, num_steps, num_simulations)
            results[config_name][epsilon] = simulation_data
    return results



results_epsilon = run_simulations_for_epsilon_values(epsilon_values, network_configurations, num_steps, num_simulations)
# Out:
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.94s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.93s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.99s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.91s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.89s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.96s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.98s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.97s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.08s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:16<00:00,  1.69s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.76s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.77s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.79s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:18<00:00,  1.84s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:17<00:00,  1.75s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.95s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.96s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.03s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  2.00s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:20<00:00,  2.04s/it]
# Simulation Progress: 100%|██████████| 10/10 [00:19<00:00,  1.92s/it]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/thesisenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Adoption Rates'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 95
#      92         plt.grid(True)
#      93         plt.show()
# ---> 95 plot_adoption_rates_for_different_epsilon(results_epsilon)
#
# Cell In[81], line 84, in plot_adoption_rates_for_different_epsilon(results)
#      82 avg_adoption_rates = []
#      83 for sim_data in simulation_data:
# ---> 84     avg_adoption_rates.append(sim_data['Adoption Rates'].values)
#      85 avg_adoption_rates = np.mean(avg_adoption_rates, axis=0)
#      86 plt.plot(avg_adoption_rates, label=f'epsilon = {epsilon:.1f}', marker='o')
#
# File ~/opt/anaconda3/envs/thesisenv/lib/python3.9/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/thesisenv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'Adoption Rates'

# %%
import os

def plot_adoption_rates_for_different_epsilon(results, save_dir):
    os.makedirs(save_dir, exist_ok=True)  # Create the directory if it doesn't exist

    for config_name, epsilon_results in results.items():
        plt.figure(figsize=(12, 8))
        colors = plt.cm.viridis(np.linspace(0, 1, len(epsilon_results)))
        
        for color, (epsilon, simulation_data) in zip(colors, epsilon_results.items()):
            avg_adoption_rates = []
            for sim_data in simulation_data:
                avg_adoption_rates.append(sim_data['Adoption Rate'].values)
            avg_adoption_rates = np.mean(avg_adoption_rates, axis=0)
            plt.plot(avg_adoption_rates, label=f'epsilon = {epsilon:.1f}', marker='o', color=color)

        plt.xlabel('Iteration', fontsize=16)
        plt.ylabel('True Price Adoption Rate (%)', fontsize=16)
        plt.ylim(0, 100)
        plt.legend(title='Epsilon', fontsize=12)
        plt.grid(True)

        # Save the plot with a self-explanatory name
        filename = f'epsilon_budgettrue_price_adoption_rate_{config_name.lower().replace(" ", "_")}.png'
        plt.savefig(os.path.join(save_dir, filename))
        plt.close()


save_dir = '/Applications/UNI/ThesisNew/Networks/No homophily/New data'
plot_adoption_rates_for_different_epsilon(results_epsilon, save_dir)

# %% [markdown]
# ## Network topology
#
# ### Watts-Strogatz Network
# - **Type:** Small-world network
# - **Known For:** High clustering coefficient and short average path lengths, which mimic many real-world social networks.
# - **Formation:** Starts with a ring of `n` nodes each connected to `k` nearest neighbors. Rewires each edge with probability `p` to a randomly chosen node.
# - **Key Parameters:**
#   - `n`: Number of nodes
#   - `k`: Number of nearest neighbors in the initial ring topology
#   - `p`: Probability of rewiring each edge
#
# ### Barabasi-Albert Network
# - **Type:** Scale-free network
# - **Known For:** Its degree distribution follows a power law, which is typical for many large networks such as the internet, citation networks, and some social networks.
# - **Formation:** Begins with a small number of nodes and adds new nodes one at a time. Each new node is connected to `m` existing nodes with a probability that depends on the number of links that the existing nodes already have.
# - **Key Parameters:**
#   - `n`: Total number of nodes
#   - `m`: Number of edges to attach from a new node to existing nodes
#
# ### Random Regular Network
# - **Type:** Regular graph
# - **Known For:** Every node has the same number of connections. This uniformity can represent idealized conditions in network modeling.
# - **Formation:** Constructed by connecting each node with `d` neighbors chosen at random, ensuring each has the same degree, while avoiding self-loops and duplicate edges.
# - **Key Parameters:**
#   - `n`: Total number of nodes
#   - `d`: Degree of each node
#
# ### Holme-Kim Network
# - **Type:** Small-world network with scale-free properties
# - **Known For:** Combines high clustering and short path lengths (like Watts-Strogatz) with a degree distribution that follows a power law (like Barabasi-Albert).
# - **Formation:** Starts like the Barabasi-Albert model by adding one node at a time, connecting to `m` existing nodes based on their degree. After each edge creation, with probability `p` adds an additional edge forming a triangle.
# - **Key Parameters:**
#   - `n`: Total number of nodes
#   - `m`: Number of edges each new node will attempt to make
#   - `p`: Triad formation probability

# %% [markdown]
# ## Global Sensitivity Analysis
#
# Sobol indices
#
# Saltelli sampling
#
# Pick key parameters (e.g. alpha, beta, rewiring probability) and key measures (true price adoption rate...)

# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

network_problems = {
    'Watts-Strogatz': {
        'num_vars': 7,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'min_increase_percentage','max_increase_percentage', 'k', 'p'],
        'bounds': [[0, 1], [0, 1], [0, 1],  [1,10], [11,20], [2, 10], [0, 1]] 
    },
    'Barabasi-Albert': {
        'num_vars': 6,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold','min_increase_percentage', 'max_increase_percentage', 'm'],
        'bounds': [[0, 1], [0, 1], [0, 1], [1,10], [11,20],[2, 10]]  
    },
    'Random Regular': {
        'num_vars': 6,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold','min_increase_percentage','max_increase_percentage','d'],
        'bounds': [[0, 1], [0, 1], [0, 1], [1,10], [11,20],[2, 10]]  
    },
    'Holme-Kim': {
        'num_vars': 7,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'min_increase_percentage','max_increase_percentage','m', 'p'],
        'bounds': [[0, 1], [0, 1], [0, 1],[1,10], [11,20],[2, 10], [0, 1]] 
    }
}

# %%
num_samples = 256

samples = {}
for network_name, problem in network_problems.items():
    samples[network_name] = saltelli.sample(problem, num_samples)
# Out:
# /var/folders/53/cl5y6r2x7n5_942j6h59yyh00000gn/T/ipykernel_2264/3049819496.py:7: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5. Please use `salib.sample.sobol`
#   samples[network_name] = saltelli.sample(problem, num_samples)

# %%
from joblib import Parallel, delayed
import numpy as np
import pandas as pd
from tqdm import tqdm
from SALib.sample import saltelli
from SALib.analyze import sobol
import json

def collect_simulation_data(model, num_steps):
    collected_data = {
        'Step': [],
        'Adoption Rate': [],
        'Avg_F_Satisfaction': [],
        'Avg_S_Satisfaction': [],
        'Avg_P_Satisfaction': [],
        'Avg_F_Uncertainty': [],
        'Avg_S_Uncertainty': [],
        'Avg_P_Uncertainty': []
    }

    for step in range(num_steps):
        model.step()
        collected_data['Step'].append(step)
        collected_data['Adoption Rate'].append(model.calculate_true_price_adoption_rate())
        collected_data['Avg_F_Satisfaction'].append(np.mean([agent.F_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_S_Satisfaction'].append(np.mean([agent.S_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_P_Satisfaction'].append(np.mean([agent.P_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_F_Uncertainty'].append(np.mean([agent.F_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_S_Uncertainty'].append(np.mean([agent.S_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_P_Uncertainty'].append(np.mean([agent.P_uncertainty for agent in model.schedule.agents]))

    model_data = pd.DataFrame(collected_data)
    return model_data

def run_single_simulation(params, config, network_name, num_steps):
    config = config.copy()
    config['TP_percentage'] = params[0]
    config['satisfaction_threshold'] = params[1]
    config['uncertainty_threshold'] = params[2]
    config['min_increase_percentage'] = params[3]
    config['max_increase_percentage'] = params[4]


    if network_name == 'Watts-Strogatz':
        config['network_params']['k'] = int(params[5])
        config['network_params']['p'] = params[6]
    elif network_name == 'Barabasi-Albert':
        config['network_params']['m'] = int(params[5])
    elif network_name == 'Random Regular':
        config['network_params']['d'] = int(params[5])
    elif network_name == 'Holme-Kim':
        config['network_params']['m'] = int(params[5])
        config['network_params']['p'] = params[6]

    model = ConsumatModel(config)
    model_data = collect_simulation_data(model, num_steps)
    final_step_data = model_data.iloc[-1]

    return [
        final_step_data['Adoption Rate'],
        final_step_data['Avg_F_Satisfaction'],
        final_step_data['Avg_S_Satisfaction'],
        final_step_data['Avg_P_Satisfaction'],
        final_step_data['Avg_F_Uncertainty'],
        final_step_data['Avg_S_Uncertainty'],
        final_step_data['Avg_P_Uncertainty']
    ]

def run_gsa_simulation_parallel(network_name, config, samples, num_steps, n_jobs=-1):
    all_results = Parallel(n_jobs=n_jobs)(
        delayed(run_single_simulation)(params, config, network_name, num_steps)
        for params in tqdm(samples, desc=f'Running simulations for {network_name}')
    )
    return np.array(all_results)

num_steps = 10

for network_name, config in network_configurations.items():
    print(f"Running GSA for {network_name} network...")
    config = base_config.copy()  
    config.update(network_configurations[network_name])
    all_results = run_gsa_simulation_parallel(network_name, config, samples[network_name], num_steps)
    
    results = {}
    
    for i, output in enumerate(['Adoption Rate', 'Avg_F_Satisfaction', 'Avg_S_Satisfaction', 'Avg_P_Satisfaction', 'Avg_F_Uncertainty', 'Avg_S_Uncertainty', 'Avg_P_Uncertainty']):
        Si = sobol.analyze(network_problems[network_name], all_results[:, i], print_to_console=True)
        results[output] = {
            'S1': Si['S1'].tolist(),
            'ST': Si['ST'].tolist(),
            'S1_conf': Si['S1_conf'].tolist(),
            'ST_conf': Si['ST_conf'].tolist()
        }
        print(f'Sensitivity analysis for {output} ({network_name} network):')
        print(Si)
    
    with open(f'nohomphily_new_sensitivity_results_{network_name}.json', 'w') as f:
        json.dump(results, f)
# Out:
# Running GSA for Watts-Strogatz network...
# Running simulations for Watts-Strogatz: 100%|██████████| 4096/4096 [2:34:13<00:00,  2.26s/it]
#                                ST   ST_conf
# TP_percentage            1.017158  0.147250
# satisfaction_threshold   0.223661  0.082378
# uncertainty_threshold    0.201194  0.074459
# min_increase_percentage  0.193815  0.073759
# max_increase_percentage  0.139026  0.073992
# k                        0.202957  0.083096
# p                        0.160992  0.065680
#                                S1   S1_conf
# TP_percentage            0.809443  0.155964
# satisfaction_threshold   0.054961  0.091045
# uncertainty_threshold    0.001268  0.080288
# min_increase_percentage  0.014665  0.071576
# max_increase_percentage  0.058509  0.068831
# k                        0.058704  0.084813
# p                        0.046219  0.071037
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.159487  0.169416
# (TP_percentage, uncertainty_threshold)             -0.057897  0.134614
# (TP_percentage, min_increase_percentage)           -0.069063  0.137054
# (TP_percentage, max_increase_percentage)           -0.108160  0.139621
# (TP_percentage, k)                                 -0.146002  0.157259
# (TP_percentage, p)                                 -0.112010  0.132919
# (satisfaction_threshold, uncertainty_threshold)    -0.122523  0.116151
# (satisfaction_threshold, min_increase_percentage)  -0.097174  0.108793
# (satisfaction_threshold, max_increase_percentage)  -0.102552  0.118728
# (satisfaction_threshold, k)                        -0.054314  0.121610
# (satisfaction_threshold, p)                        -0.101410  0.119534
# (uncertainty_threshold, min_increase_percentage)    0.042529  0.105165
# (uncertainty_threshold, max_increase_percentage)    0.011555  0.107577
# (uncertainty_threshold, k)                          0.017293  0.122425
# (uncertainty_threshold, p)                          0.041042  0.105235
# (min_increase_percentage, max_increase_percentage) -0.017329  0.101917
# (min_increase_percentage, k)                       -0.004086  0.111970
# (min_increase_percentage, p)                       -0.011706  0.104832
# (max_increase_percentage, k)                       -0.076612  0.100488
# (max_increase_percentage, p)                       -0.088916  0.093143
# (k, p)                                             -0.112481  0.085099
# Sensitivity analysis for Adoption Rate (Watts-Strogatz network):
# {'S1': array([0.80944253, 0.05496096, 0.00126781, 0.01466498, 0.05850883,
#        0.05870411, 0.0462189 ]), 'S1_conf': array([0.15596359, 0.0910446 , 0.08028772, 0.0715756 , 0.06883106,
#        0.08481259, 0.07103695]), 'ST': array([1.01715845, 0.22366132, 0.20119448, 0.19381516, 0.13902605,
#        0.20295652, 0.16099235]), 'ST_conf': array([0.14724952, 0.08237814, 0.07445889, 0.0737588 , 0.07399248,
#        0.08309648, 0.06568042]), 'S2': array([[        nan, -0.15948676, -0.05789693, -0.06906269, -0.10816047,
#         -0.14600161, -0.11200961],
#        [        nan,         nan, -0.12252315, -0.09717381, -0.1025517 ,
#         -0.05431353, -0.10141042],
#        [        nan,         nan,         nan,  0.04252947,  0.01155477,
#          0.01729294,  0.04104237],
#        [        nan,         nan,         nan,         nan, -0.01732861,
#         -0.00408611, -0.01170618],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.07661155, -0.0889157 ],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.11248146],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.16941577, 0.13461386, 0.13705355, 0.13962143,
#         0.15725883, 0.13291915],
#        [       nan,        nan, 0.11615091, 0.1087933 , 0.11872845,
#         0.12161002, 0.11953373],
#        [       nan,        nan,        nan, 0.10516541, 0.1075767 ,
#         0.12242524, 0.1052345 ],
#        [       nan,        nan,        nan,        nan, 0.10191652,
#         0.11196985, 0.10483239],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.10048845, 0.09314316],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.08509942],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.389997  0.129857
# satisfaction_threshold   0.650922  0.176548
# uncertainty_threshold    0.768790  0.203310
# min_increase_percentage  0.200319  0.111318
# max_increase_percentage  0.248079  0.129733
# k                        0.374971  0.146351
# p                        0.406796  0.251360
#                                S1   S1_conf
# TP_percentage            0.132153  0.184345
# satisfaction_threshold   0.278807  0.135437
# uncertainty_threshold    0.342558  0.136493
# min_increase_percentage  0.020099  0.059645
# max_increase_percentage  0.036409  0.071864
# k                        0.101075  0.129481
# p                        0.047460  0.109985
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.022925  0.201260
# (TP_percentage, uncertainty_threshold)             -0.135845  0.281276
# (TP_percentage, min_increase_percentage)            0.029494  0.217543
# (TP_percentage, max_increase_percentage)           -0.074813  0.221609
# (TP_percentage, k)                                 -0.056645  0.267946
# (TP_percentage, p)                                 -0.005738  0.221399
# (satisfaction_threshold, uncertainty_threshold)     0.021564  0.196966
# (satisfaction_threshold, min_increase_percentage)   0.029137  0.165961
# (satisfaction_threshold, max_increase_percentage)   0.009149  0.160928
# (satisfaction_threshold, k)                        -0.035494  0.193919
# (satisfaction_threshold, p)                         0.033495  0.181785
# (uncertainty_threshold, min_increase_percentage)   -0.016057  0.171474
# (uncertainty_threshold, max_increase_percentage)   -0.037105  0.185925
# (uncertainty_threshold, k)                         -0.020471  0.215867
# (uncertainty_threshold, p)                          0.194552  0.348887
# (min_increase_percentage, max_increase_percentage) -0.009721  0.102322
# (min_increase_percentage, k)                        0.068865  0.156880
# (min_increase_percentage, p)                        0.020184  0.085133
# (max_increase_percentage, k)                       -0.004376  0.145362
# (max_increase_percentage, p)                        0.060115  0.117122
# (k, p)                                             -0.044783  0.152917
# Sensitivity analysis for Avg_F_Satisfaction (Watts-Strogatz network):
# {'S1': array([0.13215305, 0.2788069 , 0.34255834, 0.02009879, 0.03640924,
#        0.1010747 , 0.0474602 ]), 'S1_conf': array([0.18434549, 0.13543651, 0.13649281, 0.05964492, 0.07186405,
#        0.12948077, 0.10998475]), 'ST': array([0.38999739, 0.65092207, 0.76878955, 0.20031875, 0.24807855,
#        0.3749708 , 0.4067957 ]), 'ST_conf': array([0.12985723, 0.17654821, 0.20331029, 0.11131806, 0.12973304,
#        0.14635079, 0.2513601 ]), 'S2': array([[        nan, -0.02292503, -0.13584525,  0.02949377, -0.07481323,
#         -0.05664482, -0.00573765],
#        [        nan,         nan,  0.0215645 ,  0.02913734,  0.00914899,
#         -0.03549377,  0.03349525],
#        [        nan,         nan,         nan, -0.01605671, -0.03710537,
#         -0.02047122,  0.19455222],
#        [        nan,         nan,         nan,         nan, -0.00972091,
#          0.0688653 ,  0.02018405],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.00437566,  0.06011499],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.04478289],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.2012601 , 0.28127555, 0.21754301, 0.2216085 ,
#         0.26794647, 0.22139853],
#        [       nan,        nan, 0.19696605, 0.16596117, 0.16092752,
#         0.19391904, 0.18178451],
#        [       nan,        nan,        nan, 0.17147428, 0.18592451,
#         0.21586692, 0.34888739],
#        [       nan,        nan,        nan,        nan, 0.10232219,
#         0.15687987, 0.08513262],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.14536169, 0.11712234],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.15291715],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.164139  0.059900
# satisfaction_threshold   0.219168  0.059913
# uncertainty_threshold    0.149666  0.056991
# min_increase_percentage  0.023951  0.020792
# max_increase_percentage  0.023012  0.021836
# k                        0.587707  0.126737
# p                        0.310575  0.088179
#                                S1   S1_conf
# TP_percentage            0.077448  0.071179
# satisfaction_threshold   0.175137  0.097116
# uncertainty_threshold    0.022915  0.058659
# min_increase_percentage  0.002398  0.023000
# max_increase_percentage  0.001506  0.022476
# k                        0.416804  0.154748
# p                        0.135949  0.084553
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.028580  0.111501
# (TP_percentage, uncertainty_threshold)              0.006584  0.103155
# (TP_percentage, min_increase_percentage)           -0.022201  0.102175
# (TP_percentage, max_increase_percentage)           -0.015149  0.101231
# (TP_percentage, k)                                 -0.055482  0.101727
# (TP_percentage, p)                                  0.004040  0.104031
# (satisfaction_threshold, uncertainty_threshold)    -0.008783  0.129908
# (satisfaction_threshold, min_increase_percentage)  -0.066146  0.119018
# (satisfaction_threshold, max_increase_percentage)  -0.065095  0.118290
# (satisfaction_threshold, k)                        -0.128946  0.129624
# (satisfaction_threshold, p)                        -0.074724  0.119170
# (uncertainty_threshold, min_increase_percentage)   -0.028688  0.085390
# (uncertainty_threshold, max_increase_percentage)   -0.030281  0.083078
# (uncertainty_threshold, k)                          0.000833  0.089536
# (uncertainty_threshold, p)                         -0.008550  0.080937
# (min_increase_percentage, max_increase_percentage) -0.003496  0.033168
# (min_increase_percentage, k)                       -0.022210  0.033014
# (min_increase_percentage, p)                       -0.009432  0.032492
# (max_increase_percentage, k)                       -0.023530  0.036397
# (max_increase_percentage, p)                       -0.011372  0.040166
# (k, p)                                              0.124175  0.202341
# Sensitivity analysis for Avg_S_Satisfaction (Watts-Strogatz network):
# {'S1': array([0.07744754, 0.17513739, 0.02291513, 0.00239836, 0.00150605,
#        0.41680447, 0.13594851]), 'S1_conf': array([0.07117868, 0.09711579, 0.05865902, 0.02300011, 0.0224762 ,
#        0.1547475 , 0.08455318]), 'ST': array([0.16413949, 0.21916771, 0.14966642, 0.02395069, 0.02301246,
#        0.58770745, 0.31057453]), 'ST_conf': array([0.05990039, 0.05991342, 0.05699086, 0.02079221, 0.02183566,
#        0.12673659, 0.08817937]), 'S2': array([[        nan, -0.02857981,  0.00658355, -0.02220056, -0.01514932,
#         -0.05548196,  0.00404018],
#        [        nan,         nan, -0.00878252, -0.06614579, -0.06509484,
#         -0.12894594, -0.0747239 ],
#        [        nan,         nan,         nan, -0.02868827, -0.03028112,
#          0.00083278, -0.00855049],
#        [        nan,         nan,         nan,         nan, -0.00349573,
#         -0.02221015, -0.00943192],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.02352954, -0.01137162],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.12417537],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.11150064, 0.10315475, 0.10217497, 0.10123145,
#         0.10172676, 0.10403067],
#        [       nan,        nan, 0.12990844, 0.1190177 , 0.11828977,
#         0.12962401, 0.11917004],
#        [       nan,        nan,        nan, 0.08539023, 0.08307763,
#         0.08953562, 0.08093734],
#        [       nan,        nan,        nan,        nan, 0.03316764,
#         0.03301359, 0.03249208],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.03639688, 0.04016604],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.2023413 ],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.316305  0.104514
# satisfaction_threshold   0.901966  0.141396
# uncertainty_threshold    0.617776  0.149061
# min_increase_percentage  0.236180  0.091544
# max_increase_percentage  0.276316  0.099593
# k                        0.343621  0.102831
# p                        0.346711  0.117594
#                                S1   S1_conf
# TP_percentage           -0.032978  0.102884
# satisfaction_threshold   0.247518  0.158671
# uncertainty_threshold    0.006142  0.149270
# min_increase_percentage -0.046459  0.074093
# max_increase_percentage -0.091049  0.093310
# k                       -0.073802  0.092547
# p                       -0.070953  0.087269
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.026856  0.135029
# (TP_percentage, uncertainty_threshold)              0.037639  0.146381
# (TP_percentage, min_increase_percentage)            0.076933  0.141051
# (TP_percentage, max_increase_percentage)            0.036731  0.130997
# (TP_percentage, k)                                  0.038416  0.131111
# (TP_percentage, p)                                  0.004396  0.164880
# (satisfaction_threshold, uncertainty_threshold)     0.286329  0.196561
# (satisfaction_threshold, min_increase_percentage)   0.001888  0.184470
# (satisfaction_threshold, max_increase_percentage)   0.072236  0.188510
# (satisfaction_threshold, k)                         0.057412  0.187709
# (satisfaction_threshold, p)                         0.059769  0.175134
# (uncertainty_threshold, min_increase_percentage)   -0.009776  0.182322
# (uncertainty_threshold, max_increase_percentage)    0.029692  0.183014
# (uncertainty_threshold, k)                          0.049701  0.192087
# (uncertainty_threshold, p)                          0.036726  0.204024
# (min_increase_percentage, max_increase_percentage)  0.091680  0.139666
# (min_increase_percentage, k)                        0.076699  0.139086
# (min_increase_percentage, p)                        0.041964  0.148615
# (max_increase_percentage, k)                        0.066380  0.142904
# (max_increase_percentage, p)                        0.043229  0.152808
# (k, p)                                              0.058824  0.162739
# Sensitivity analysis for Avg_P_Satisfaction (Watts-Strogatz network):
# {'S1': array([-0.03297831,  0.24751847,  0.00614185, -0.04645943, -0.09104851,
#        -0.07380189, -0.07095271]), 'S1_conf': array([0.10288431, 0.15867071, 0.14927017, 0.07409319, 0.0933098 ,
#        0.09254734, 0.08726894]), 'ST': array([0.31630523, 0.90196557, 0.6177757 , 0.23617992, 0.27631554,
#        0.34362101, 0.34671087]), 'ST_conf': array([0.10451442, 0.14139626, 0.14906075, 0.09154356, 0.09959294,
#        0.10283072, 0.11759372]), 'S2': array([[        nan,  0.02685623,  0.03763905,  0.07693301,  0.03673083,
#          0.03841641,  0.00439561],
#        [        nan,         nan,  0.28632892,  0.00188751,  0.07223576,
#          0.05741191,  0.05976946],
#        [        nan,         nan,         nan, -0.00977633,  0.02969194,
#          0.04970063,  0.03672571],
#        [        nan,         nan,         nan,         nan,  0.09168025,
#          0.07669947,  0.04196398],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.06638019,  0.04322915],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.05882435],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.13502856, 0.14638125, 0.14105067, 0.13099702,
#         0.13111097, 0.16487978],
#        [       nan,        nan, 0.19656062, 0.18446986, 0.18851039,
#         0.18770851, 0.17513426],
#        [       nan,        nan,        nan, 0.1823216 , 0.18301429,
#         0.19208694, 0.20402441],
#        [       nan,        nan,        nan,        nan, 0.13966625,
#         0.1390861 , 0.14861529],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.1429039 , 0.15280789],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.16273896],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            1.020938  0.279646
# satisfaction_threshold   0.781701  0.235285
# uncertainty_threshold    0.683951  0.191495
# min_increase_percentage  0.465381  0.223370
# max_increase_percentage  0.530751  0.239475
# k                        0.657502  0.195469
# p                        0.831232  0.369593
#                                S1   S1_conf
# TP_percentage            0.227208  0.215086
# satisfaction_threshold  -0.066437  0.140686
# uncertainty_threshold   -0.008501  0.180408
# min_increase_percentage -0.017545  0.095874
# max_increase_percentage -0.059477  0.087179
# k                       -0.051977  0.170233
# p                        0.015187  0.136910
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.252183  0.386918
# (TP_percentage, uncertainty_threshold)             -0.172024  0.323368
# (TP_percentage, min_increase_percentage)            0.112066  0.244409
# (TP_percentage, max_increase_percentage)            0.057572  0.215699
# (TP_percentage, k)                                  0.124126  0.271218
# (TP_percentage, p)                                  0.001985  0.273264
# (satisfaction_threshold, uncertainty_threshold)     0.092584  0.249391
# (satisfaction_threshold, min_increase_percentage)   0.199676  0.132377
# (satisfaction_threshold, max_increase_percentage)   0.122903  0.153170
# (satisfaction_threshold, k)                         0.159764  0.264319
# (satisfaction_threshold, p)                         0.300972  0.172052
# (uncertainty_threshold, min_increase_percentage)    0.081135  0.239357
# (uncertainty_threshold, max_increase_percentage)   -0.013600  0.274775
# (uncertainty_threshold, k)                          0.255632  0.251816
# (uncertainty_threshold, p)                          0.078423  0.346620
# (min_increase_percentage, max_increase_percentage) -0.013066  0.119874
# (min_increase_percentage, k)                        0.233697  0.258765
# (min_increase_percentage, p)                        0.033851  0.141076
# (max_increase_percentage, k)                        0.020070  0.210257
# (max_increase_percentage, p)                        0.020975  0.181095
# (k, p)                                              0.040287  0.240209
# Sensitivity analysis for Avg_F_Uncertainty (Watts-Strogatz network):
# {'S1': array([ 0.227208  , -0.06643688, -0.0085014 , -0.01754484, -0.05947699,
#        -0.05197679,  0.01518657]), 'S1_conf': array([0.21508628, 0.14068592, 0.18040808, 0.0958735 , 0.0871788 ,
#        0.17023323, 0.13691012]), 'ST': array([1.02093796, 0.78170112, 0.68395074, 0.46538063, 0.53075127,
#        0.65750178, 0.8312321 ]), 'ST_conf': array([0.2796462 , 0.23528461, 0.1914947 , 0.22337002, 0.23947535,
#        0.195469  , 0.36959303]), 'S2': array([[        nan,  0.25218263, -0.17202377,  0.11206616,  0.05757249,
#          0.12412582,  0.00198487],
#        [        nan,         nan,  0.0925838 ,  0.19967567,  0.12290315,
#          0.15976387,  0.30097168],
#        [        nan,         nan,         nan,  0.08113495, -0.01359967,
#          0.25563153,  0.07842259],
#        [        nan,         nan,         nan,         nan, -0.0130657 ,
#          0.23369661,  0.03385123],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.02006956,  0.02097456],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.04028676],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.38691755, 0.32336828, 0.24440895, 0.21569893,
#         0.27121793, 0.27326397],
#        [       nan,        nan, 0.24939091, 0.13237703, 0.15317024,
#         0.26431876, 0.172052  ],
#        [       nan,        nan,        nan, 0.23935678, 0.27477494,
#         0.25181554, 0.34661994],
#        [       nan,        nan,        nan,        nan, 0.11987378,
#         0.25876491, 0.14107601],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.21025677, 0.18109486],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.24020892],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            1.002226  0.146872
# satisfaction_threshold   0.362619  0.121950
# uncertainty_threshold    0.353702  0.117967
# min_increase_percentage  0.334985  0.129274
# max_increase_percentage  0.242640  0.112051
# k                        0.359207  0.133760
# p                        0.351470  0.117218
#                                S1   S1_conf
# TP_percentage            0.628303  0.152552
# satisfaction_threshold   0.083115  0.108438
# uncertainty_threshold    0.042134  0.098866
# min_increase_percentage  0.003086  0.102457
# max_increase_percentage  0.054859  0.093229
# k                        0.089006  0.114422
# p                        0.089054  0.105602
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.186493  0.206040
# (TP_percentage, uncertainty_threshold)             -0.076915  0.158655
# (TP_percentage, min_increase_percentage)           -0.027393  0.182027
# (TP_percentage, max_increase_percentage)           -0.086391  0.194369
# (TP_percentage, k)                                 -0.167013  0.205707
# (TP_percentage, p)                                 -0.145162  0.164757
# (satisfaction_threshold, uncertainty_threshold)    -0.148109  0.159074
# (satisfaction_threshold, min_increase_percentage)  -0.130472  0.142935
# (satisfaction_threshold, max_increase_percentage)  -0.104655  0.145570
# (satisfaction_threshold, k)                        -0.091945  0.161684
# (satisfaction_threshold, p)                        -0.115600  0.150217
# (uncertainty_threshold, min_increase_percentage)    0.058914  0.155383
# (uncertainty_threshold, max_increase_percentage)    0.000617  0.139908
# (uncertainty_threshold, k)                          0.036846  0.154107
# (uncertainty_threshold, p)                          0.075026  0.140318
# (min_increase_percentage, max_increase_percentage) -0.009771  0.128710
# (min_increase_percentage, k)                        0.000961  0.133127
# (min_increase_percentage, p)                       -0.007468  0.136033
# (max_increase_percentage, k)                       -0.098960  0.118599
# (max_increase_percentage, p)                       -0.110647  0.123239
# (k, p)                                             -0.150627  0.137077
# Sensitivity analysis for Avg_S_Uncertainty (Watts-Strogatz network):
# {'S1': array([0.62830336, 0.08311516, 0.04213446, 0.00308618, 0.05485863,
#        0.08900625, 0.08905361]), 'S1_conf': array([0.15255186, 0.10843821, 0.09886596, 0.10245713, 0.09322857,
#        0.11442157, 0.10560213]), 'ST': array([1.00222638, 0.36261937, 0.35370229, 0.33498528, 0.24263966,
#        0.35920703, 0.35147016]), 'ST_conf': array([0.14687244, 0.12194973, 0.11796745, 0.12927419, 0.11205053,
#        0.13375985, 0.11721798]), 'S2': array([[        nan, -0.18649346, -0.07691477, -0.02739323, -0.08639093,
#         -0.16701319, -0.14516213],
#        [        nan,         nan, -0.14810933, -0.13047198, -0.1046548 ,
#         -0.09194494, -0.11560021],
#        [        nan,         nan,         nan,  0.05891399,  0.00061672,
#          0.03684557,  0.07502591],
#        [        nan,         nan,         nan,         nan, -0.00977059,
#          0.00096139, -0.00746776],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.09895972, -0.11064687],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.15062724],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.20603969, 0.15865543, 0.18202678, 0.19436923,
#         0.2057065 , 0.16475723],
#        [       nan,        nan, 0.15907447, 0.14293518, 0.14556965,
#         0.16168352, 0.15021683],
#        [       nan,        nan,        nan, 0.15538328, 0.1399078 ,
#         0.15410668, 0.14031839],
#        [       nan,        nan,        nan,        nan, 0.12870997,
#         0.13312673, 0.13603293],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.11859941, 0.12323917],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.13707679],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.549174  0.236058
# satisfaction_threshold   0.696362  0.216592
# uncertainty_threshold    0.712127  0.146910
# min_increase_percentage  0.455141  0.186764
# max_increase_percentage  0.431341  0.207441
# k                        0.574182  0.240447
# p                        0.423287  0.164898
#                                S1   S1_conf
# TP_percentage            0.104769  0.141540
# satisfaction_threshold   0.036802  0.162640
# uncertainty_threshold    0.350711  0.149891
# min_increase_percentage  0.094986  0.122751
# max_increase_percentage  0.036127  0.085599
# k                        0.134391  0.136364
# p                        0.068412  0.118373
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.031027  0.229170
# (TP_percentage, uncertainty_threshold)             -0.114194  0.179994
# (TP_percentage, min_increase_percentage)           -0.159436  0.180805
# (TP_percentage, max_increase_percentage)           -0.116354  0.153294
# (TP_percentage, k)                                 -0.207690  0.178388
# (TP_percentage, p)                                 -0.141004  0.200349
# (satisfaction_threshold, uncertainty_threshold)     0.035821  0.223702
# (satisfaction_threshold, min_increase_percentage)   0.028951  0.178297
# (satisfaction_threshold, max_increase_percentage)   0.065386  0.174053
# (satisfaction_threshold, k)                         0.040536  0.203592
# (satisfaction_threshold, p)                         0.063774  0.178657
# (uncertainty_threshold, min_increase_percentage)   -0.164670  0.234764
# (uncertainty_threshold, max_increase_percentage)   -0.077236  0.231677
# (uncertainty_threshold, k)                         -0.043095  0.250590
# (uncertainty_threshold, p)                         -0.051215  0.218111
# (min_increase_percentage, max_increase_percentage) -0.046191  0.155708
# (min_increase_percentage, k)                       -0.142645  0.282855
# (min_increase_percentage, p)                       -0.084736  0.227703
# (max_increase_percentage, k)                       -0.093603  0.191250
# (max_increase_percentage, p)                       -0.058281  0.149789
# (k, p)                                             -0.099824  0.255166
# Sensitivity analysis for Avg_P_Uncertainty (Watts-Strogatz network):
# {'S1': array([0.10476921, 0.03680213, 0.35071133, 0.09498629, 0.03612668,
#        0.13439063, 0.06841206]), 'S1_conf': array([0.14154035, 0.16264011, 0.14989064, 0.1227513 , 0.08559879,
#        0.13636391, 0.11837256]), 'ST': array([0.54917393, 0.69636161, 0.71212664, 0.45514112, 0.43134108,
#        0.57418189, 0.42328692]), 'ST_conf': array([0.23605773, 0.21659235, 0.1469096 , 0.18676433, 0.20744102,
#        0.24044717, 0.16489816]), 'S2': array([[        nan, -0.03102746, -0.11419351, -0.15943618, -0.11635392,
#         -0.20769003, -0.14100443],
#        [        nan,         nan,  0.03582082,  0.02895092,  0.06538562,
#          0.04053558,  0.06377402],
#        [        nan,         nan,         nan, -0.16467011, -0.07723578,
#         -0.0430947 , -0.05121506],
#        [        nan,         nan,         nan,         nan, -0.04619086,
#         -0.14264516, -0.08473583],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.09360304, -0.05828137],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.09982435],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.22916973, 0.17999383, 0.1808048 , 0.15329435,
#         0.1783882 , 0.20034886],
#        [       nan,        nan, 0.2237023 , 0.17829729, 0.17405321,
#         0.20359206, 0.17865673],
#        [       nan,        nan,        nan, 0.23476448, 0.23167662,
#         0.25058968, 0.2181112 ],
#        [       nan,        nan,        nan,        nan, 0.15570795,
#         0.28285463, 0.2277027 ],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.1912501 , 0.14978855],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.25516594],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
# Running GSA for Barabasi-Albert network...
# Running simulations for Barabasi-Albert: 100%|██████████| 3584/3584 [7:31:09<00:00,  7.55s/it]
#                                ST   ST_conf
# TP_percentage            0.830005  0.128456
# satisfaction_threshold   0.243946  0.076442
# uncertainty_threshold    0.385198  0.106221
# min_increase_percentage  0.132169  0.080425
# max_increase_percentage  0.119769  0.063504
# m                        0.163561  0.073316
#                                S1   S1_conf
# TP_percentage            0.536010  0.150413
# satisfaction_threshold  -0.009299  0.077438
# uncertainty_threshold    0.063167  0.112518
# min_increase_percentage -0.039232  0.055734
# max_increase_percentage -0.014504  0.053730
# m                       -0.024590  0.066617
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.105226  0.168150
# (TP_percentage, uncertainty_threshold)              0.125955  0.169616
# (TP_percentage, min_increase_percentage)            0.019987  0.166788
# (TP_percentage, max_increase_percentage)            0.028541  0.147824
# (TP_percentage, m)                                  0.047418  0.143885
# (satisfaction_threshold, uncertainty_threshold)     0.026952  0.113258
# (satisfaction_threshold, min_increase_percentage)   0.021108  0.126217
# (satisfaction_threshold, max_increase_percentage)   0.030534  0.123745
# (satisfaction_threshold, m)                        -0.019206  0.118985
# (uncertainty_threshold, min_increase_percentage)   -0.012863  0.130084
# (uncertainty_threshold, max_increase_percentage)   -0.033614  0.118206
# (uncertainty_threshold, m)                          0.009047  0.123705
# (min_increase_percentage, max_increase_percentage)  0.074061  0.097151
# (min_increase_percentage, m)                        0.039528  0.098812
# (max_increase_percentage, m)                        0.030860  0.072370
# Sensitivity analysis for Adoption Rate (Barabasi-Albert network):
# {'S1': array([ 0.53600955, -0.00929873,  0.06316652, -0.03923192, -0.01450377,
#        -0.02459018]), 'S1_conf': array([0.15041325, 0.07743776, 0.11251827, 0.05573415, 0.05373037,
#        0.06661729]), 'ST': array([0.83000526, 0.2439459 , 0.38519793, 0.13216851, 0.1197692 ,
#        0.16356077]), 'ST_conf': array([0.12845649, 0.07644235, 0.1062208 , 0.08042486, 0.06350432,
#        0.0733161 ]), 'S2': array([[        nan,  0.10522581,  0.12595475,  0.01998709,  0.02854051,
#          0.04741822],
#        [        nan,         nan,  0.02695221,  0.02110782,  0.03053417,
#         -0.01920637],
#        [        nan,         nan,         nan, -0.01286297, -0.0336143 ,
#          0.0090472 ],
#        [        nan,         nan,         nan,         nan,  0.07406094,
#          0.03952784],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.03086048],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan]]), 'S2_conf': array([[       nan, 0.1681505 , 0.16961571, 0.16678829, 0.14782395,
#         0.1438854 ],
#        [       nan,        nan, 0.11325841, 0.12621697, 0.12374547,
#         0.11898498],
#        [       nan,        nan,        nan, 0.130084  , 0.1182062 ,
#         0.12370467],
#        [       nan,        nan,        nan,        nan, 0.09715105,
#         0.09881213],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.07237012],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan]])}
#                                ST   ST_conf
# TP_percentage            0.241827  0.114264
# satisfaction_threshold   0.479031  0.103202
# uncertainty_threshold    0.762061  0.190438
# min_increase_percentage  0.162950  0.101676
# max_increase_percentage  0.161531  0.079894
# m                        0.153872  0.051346
#                                S1   S1_conf
# TP_percentage           -0.041547  0.074808
# satisfaction_threshold   0.150063  0.117324
# uncertainty_threshold    0.441971  0.142448
# min_increase_percentage -0.016917  0.067249
# max_increase_percentage  0.030588  0.065186
# m                        0.012813  0.057256
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.099318  0.106293
# (TP_percentage, uncertainty_threshold)              0.139968  0.139600
# (TP_percentage, min_increase_percentage)            0.098286  0.105169
# (TP_percentage, max_increase_percentage)            0.066184  0.113638
# (TP_percentage, m)                                  0.129180  0.135899
# (satisfaction_threshold, uncertainty_threshold)     0.082679  0.151995
# (satisfaction_threshold, min_increase_percentage)   0.006574  0.138851
# (satisfaction_threshold, max_increase_percentage)  -0.001060  0.155153
# (satisfaction_threshold, m)                        -0.012790  0.140315
# (uncertainty_threshold, min_increase_percentage)   -0.097673  0.151331
# (uncertainty_threshold, max_increase_percentage)   -0.159630  0.152590
# (uncertainty_threshold, m)                         -0.061168  0.149150
# (min_increase_percentage, max_increase_percentage)  0.016392  0.087978
# (min_increase_percentage, m)                        0.035464  0.091840
# (max_increase_percentage, m)                       -0.043774  0.095869
# Sensitivity analysis for Avg_F_Satisfaction (Barabasi-Albert network):
# {'S1': array([-0.04154659,  0.15006295,  0.44197081, -0.01691741,  0.0305885 ,
#         0.01281346]), 'S1_conf': array([0.07480827, 0.11732389, 0.14244769, 0.06724906, 0.06518603,
#        0.05725617]), 'ST': array([0.2418272 , 0.47903086, 0.76206125, 0.1629505 , 0.16153139,
#        0.15387158]), 'ST_conf': array([0.11426425, 0.10320202, 0.1904379 , 0.1016762 , 0.07989359,
#        0.0513461 ]), 'S2': array([[        nan,  0.0993184 ,  0.13996764,  0.09828624,  0.06618369,
#          0.12918046],
#        [        nan,         nan,  0.08267854,  0.00657372, -0.00105978,
#         -0.01278984],
#        [        nan,         nan,         nan, -0.09767272, -0.15962986,
#         -0.06116773],
#        [        nan,         nan,         nan,         nan,  0.01639174,
#          0.03546411],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.04377418],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan]]), 'S2_conf': array([[       nan, 0.10629326, 0.1396003 , 0.10516929, 0.11363757,
#         0.13589864],
#        [       nan,        nan, 0.15199474, 0.1388513 , 0.15515323,
#         0.14031456],
#        [       nan,        nan,        nan, 0.15133107, 0.15258977,
#         0.14915004],
#        [       nan,        nan,        nan,        nan, 0.08797787,
#         0.09183957],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.09586902],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan]])}
#                                ST   ST_conf
# TP_percentage            0.313820  0.115554
# satisfaction_threshold   0.487864  0.131994
# uncertainty_threshold    0.462169  0.137548
# min_increase_percentage  0.019482  0.016326
# max_increase_percentage  0.020816  0.018062
# m                        0.105225  0.049569
#                                S1   S1_conf
# TP_percentage            0.071311  0.087103
# satisfaction_threshold   0.131891  0.119086
# uncertainty_threshold    0.218500  0.137360
# min_increase_percentage -0.018415  0.025233
# max_increase_percentage -0.003042  0.035698
# m                       -0.071499  0.056737
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.015604  0.135130
# (TP_percentage, uncertainty_threshold)              0.072404  0.133846
# (TP_percentage, min_increase_percentage)            0.024555  0.114440
# (TP_percentage, max_increase_percentage)            0.027744  0.114197
# (TP_percentage, m)                                  0.061546  0.119410
# (satisfaction_threshold, uncertainty_threshold)     0.161344  0.221300
# (satisfaction_threshold, min_increase_percentage)   0.042822  0.198130
# (satisfaction_threshold, max_increase_percentage)   0.011937  0.200231
# (satisfaction_threshold, m)                         0.071193  0.203519
# (uncertainty_threshold, min_increase_percentage)   -0.056686  0.184837
# (uncertainty_threshold, max_increase_percentage)   -0.068400  0.185288
# (uncertainty_threshold, m)                          0.022870  0.186332
# (min_increase_percentage, max_increase_percentage)  0.010029  0.037495
# (min_increase_percentage, m)                        0.010736  0.037334
# (max_increase_percentage, m)                        0.008621  0.059126
# Sensitivity analysis for Avg_S_Satisfaction (Barabasi-Albert network):
# {'S1': array([ 0.07131146,  0.13189062,  0.21850002, -0.01841452, -0.00304176,
#        -0.07149899]), 'S1_conf': array([0.08710319, 0.11908629, 0.13736048, 0.02523261, 0.03569752,
#        0.05673731]), 'ST': array([0.3138199 , 0.48786367, 0.46216883, 0.0194822 , 0.02081646,
#        0.10522547]), 'ST_conf': array([0.11555403, 0.13199395, 0.13754763, 0.01632612, 0.01806233,
#        0.04956858]), 'S2': array([[        nan, -0.01560434,  0.07240363,  0.02455497,  0.02774351,
#          0.06154635],
#        [        nan,         nan,  0.16134374,  0.0428221 ,  0.01193723,
#          0.07119319],
#        [        nan,         nan,         nan, -0.05668592, -0.06840041,
#          0.02286963],
#        [        nan,         nan,         nan,         nan,  0.01002899,
#          0.01073624],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.00862123],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan]]), 'S2_conf': array([[       nan, 0.13513006, 0.1338456 , 0.11443953, 0.11419704,
#         0.11940971],
#        [       nan,        nan, 0.22130047, 0.1981304 , 0.20023088,
#         0.20351863],
#        [       nan,        nan,        nan, 0.18483681, 0.18528769,
#         0.18633181],
#        [       nan,        nan,        nan,        nan, 0.03749507,
#         0.03733352],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.05912628],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan]])}
#                                ST   ST_conf
# TP_percentage            0.144783  0.067418
# satisfaction_threshold   0.679686  0.139394
# uncertainty_threshold    0.716515  0.137302
# min_increase_percentage  0.168554  0.086522
# max_increase_percentage  0.112625  0.077254
# m                        0.235646  0.093496
#                                S1   S1_conf
# TP_percentage           -0.038937  0.073421
# satisfaction_threshold   0.293128  0.141131
# uncertainty_threshold    0.244459  0.139459
# min_increase_percentage  0.010781  0.076869
# max_increase_percentage -0.010364  0.070629
# m                       -0.023015  0.084683
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.106464  0.113318
# (TP_percentage, uncertainty_threshold)              0.112151  0.119840
# (TP_percentage, min_increase_percentage)            0.047626  0.109328
# (TP_percentage, max_increase_percentage)            0.032297  0.111522
# (TP_percentage, m)                                  0.035290  0.111812
# (satisfaction_threshold, uncertainty_threshold)     0.178554  0.202561
# (satisfaction_threshold, min_increase_percentage)  -0.035098  0.191148
# (satisfaction_threshold, max_increase_percentage)  -0.018674  0.193417
# (satisfaction_threshold, m)                        -0.012113  0.192200
# (uncertainty_threshold, min_increase_percentage)   -0.067723  0.143816
# (uncertainty_threshold, max_increase_percentage)   -0.001423  0.168145
# (uncertainty_threshold, m)                          0.027892  0.163484
# (min_increase_percentage, max_increase_percentage) -0.020925  0.096283
# (min_increase_percentage, m)                       -0.046012  0.095338
# (max_increase_percentage, m)                        0.009108  0.101249
# Sensitivity analysis for Avg_P_Satisfaction (Barabasi-Albert network):
# {'S1': array([-0.03893662,  0.29312798,  0.24445943,  0.01078078, -0.01036411,
#        -0.0230149 ]), 'S1_conf': array([0.07342075, 0.14113095, 0.13945877, 0.07686884, 0.0706286 ,
#        0.08468343]), 'ST': array([0.14478304, 0.67968601, 0.71651525, 0.16855448, 0.11262457,
#        0.2356461 ]), 'ST_conf': array([0.06741806, 0.13939375, 0.13730191, 0.08652171, 0.0772536 ,
#        0.093496  ]), 'S2': array([[        nan,  0.10646416,  0.11215067,  0.04762592,  0.0322971 ,
#          0.03529027],
#        [        nan,         nan,  0.17855365, -0.03509786, -0.0186735 ,
#         -0.01211276],
#        [        nan,         nan,         nan, -0.06772265, -0.00142336,
#          0.02789224],
#        [        nan,         nan,         nan,         nan, -0.02092463,
#         -0.04601168],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.00910816],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan]]), 'S2_conf': array([[       nan, 0.11331778, 0.11983957, 0.10932779, 0.11152191,
#         0.11181187],
#        [       nan,        nan, 0.20256108, 0.19114794, 0.19341672,
#         0.19219973],
#        [       nan,        nan,        nan, 0.14381569, 0.1681454 ,
#         0.16348439],
#        [       nan,        nan,        nan,        nan, 0.09628335,
#         0.09533809],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.10124937],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan]])}
#                                ST   ST_conf
# TP_percentage            0.372154  0.110896
# satisfaction_threshold   0.481462  0.135885
# uncertainty_threshold    0.848417  0.129916
# min_increase_percentage  0.383011  0.129507
# max_increase_percentage  0.373529  0.154298
# m                        0.484835  0.140924
#                                S1   S1_conf
# TP_percentage           -0.019951  0.099152
# satisfaction_threshold   0.034598  0.102085
# uncertainty_threshold    0.445546  0.164746
# min_increase_percentage -0.028120  0.119814
# max_increase_percentage  0.067334  0.119716
# m                        0.011540  0.124044
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.110873  0.159848
# (TP_percentage, uncertainty_threshold)              0.147904  0.169185
# (TP_percentage, min_increase_percentage)            0.126254  0.149321
# (TP_percentage, max_increase_percentage)            0.120409  0.162119
# (TP_percentage, m)                                  0.121577  0.171821
# (satisfaction_threshold, uncertainty_threshold)     0.011499  0.176962
# (satisfaction_threshold, min_increase_percentage)   0.101999  0.165485
# (satisfaction_threshold, max_increase_percentage)   0.020763  0.184350
# (satisfaction_threshold, m)                         0.131261  0.167609
# (uncertainty_threshold, min_increase_percentage)   -0.127672  0.193052
# (uncertainty_threshold, max_increase_percentage)   -0.203038  0.214956
# (uncertainty_threshold, m)                          0.075788  0.223579
# (min_increase_percentage, max_increase_percentage) -0.012190  0.161677
# (min_increase_percentage, m)                        0.017855  0.168730
# (max_increase_percentage, m)                       -0.070688  0.181172
# Sensitivity analysis for Avg_F_Uncertainty (Barabasi-Albert network):
# {'S1': array([-0.01995124,  0.03459785,  0.44554615, -0.0281197 ,  0.06733381,
#         0.01153953]), 'S1_conf': array([0.09915213, 0.10208523, 0.16474611, 0.11981397, 0.1197161 ,
#        0.124044  ]), 'ST': array([0.37215362, 0.4814623 , 0.84841711, 0.38301122, 0.37352905,
#        0.48483488]), 'ST_conf': array([0.11089593, 0.13588548, 0.12991605, 0.12950667, 0.15429762,
#        0.14092394]), 'S2': array([[        nan,  0.11087332,  0.14790429,  0.12625403,  0.12040942,
#          0.12157688],
#        [        nan,         nan,  0.01149889,  0.10199887,  0.02076309,
#          0.13126075],
#        [        nan,         nan,         nan, -0.12767226, -0.20303828,
#          0.07578822],
#        [        nan,         nan,         nan,         nan, -0.01219029,
#          0.01785547],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.07068812],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan]]), 'S2_conf': array([[       nan, 0.15984796, 0.16918463, 0.14932103, 0.1621189 ,
#         0.17182125],
#        [       nan,        nan, 0.17696183, 0.1654848 , 0.18434964,
#         0.16760909],
#        [       nan,        nan,        nan, 0.19305156, 0.21495582,
#         0.22357927],
#        [       nan,        nan,        nan,        nan, 0.16167675,
#         0.16872974],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.18117238],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan]])}
#                                ST   ST_conf
# TP_percentage            0.733110  0.116216
# satisfaction_threshold   0.286682  0.088678
# uncertainty_threshold    0.447162  0.117441
# min_increase_percentage  0.119844  0.060317
# max_increase_percentage  0.121707  0.063470
# m                        0.206648  0.087712
#                                S1   S1_conf
# TP_percentage            0.411798  0.145466
# satisfaction_threshold   0.019833  0.085710
# uncertainty_threshold    0.133832  0.117714
# min_increase_percentage -0.019557  0.068637
# max_increase_percentage  0.001004  0.066409
# m                       -0.029713  0.091130
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.094846  0.156689
# (TP_percentage, uncertainty_threshold)              0.139163  0.152302
# (TP_percentage, min_increase_percentage)            0.027052  0.159780
# (TP_percentage, max_increase_percentage)            0.060619  0.123149
# (TP_percentage, m)                                  0.081179  0.165600
# (satisfaction_threshold, uncertainty_threshold)     0.018519  0.121638
# (satisfaction_threshold, min_increase_percentage)   0.019485  0.128108
# ...
# (TP_percentage, m)                                 -0.057018  0.102854
# (TP_percentage, p)                                 -0.046052  0.096290
# (satisfaction_threshold, uncertainty_threshold)     0.278114  0.173460
# (satisfaction_threshold, min_increase_percentage)   0.086104  0.190036
# (satisfaction_threshold, max_increase_percentage)   0.143500  0.204405
# (satisfaction_threshold, m)                         0.082695  0.194172
# (satisfaction_threshold, p)                         0.107858  0.201277
# (uncertainty_threshold, min_increase_percentage)   -0.044195  0.140836
# (uncertainty_threshold, max_increase_percentage)   -0.022420  0.172490
# (uncertainty_threshold, m)                         -0.043763  0.143765
# (uncertainty_threshold, p)                          0.045719  0.176478
# (min_increase_percentage, max_increase_percentage) -0.000862  0.086545
# (min_increase_percentage, m)                       -0.028439  0.096804
# (min_increase_percentage, p)                        0.011115  0.085484
# (max_increase_percentage, m)                        0.062123  0.102313
# (max_increase_percentage, p)                        0.072040  0.093978
# (m, p)                                              0.051656  0.100323
# Sensitivity analysis for Avg_P_Satisfaction (Holme-Kim network):
# {'S1': array([ 0.02386949,  0.22530355,  0.34301009, -0.0124797 , -0.01234276,
#        -0.02601961, -0.03061204]), 'S1_conf': array([0.07834444, 0.13966262, 0.1394122 , 0.07057002, 0.07086331,
#        0.07904788, 0.07190036]), 'ST': array([0.16800413, 0.7320388 , 0.73530195, 0.12999317, 0.1805041 ,
#        0.21401034, 0.18909393]), 'ST_conf': array([0.05962331, 0.11907037, 0.14477414, 0.06728758, 0.08721852,
#        0.07889241, 0.08379084]), 'S2': array([[        nan, -0.00969377, -0.01871664, -0.03676474, -0.04685234,
#         -0.05701814, -0.04605224],
#        [        nan,         nan,  0.27811414,  0.08610369,  0.14350023,
#          0.08269538,  0.10785815],
#        [        nan,         nan,         nan, -0.04419488, -0.02242045,
#         -0.0437629 ,  0.04571865],
#        [        nan,         nan,         nan,         nan, -0.00086231,
#         -0.02843921,  0.01111483],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.06212313,  0.07203995],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.05165597],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.10674598, 0.11836607, 0.097311  , 0.09700864,
#         0.10285384, 0.09628987],
#        [       nan,        nan, 0.17346002, 0.19003601, 0.20440457,
#         0.1941717 , 0.20127743],
#        [       nan,        nan,        nan, 0.1408361 , 0.17248965,
#         0.14376454, 0.17647752],
#        [       nan,        nan,        nan,        nan, 0.08654483,
#         0.09680429, 0.08548359],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.10231274, 0.09397847],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.10032292],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.403611  0.115491
# satisfaction_threshold   0.610067  0.138687
# uncertainty_threshold    0.760655  0.132918
# min_increase_percentage  0.414502  0.137853
# max_increase_percentage  0.542298  0.145475
# m                        0.413570  0.114935
# p                        0.497556  0.135776
#                                S1   S1_conf
# TP_percentage            0.035794  0.095847
# satisfaction_threshold   0.041175  0.121491
# uncertainty_threshold    0.333196  0.165331
# min_increase_percentage -0.043596  0.112267
# max_increase_percentage  0.038205  0.122046
# m                       -0.021781  0.106068
# p                       -0.119999  0.102681
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.061695  0.126347
# (TP_percentage, uncertainty_threshold)              0.124045  0.180435
# (TP_percentage, min_increase_percentage)            0.095457  0.127772
# (TP_percentage, max_increase_percentage)            0.058050  0.132640
# (TP_percentage, m)                                  0.109777  0.140177
# (TP_percentage, p)                                  0.149217  0.126493
# (satisfaction_threshold, uncertainty_threshold)     0.227609  0.171489
# (satisfaction_threshold, min_increase_percentage)   0.165273  0.159792
# (satisfaction_threshold, max_increase_percentage)   0.101353  0.178467
# (satisfaction_threshold, m)                         0.139167  0.167109
# (satisfaction_threshold, p)                         0.173527  0.155846
# (uncertainty_threshold, min_increase_percentage)    0.109795  0.229878
# (uncertainty_threshold, max_increase_percentage)   -0.110905  0.237433
# (uncertainty_threshold, m)                          0.037190  0.209313
# (uncertainty_threshold, p)                          0.166296  0.226904
# (min_increase_percentage, max_increase_percentage)  0.054703  0.164370
# (min_increase_percentage, m)                        0.091455  0.160045
# (min_increase_percentage, p)                        0.140222  0.152974
# (max_increase_percentage, m)                        0.065778  0.166293
# (max_increase_percentage, p)                        0.110441  0.151163
# (m, p)                                              0.242914  0.144118
# Sensitivity analysis for Avg_F_Uncertainty (Holme-Kim network):
# {'S1': array([ 0.03579425,  0.04117526,  0.33319625, -0.04359586,  0.03820544,
#        -0.02178132, -0.11999927]), 'S1_conf': array([0.09584673, 0.12149065, 0.16533125, 0.11226699, 0.12204642,
#        0.1060678 , 0.10268104]), 'ST': array([0.40361149, 0.61006718, 0.76065536, 0.41450236, 0.54229795,
#        0.41357033, 0.49755614]), 'ST_conf': array([0.11549099, 0.138687  , 0.13291846, 0.13785299, 0.14547489,
#        0.11493503, 0.13577629]), 'S2': array([[        nan,  0.06169463,  0.12404493,  0.09545685,  0.05805005,
#          0.10977705,  0.14921659],
#        [        nan,         nan,  0.22760866,  0.16527279,  0.10135321,
#          0.13916716,  0.17352713],
#        [        nan,         nan,         nan,  0.10979513, -0.11090494,
#          0.03718996,  0.16629647],
#        [        nan,         nan,         nan,         nan,  0.0547031 ,
#          0.09145543,  0.14022175],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.06577753,  0.11044064],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.24291443],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.12634704, 0.18043546, 0.1277723 , 0.13264044,
#         0.14017732, 0.12649335],
#        [       nan,        nan, 0.17148887, 0.15979186, 0.17846666,
#         0.16710868, 0.15584644],
#        [       nan,        nan,        nan, 0.22987788, 0.23743278,
#         0.20931318, 0.2269043 ],
#        [       nan,        nan,        nan,        nan, 0.16436978,
#         0.16004492, 0.1529738 ],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.16629276, 0.15116267],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.144118  ],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.712279  0.133250
# satisfaction_threshold   0.329925  0.103205
# uncertainty_threshold    0.499257  0.117101
# min_increase_percentage  0.247765  0.106458
# max_increase_percentage  0.283061  0.104685
# m                        0.204597  0.081256
# p                        0.209189  0.076642
#                                S1   S1_conf
# TP_percentage            0.439626  0.136014
# satisfaction_threshold   0.129287  0.089160
# uncertainty_threshold    0.197058  0.130308
# min_increase_percentage  0.101131  0.093313
# max_increase_percentage  0.070496  0.097628
# m                        0.057123  0.069102
# p                        0.085811  0.080882
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.200432  0.173595
# (TP_percentage, uncertainty_threshold)             -0.017486  0.186640
# (TP_percentage, min_increase_percentage)           -0.205424  0.187936
# (TP_percentage, max_increase_percentage)           -0.102519  0.180258
# (TP_percentage, m)                                 -0.135993  0.173273
# (TP_percentage, p)                                 -0.173083  0.163091
# (satisfaction_threshold, uncertainty_threshold)    -0.091272  0.124511
# (satisfaction_threshold, min_increase_percentage)  -0.135479  0.132818
# (satisfaction_threshold, max_increase_percentage)  -0.130417  0.129536
# (satisfaction_threshold, m)                        -0.136735  0.131499
# (satisfaction_threshold, p)                        -0.127262  0.128719
# (uncertainty_threshold, min_increase_percentage)    0.033756  0.155851
# (uncertainty_threshold, max_increase_percentage)    0.039228  0.160838
# (uncertainty_threshold, m)                          0.015886  0.164344
# (uncertainty_threshold, p)                         -0.024674  0.153805
# (min_increase_percentage, max_increase_percentage) -0.077302  0.108917
# (min_increase_percentage, m)                       -0.094738  0.109689
# (min_increase_percentage, p)                       -0.085610  0.115959
# (max_increase_percentage, m)                       -0.090330  0.115217
# (max_increase_percentage, p)                       -0.038653  0.103854
# (m, p)                                             -0.071095  0.113557
# Sensitivity analysis for Avg_S_Uncertainty (Holme-Kim network):
# {'S1': array([0.43962567, 0.12928662, 0.1970576 , 0.1011313 , 0.07049638,
#        0.05712296, 0.08581057]), 'S1_conf': array([0.13601408, 0.08916042, 0.1303081 , 0.09331347, 0.09762847,
#        0.06910154, 0.08088232]), 'ST': array([0.7122788 , 0.32992508, 0.49925715, 0.24776474, 0.28306094,
#        0.20459713, 0.20918942]), 'ST_conf': array([0.13324958, 0.10320508, 0.11710124, 0.10645796, 0.10468495,
#        0.08125596, 0.07664168]), 'S2': array([[        nan, -0.20043169, -0.01748632, -0.20542351, -0.10251854,
#         -0.13599264, -0.17308325],
#        [        nan,         nan, -0.09127206, -0.13547919, -0.13041689,
#         -0.13673506, -0.12726187],
#        [        nan,         nan,         nan,  0.03375628,  0.0392275 ,
#          0.01588552, -0.02467372],
#        [        nan,         nan,         nan,         nan, -0.07730151,
#         -0.09473822, -0.08560989],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.09032954, -0.03865336],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.07109543],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.17359544, 0.18664046, 0.18793569, 0.18025792,
#         0.17327297, 0.16309104],
#        [       nan,        nan, 0.12451055, 0.13281787, 0.12953598,
#         0.1314989 , 0.12871885],
#        [       nan,        nan,        nan, 0.15585137, 0.16083822,
#         0.16434433, 0.15380506],
#        [       nan,        nan,        nan,        nan, 0.10891666,
#         0.10968858, 0.1159589 ],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.11521659, 0.10385418],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.11355704],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.581232  0.214641
# satisfaction_threshold   0.823391  0.194085
# uncertainty_threshold    0.927498  0.198447
# min_increase_percentage  0.664788  0.197248
# max_increase_percentage  0.776671  0.238410
# m                        0.695192  0.199625
# p                        0.680155  0.209383
#                                S1   S1_conf
# TP_percentage            0.087462  0.125446
# satisfaction_threshold   0.084053  0.158693
# uncertainty_threshold    0.068644  0.204115
# min_increase_percentage  0.106128  0.128141
# max_increase_percentage  0.074870  0.142668
# m                        0.016377  0.154429
# p                       -0.007816  0.143441
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.200207  0.231909
# (TP_percentage, uncertainty_threshold)             -0.041063  0.285250
# (TP_percentage, min_increase_percentage)           -0.124333  0.206709
# (TP_percentage, max_increase_percentage)           -0.108410  0.195668
# (TP_percentage, m)                                  0.016054  0.153688
# (TP_percentage, p)                                 -0.014674  0.157525
# (satisfaction_threshold, uncertainty_threshold)     0.115008  0.250811
# (satisfaction_threshold, min_increase_percentage)  -0.041615  0.213302
# (satisfaction_threshold, max_increase_percentage)  -0.102667  0.205327
# (satisfaction_threshold, m)                         0.044736  0.188235
# (satisfaction_threshold, p)                         0.012283  0.223349
# (uncertainty_threshold, min_increase_percentage)    0.019298  0.269847
# (uncertainty_threshold, max_increase_percentage)   -0.085444  0.229557
# (uncertainty_threshold, m)                          0.001250  0.281233
# (uncertainty_threshold, p)                          0.112076  0.296789
# (min_increase_percentage, max_increase_percentage) -0.157670  0.225011
# (min_increase_percentage, m)                       -0.023006  0.187528
# (min_increase_percentage, p)                       -0.002513  0.214543
# (max_increase_percentage, m)                        0.005786  0.165542
# (max_increase_percentage, p)                        0.027711  0.180538
# (m, p)                                              0.179934  0.211701
# Sensitivity analysis for Avg_P_Uncertainty (Holme-Kim network):
# {'S1': array([ 0.08746175,  0.08405281,  0.06864399,  0.10612803,  0.07487049,
#         0.01637693, -0.00781569]), 'S1_conf': array([0.12544553, 0.15869312, 0.20411542, 0.12814087, 0.14266756,
#        0.15442942, 0.14344107]), 'ST': array([0.58123178, 0.82339093, 0.92749765, 0.6647884 , 0.77667121,
#        0.69519222, 0.68015468]), 'ST_conf': array([0.21464143, 0.19408548, 0.19844652, 0.19724803, 0.23841023,
#        0.19962493, 0.20938305]), 'S2': array([[        nan, -0.20020746, -0.04106285, -0.12433327, -0.10840959,
#          0.01605415, -0.01467411],
#        [        nan,         nan,  0.11500835, -0.04161481, -0.10266657,
#          0.04473603,  0.01228286],
#        [        nan,         nan,         nan,  0.01929811, -0.08544445,
#          0.0012497 ,  0.11207604],
#        [        nan,         nan,         nan,         nan, -0.15767041,
#         -0.02300626, -0.00251347],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.00578627,  0.02771055],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.17993397],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.2319092 , 0.28525003, 0.20670913, 0.19566756,
#         0.15368829, 0.15752455],
#        [       nan,        nan, 0.250811  , 0.2133019 , 0.20532672,
#         0.18823538, 0.22334945],
#        [       nan,        nan,        nan, 0.26984738, 0.22955695,
#         0.28123326, 0.29678885],
#        [       nan,        nan,        nan,        nan, 0.22501089,
#         0.18752793, 0.21454273],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.16554193, 0.18053821],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.21170067],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}

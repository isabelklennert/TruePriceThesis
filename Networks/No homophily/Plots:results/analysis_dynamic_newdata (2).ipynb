# %% [markdown]
# # Analysis of dynamic network ABM
# Standard networks, no SDA yet

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import networkx as nx
import cProfile
import pstats
import mesa
pd.set_option('display.max_colwidth', 10000)
import joblib
import matplotlib.pyplot as plt
from collections import Counter
from tqdm import tqdm
from SALib.sample import saltelli
from SALib.analyze import sobol
from SALib.test_functions import Ishigami
# from mesa.batchrunner import BatchRunner
import itertools

# %%
#from model import ConsumatModel
from model_dynamicnetwork_newdata import ConsumatModel

# %%
base_config = {
    'TP_percentage': 0.7,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'],
    'seed': 42  # Seed for reproducibility
}

# Configuration for Watts-Strogatz network
watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


# Configuration for Barabasi-Albert network
barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

# Configuration for Random Regular network
random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

# Configuration for Holme-Kim network
holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})

# %% [markdown]
# ## Network topology
#
# ### Watts-Strogatz Network
# - **Type:** Small-world network
# - **Known For:** High clustering coefficient and short average path lengths, which mimic many real-world social networks.
# - **Formation:** Starts with a ring of `n` nodes each connected to `k` nearest neighbors. Rewires each edge with probability `p` to a randomly chosen node.
# - **Key Parameters:**
#   - `n`: Number of nodes
#   - `k`: Number of nearest neighbors in the initial ring topology
#   - `p`: Probability of rewiring each edge
#
# ### Barabasi-Albert Network
# - **Type:** Scale-free network
# - **Known For:** Its degree distribution follows a power law, which is typical for many large networks such as the internet, citation networks, and some social networks.
# - **Formation:** Begins with a small number of nodes and adds new nodes one at a time. Each new node is connected to `k` existing nodes with a probability that depends on the number of links that the existing nodes already have.
# - **Key Parameters:**
#   - `n`: Total number of nodes
#   - `m`: Number of edges to attach from a new node to existing nodes
#
# ### Random Regular Network
# - **Type:** Regular graph
# - **Known For:** Every node has the same number of connections. This uniformity can represent idealized conditions in network modeling.
# - **Formation:** Constructed by connecting each node with `d` neighbors chosen at random, ensuring each has the same degree, while avoiding self-loops and duplicate edges.
# - **Key Parameters:**
#   - `n`: Total number of nodes
#   - `d`: Degree of each node
#
# ### Holme-Kim Network
# - **Type:** Small-world network with scale-free properties
# - **Known For:** Combines high clustering and short path lengths (like Watts-Strogatz) with a degree distribution that follows a power law (like Barabasi-Albert).
# - **Formation:** Starts like the Barabasi-Albert model by adding one node at a time, connecting to `m` existing nodes based on their degree. After each edge creation, with probability `p` adds an additional edge forming a triangle.
# - **Key Parameters:**
#   - `n`: Total number of nodes
#   - `m`: Number of edges each new node will attempt to make
#   - `p`: Triad formation probability

# %%
def run_simulation(model, num_steps):
    adoption_rates = []

    for _ in tqdm(range(num_steps), desc='Simulation Progress'):
        model.step()
        current_adoption_rate = model.calculate_true_price_adoption_rate()
        adoption_rates.append(current_adoption_rate)

    model_data = model.datacollector.get_model_vars_dataframe()
    agent_data = model.datacollector.get_agent_vars_dataframe()
    model_data['Adoption Rates'] = adoption_rates

    return model_data, agent_data

def run_all_simulations(configurations, num_steps, num_simulations):
    results = {}
    all_simulation_data = {}
    
    for config_name, config in configurations.items():
        print(f"Running simulations for {config_name} with parameters: {config}")
        
        all_simulation_data[config_name] = []
        
        for simulation in range(num_simulations):
            model = ConsumatModel(config)
            model_data, agent_data = run_simulation(model, num_steps)
            all_simulation_data[config_name].append(model_data)

        aggregated_data = pd.concat(all_simulation_data[config_name]).groupby(level=0).mean()
        results[config_name] = aggregated_data

    return results, all_simulation_data


def generate_decision_modes_count(agent_data):
    decision_modes_count = agent_data.groupby(['Step'])[['Repeat', 'Imitate', 'Deliberate', 'Social_Compare']].sum()
    return decision_modes_count

# %%
def plot_adoption_rates(all_simulation_data, varying_params):
    param_name = list(varying_params.keys())[0]
    
    # Group configurations by network
    network_groups = {}
    for config_name in all_simulation_data.keys():
        network_name = config_name.split('_Config_')[0]
        if network_name not in network_groups:
            network_groups[network_name] = []
        network_groups[network_name].append(config_name)
    
    # Plot each network's configurations
    for network_name, config_names in network_groups.items():
        plt.figure(figsize=(10, 6))
        
        for config_name in config_names:
            data = all_simulation_data[config_name]
            tp_value = config_name.split('_TP_')[1]
            for idx, sim_data in enumerate(data):
                plt.plot(sim_data['Adoption Rates'], marker='o', label=f'{param_name} {tp_value}')
        
        plt.title(f'True Price Adoption Rate Over Iterations for {network_name}')
        plt.xlabel('Iteration')
        plt.ylabel('True Price Adoption Rate (%)')
        plt.grid(True)
        plt.legend()
        plt.show()



def plot_network_metrics(results, varying_params):
    param_name = list(varying_params.keys())[0]
    
    network_groups = {}
    for config_name in results.keys():
        network_name = config_name.split('_Config_')[0]
        if network_name not in network_groups:
            network_groups[network_name] = []
        network_groups[network_name].append(config_name)
    
    for network_name, config_names in network_groups.items():
        plt.figure(figsize=(10, 5))
        
        metrics_plotted = False
        for config_name in config_names:
            aggregated_data = results[config_name]
            tp_value = config_name.split('_TP_')[1]
            if 'Average Degree' in aggregated_data.columns:
                plt.plot(aggregated_data['Average Degree'], marker='o', label=f'Average Degree {param_name} {tp_value}')
                metrics_plotted = True
            if 'Variance of Degree' in aggregated_data.columns:
                plt.plot(aggregated_data['Variance of Degree'], marker='o', label=f'Variance of Degree {param_name} {tp_value}')
                metrics_plotted = True
            if 'Average Clustering' in aggregated_data.columns:
                plt.plot(aggregated_data['Average Clustering'], marker='o', label=f'Average Clustering {param_name} {tp_value}')
                metrics_plotted = True
            if 'Average Path Length' in aggregated_data.columns:
                plt.plot(aggregated_data['Average Path Length'], marker='o', label=f'Average Path Length {param_name} {tp_value}', linestyle='--')
                metrics_plotted = True
        
        if metrics_plotted:
            plt.xlabel('Step')
            plt.ylabel('Metric Value')
            plt.title(f'Network Metrics Over Time for {network_name}')
            plt.legend()
            plt.show()


def plot_decision_modes(network_configurations, num_steps):
    for network_name, config in network_configurations.items():
        model = ConsumatModel(config)
        _, agent_data = run_simulation(model, num_steps)
        
        decision_modes_count = generate_decision_modes_count(agent_data)
        print(f"Decision Mode Counts for {network_name} network:")
        print(decision_modes_count)

        plt.figure(figsize=(12, 8))
        plt.plot(decision_modes_count.index, decision_modes_count['Repeat'], label='Repeat', linestyle='-', marker='o')
        plt.plot(decision_modes_count.index, decision_modes_count['Imitate'], label='Imitate', linestyle='--', marker='x')
        plt.plot(decision_modes_count.index, decision_modes_count['Deliberate'], label='Deliberate', linestyle='-.', marker='s')
        plt.plot(decision_modes_count.index, decision_modes_count['Social_Compare'], label='Social Compare', linestyle=':', marker='d')
        plt.title(f'Decision Modes over Time for {network_name} network')
        plt.xlabel('Time Step')
        plt.ylabel('Number of Agents')
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.grid(True)
        plt.show()

# %% [markdown]
# ### Vary network parameters

# %%
def generate_configurations(base_config, varying_params):
    keys, values = zip(*varying_params.items())
    configurations = []
    
    for combination in itertools.product(*values):
        config = base_config.copy()
        config.update(dict(zip(keys, combination)))
        configurations.append(config)
    
    return configurations

# %%
# Example network configurations (replace with actual configurations)
network_configurations = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

# Varying parameters
varying_params = {
    'TP_percentage': [0.4, 0.5, 0.6, 0.7],
}

num_simulations = 1
num_steps = 10

# Generate configurations
all_configurations = {}
for network_name, net_config in network_configurations.items():
    net_configs = generate_configurations({**base_config, **net_config}, varying_params)
    for idx, config in enumerate(net_configs):
        config_name = f"{network_name}_Config_{idx+1}_TP_{config['TP_percentage']}"
        all_configurations[config_name] = config

# Run all simulations
results, all_simulation_data = run_all_simulations(all_configurations, num_steps, num_simulations)

# Plotting results
plot_adoption_rates(all_simulation_data, varying_params)
# Out:
# Running simulations for Watts-Strogatz_Config_1_TP_0.4 with parameters: {'TP_percentage': 0.4, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 0.3}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:27<00:00,  2.74s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_Config_2_TP_0.5 with parameters: {'TP_percentage': 0.5, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 0.3}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:25<00:00,  2.52s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_Config_3_TP_0.6 with parameters: {'TP_percentage': 0.6, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 0.3}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:24<00:00,  2.41s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_Config_4_TP_0.7 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 0.3}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:26<00:00,  2.62s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Barabasi-Albert_Config_1_TP_0.4 with parameters: {'TP_percentage': 0.4, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'barabasi_albert', 'network_params': {'n': 1600, 'm': 8}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:33<00:00,  3.34s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Barabasi-Albert_Config_2_TP_0.5 with parameters: {'TP_percentage': 0.5, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'barabasi_albert', 'network_params': {'n': 1600, 'm': 8}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:31<00:00,  3.11s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Barabasi-Albert_Config_3_TP_0.6 with parameters: {'TP_percentage': 0.6, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'barabasi_albert', 'network_params': {'n': 1600, 'm': 8}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:29<00:00,  2.90s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Barabasi-Albert_Config_4_TP_0.7 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'barabasi_albert', 'network_params': {'n': 1600, 'm': 8}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:28<00:00,  2.84s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Random Regular_Config_1_TP_0.4 with parameters: {'TP_percentage': 0.4, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'random_regular', 'network_params': {'n': 1600, 'd': 8}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:26<00:00,  2.66s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Random Regular_Config_2_TP_0.5 with parameters: {'TP_percentage': 0.5, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'random_regular', 'network_params': {'n': 1600, 'd': 8}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:27<00:00,  2.74s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
# Running simulations for Random Regular_Config_3_TP_0.6 with parameters: {'TP_percentage': 0.6, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'random_regular', 'network_params': {'n': 1600, 'd': 8}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:25<00:00,  2.56s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Random Regular_Config_4_TP_0.7 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'random_regular', 'network_params': {'n': 1600, 'd': 8}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:25<00:00,  2.52s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_Config_1_TP_0.4 with parameters: {'TP_percentage': 0.4, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 0.3}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:29<00:00,  2.98s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_Config_2_TP_0.5 with parameters: {'TP_percentage': 0.5, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 0.3}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:30<00:00,  3.06s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_Config_3_TP_0.6 with parameters: {'TP_percentage': 0.6, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 0.3}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:25<00:00,  2.59s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_Config_4_TP_0.7 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 0.3}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:24<00:00,  2.47s/it]

# %%
# Parameters to vary
parameter_name = 'p'
parameter_values = np.linspace(0, 1, 10)
num_steps = 10
num_simulations = 1

# Base configuration
base_config = {
    'TP_percentage': 0.7,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'],
    'seed': 42  # Seed for reproducibility
}

# Network configurations
network_configurations = {
    'Watts-Strogatz': {
        'network_type': 'watts_strogatz',
        'network_params': {
            'n': 1600,
            'k': 8,
            'p': 0.3
        }
    },
    'Holme-Kim': {
        'network_type': 'holme_kim',
        'network_params': {
            'n': 1600,
            'm': 8,
            'p': 0.3
        }
    }
}

# Parameters to vary
parameter_name = 'p'
parameter_values = np.arange(0, 1.1, 0.10)
num_steps = 10
num_simulations = 1

# Generate configurations
def generate_varying_param_configurations(base_config, network_configurations, parameter_name, parameter_values):
    all_configurations = {}
    for network_name, net_config in network_configurations.items():
        for value in parameter_values:
            config = base_config.copy()
            config.update(net_config)
            config['network_params'][parameter_name] = value
            config_name = f"{network_name}_p_{value:.2f}"
            all_configurations[config_name] = config
    return all_configurations

all_configurations = generate_varying_param_configurations(base_config, network_configurations, parameter_name, parameter_values)

# Run all simulations
results, all_simulation_data = run_all_simulations(all_configurations, num_steps, num_simulations)

# Plotting results
def plot_varying_parameter_results(all_simulation_data, parameter_name):
    network_groups = {}
    for config_name in all_simulation_data.keys():
        network_name = config_name.split('_p_')[0]
        if network_name not in network_groups:
            network_groups[network_name] = []
        network_groups[network_name].append(config_name)
    
    for network_name, config_names in network_groups.items():
        plt.figure(figsize=(10, 6))
        
        for config_name in config_names:
            data = all_simulation_data[config_name]
            p_value = config_name.split('_p_')[1]
            for idx, sim_data in enumerate(data):
                plt.plot(sim_data['Adoption Rates'], marker='o', label=f'p={p_value}')
        
        plt.title(f'True Price Adoption Rate Over Iterations for {network_name}')
        plt.xlabel('Iteration')
        plt.ylabel('True Price Adoption Rate (%)')
        plt.grid(True)
        plt.legend()
        plt.show()

# Plot results for adoption rates
plot_varying_parameter_results(all_simulation_data, parameter_name)
# Out:
# Running simulations for Watts-Strogatz_p_0.00 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:08<00:00, 12.85s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_p_0.10 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:06<00:00, 12.69s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_p_0.20 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:11<00:00, 13.13s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_p_0.30 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:12<00:00, 13.26s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_p_0.40 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:13<00:00, 13.37s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_p_0.50 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:12<00:00, 13.22s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_p_0.60 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:08<00:00, 12.90s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_p_0.70 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:00<00:00, 12.03s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_p_0.80 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:05<00:00, 12.52s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_p_0.90 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:00<00:00, 12.01s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Watts-Strogatz_p_1.00 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'watts_strogatz', 'network_params': {'n': 1600, 'k': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [02:06<00:00, 12.67s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_p_0.00 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:35<00:00, 27.52s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_p_0.10 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:24<00:00, 26.48s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_p_0.20 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:29<00:00, 26.91s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_p_0.30 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:23<00:00, 26.33s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_p_0.40 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:22<00:00, 26.26s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
# Running simulations for Holme-Kim_p_0.50 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:25<00:00, 26.56s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_p_0.60 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:28<00:00, 26.82s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_p_0.70 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:27<00:00, 26.78s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_p_0.80 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:23<00:00, 26.30s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_p_0.90 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:23<00:00, 26.32s/it]
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:21: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Running simulations for Holme-Kim_p_1.00 with parameters: {'TP_percentage': 0.7, 'satisfaction_threshold': 0.5, 'uncertainty_threshold': 0.5, 'product_price_range': (5, 10), 'min_increase_percentage': 4, 'max_increase_percentage': 10, 'num_products': 20, 'inflation_rate': 3, 'epsilon': 0.5, 'comparison_attributes': ['budget', 'preference_sustainability', 'preference_conformity'], 'seed': 42, 'network_type': 'holme_kim', 'network_params': {'n': 1600, 'm': 8, 'p': 1.0}}
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:592: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#
# C:\Users\elpha\Downloads\ThesisNew\Networks\No homophily\New data\model_dynamicnetwork_newdata.py:412: UserWarning: You are trying to set model.agents. In a next release, this attribute is used by MESA itself so you cannot use it directly anymore.Please adjust your code to use a different attribute name for custom agent storage
#   self.products = self.create_products()
# Simulation Progress: 100%|█████████████████████████████████████████████████████████████| 10/10 [04:21<00:00, 26.17s/it]

# %% [markdown]
# def run_simulation_for_tp_percentage(config, tp_percentages, num_steps):
#     results_by_tp_percentage = []
#
#     for tp_percentage in tqdm(tp_percentages, desc='TP Percentage Progress'):
#         # Update the config with the current TP_percentage
#         config['TP_percentage'] = tp_percentage
#
#         # Run the simulation
#         model = ConsumatModel(config)
#         model_data, agent_data = run_simulation(model, num_steps)
#
#         # Extract the adoption rates and decision modes from the DataFrame
#         adoption_rates = model_data['Adoption Rates'].values
#         decision_modes_count = generate_decision_modes_count(agent_data)
#
#         # Store the adoption rates and decision modes for this TP_percentage
#         results_by_tp_percentage.append((adoption_rates, decision_modes_count))
#
#     return results_by_tp_percentage
# # Base configuration
# base_config = {
#     'TP_percentage': 0.7,
#     'satisfaction_threshold': 0.5,
#     'uncertainty_threshold': 0.5,
#     'kde_models_dir': '/Applications/UNI/Thesis/saved_data/',
#     'product_price_range': (5, 10),
#     'min_increase_percentage': 4,
#     'max_increase_percentage': 10,
#     'num_products': 20,
#     'inflation_rate': 3,
#     'seed': 42  # Seed for reproducibility
# }
#
# # Network configurations
# network_configs = {
#     'Watts-Strogatz': {
#         'network_type': 'watts_strogatz',
#         'network_params': {
#             'n': 1600,
#             'k': 4,
#             'p': 0.2
#         }
#     },
#     'Barabasi-Albert': {
#         'network_type': 'barabasi_albert',
#         'network_params': {
#             'n': 1600,
#             'm': 4
#         }
#     },
#     'Random Regular': {
#         'network_type': 'random_regular',
#         'network_params': {
#             'n': 1600,
#             'd': 4
#         }
#     },
#     'Holme-Kim': {
#         'network_type': 'holme_kim',
#         'network_params': {
#             'n': 1600,
#             'm': 4,
#             'p': 0.1
#         }
#     }
# }
#
# # Define a range of values for TP_percentage
# tp_percentages = np.linspace(0.4, 0.9, 19)  # From 40% to 90%
#
# # Hold the number of steps constant for each simulation
# num_steps = 10
#
# # Function to generate decision modes count DataFrame
# def generate_decision_modes_count(agent_data):
#     decision_modes_count = agent_data.groupby(['Step'])[['Repeat', 'Imitate', 'Deliberate', 'Social_Compare']].sum()
#     return decision_modes_count
#
# # Run simulations and collect results for all networks
# all_network_results = {}
# for network_name, network_config in network_configs.items():
#     print(f"Running simulations for {network_name} network...")
#     config = base_config.copy()
#     config.update(network_config)
#     results_by_tp_percentage = run_simulation_for_tp_percentage(config, tp_percentages, num_steps)
#     all_network_results[network_name] = results_by_tp_percentage
#
# # Plot the results for each network
# for network_name, results_by_tp_percentage in all_network_results.items():
#     # Plot True Price Adoption Rates
#     plt.figure(figsize=(10, 6))
#     for i, (adoption_rates, _) in enumerate(results_by_tp_percentage):
#         plt.plot(range(1, num_steps + 1), adoption_rates, label=f'TP_percentage = {tp_percentages[i]:.1f}', marker='o')
#     plt.title(f'True Price Percentage Impact on Adoption Rate - {network_name}')
#     plt.xlabel('Time Step')
#     plt.ylabel('True Price Adoption Rate (%)')
#     plt.legend()
#     plt.grid(True)
#     plt.show()
#
#     # Plot Decision Modes
#     fig, axs = plt.subplots(2, 2, figsize=(15, 10))
#     fig.suptitle(f'Decision Modes for Different TP Percentages - {network_name}')
#
#     mode_labels = ['Repeat', 'Imitate', 'Deliberate', 'Social_Compare']
#     for idx, mode in enumerate(mode_labels):
#         ax = axs[idx // 2, idx % 2]
#         for i, (_, decision_modes_count) in enumerate(results_by_tp_percentage):
#             ax.plot(decision_modes_count.index, decision_modes_count[mode], label=f'TP_percentage = {tp_percentages[i]:.1f}', marker='o')
#         ax.set_title(f'{mode} Mode')
#         ax.set_xlabel('Time Step')
#         ax.set_ylabel('Number of Agents')
#         ax.legend()
#         ax.grid(True)
#
#     plt.tight_layout(rect=[0, 0, 1, 0.95])
#     plt.show()

# %% [markdown]
# ## Global Sensitivity Analysis
#
# Sobol indices
#
# Saltelli sampling
#
# Pick key parameters (e.g. alpha, beta, rewiring probability) and key measures (true price adoption rate...)

# %% [markdown]
# ### Sensitivity Analysis

# %% [markdown]
# ### GSA

# %%
# Install specific versions of the libraries
# !pip install SALib==1.4.8
# !pip install numpy==1.26.4
# !pip install pandas==2.2.0
# Out:
# Collecting SALib==1.4.8
#   Downloading salib-1.4.8-py3-none-any.whl (778 kB)
#      -------------------------------------- 778.7/778.7 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.2 in c:\users\elpha\anaconda3\lib\site-packages (from SALib==1.4.8) (2.2.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\elpha\anaconda3\lib\site-packages (from SALib==1.4.8) (2.0.0)
# Requirement already satisfied: multiprocess in c:\users\elpha\anaconda3\lib\site-packages (from SALib==1.4.8) (0.70.16)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\elpha\anaconda3\lib\site-packages (from SALib==1.4.8) (3.5.2)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\elpha\anaconda3\lib\site-packages (from SALib==1.4.8) (1.13.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\elpha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->SALib==1.4.8) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\elpha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->SALib==1.4.8) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\elpha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->SALib==1.4.8) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\elpha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->SALib==1.4.8) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\elpha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->SALib==1.4.8) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\elpha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->SALib==1.4.8) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\elpha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->SALib==1.4.8) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elpha\anaconda3\lib\site-packages (from pandas>=1.2->SALib==1.4.8) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elpha\anaconda3\lib\site-packages (from pandas>=1.2->SALib==1.4.8) (2024.1)
# Requirement already satisfied: dill>=0.3.8 in c:\users\elpha\anaconda3\lib\site-packages (from multiprocess->SALib==1.4.8) (0.3.8)
# Requirement already satisfied: six>=1.5 in c:\users\elpha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->SALib==1.4.8) (1.16.0)
# Installing collected packages: SALib
#   Attempting uninstall: SALib
#     Found existing installation: SALib 1.5.0
#     Uninstalling SALib-1.5.0:
#       Successfully uninstalled SALib-1.5.0
# Successfully installed SALib-1.4.8
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
#      --------------------------------------- 15.8/15.8 MB 43.7 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\elpha\\anaconda3\\Lib\\site-packages\\~umpy.libs\\libscipy_openblas64_-fb1711452d4d8cee9f276fd1449ee5c7.dll'
# Consider using the `--user` option or check the permissions.
# Collecting pandas==2.2.0
#   Downloading pandas-2.2.0-cp39-cp39-win_amd64.whl (11.6 MB)
#      --------------------------------------- 11.6/11.6 MB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\elpha\anaconda3\lib\site-packages (from pandas==2.2.0) (2022.7)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\elpha\anaconda3\lib\site-packages (from pandas==2.2.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\elpha\anaconda3\lib\site-packages (from pandas==2.2.0) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elpha\anaconda3\lib\site-packages (from pandas==2.2.0) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\elpha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.0) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# Successfully installed pandas-2.2.0

# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

base_config = {
    'TP_percentage': 0.7,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['preference_sustainability'],
    'seed': 42  # Seed for reproducibility
}

# Configuration for Watts-Strogatz network
watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


# Configuration for Barabasi-Albert network
barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

# Configuration for Random Regular network
random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

# Configuration for Holme-Kim network
holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})


network_configs = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

# Define the model inputs for each network type
network_problems = {
    'Watts-Strogatz': {
        'num_vars': 8,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon', 'min_increase_percentage','max_increase_percentage', 'k', 'p'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1], [1,10], [11,20], [2, 10], [0, 1]] 
    },
    'Barabasi-Albert': {
        'num_vars': 7,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold','epsilon','min_increase_percentage', 'max_increase_percentage', 'm'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1],[1,10], [11,20],[2, 10]]  
    },
    'Random Regular': {
        'num_vars': 7,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon','min_increase_percentage','max_increase_percentage','d'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1],[1,10], [11,20],[2, 10]]  
    },
    'Holme-Kim': {
        'num_vars': 8,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon','min_increase_percentage','max_increase_percentage','m', 'p'],
        'bounds': [[0, 1], [0, 1], [0, 1],[0,1], [1,10], [11,20],[2, 10], [0, 1]] 
    }
}

# %%
# Number of samples
num_samples = 256

# Generate samples for each network problem
samples = {}
for network_name, problem in network_problems.items():
    samples[network_name] = saltelli.sample(problem, num_samples)
# Out:
# C:\Users\elpha\AppData\Local\Temp\ipykernel_21120\3049819496.py:7: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5.1 Please use `salib.sample.sobol`
#   samples[network_name] = saltelli.sample(problem, num_samples)

# %%
from joblib import Parallel, delayed
import numpy as np
import pandas as pd
from tqdm import tqdm
from SALib.sample import saltelli
from SALib.analyze import sobol
import json

def collect_simulation_data(model, num_steps):
    collected_data = {
        'Step': [],
        'Adoption Rate': [],
        'Avg_F_Satisfaction': [],
        'Avg_S_Satisfaction': [],
        'Avg_P_Satisfaction': [],
        'Avg_F_Uncertainty': [],
        'Avg_S_Uncertainty': [],
        'Avg_P_Uncertainty': []
    }

    for step in range(num_steps):
        model.step()
        collected_data['Step'].append(step)
        collected_data['Adoption Rate'].append(model.calculate_true_price_adoption_rate())
        collected_data['Avg_F_Satisfaction'].append(np.mean([agent.F_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_S_Satisfaction'].append(np.mean([agent.S_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_P_Satisfaction'].append(np.mean([agent.P_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_F_Uncertainty'].append(np.mean([agent.F_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_S_Uncertainty'].append(np.mean([agent.S_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_P_Uncertainty'].append(np.mean([agent.P_uncertainty for agent in model.schedule.agents]))

    model_data = pd.DataFrame(collected_data)
    return model_data

def run_single_simulation(params, config, network_name, num_steps):
    config = config.copy()
    config['TP_percentage'] = params[0]
    config['satisfaction_threshold'] = params[1]
    config['uncertainty_threshold'] = params[2]
    config['epsilon'] = params[3]
    config['min_increase_percentage'] = params[4]
    config['max_increase_percentage'] = params[5]

    if network_name == 'Watts-Strogatz':
        config['network_params']['k'] = int(params[6])
        config['network_params']['p'] = params[7]
    elif network_name == 'Barabasi-Albert':
        config['network_params']['m'] = int(params[6])
    elif network_name == 'Random Regular':
        config['network_params']['d'] = int(params[6])
    elif network_name == 'Holme-Kim':
        config['network_params']['m'] = int(params[6])
        config['network_params']['p'] = params[7]

    model = ConsumatModel(config)
    model_data = collect_simulation_data(model, num_steps)
    final_step_data = model_data.iloc[-1]

    return [
        final_step_data['Adoption Rate'],
        final_step_data['Avg_F_Satisfaction'],
        final_step_data['Avg_S_Satisfaction'],
        final_step_data['Avg_P_Satisfaction'],
        final_step_data['Avg_F_Uncertainty'],
        final_step_data['Avg_S_Uncertainty'],
        final_step_data['Avg_P_Uncertainty']
    ]

def run_gsa_simulation_parallel(network_name, config, samples, num_steps, n_jobs=-1):
    all_results = Parallel(n_jobs=n_jobs)(
        delayed(run_single_simulation)(params, config, network_name, num_steps)
        for params in tqdm(samples, desc=f'Running simulations for {network_name}')
    )
    return np.array(all_results)

num_steps = 10

# Run GSA for each network
for network_name, config in network_configurations.items():
    print(f"Running GSA for {network_name} network...")
    config = base_config.copy()
    config.update(network_configs[network_name])
    all_results = run_gsa_simulation_parallel(network_name, config, samples[network_name], num_steps)
    
    results = {}
    
    # Perform Sobol sensitivity analysis
    for i, output in enumerate(['Adoption Rate', 'Avg_F_Satisfaction', 'Avg_S_Satisfaction', 'Avg_P_Satisfaction', 'Avg_F_Uncertainty', 'Avg_S_Uncertainty', 'Avg_P_Uncertainty']):
        Si = sobol.analyze(network_problems[network_name], all_results[:, i], print_to_console=True)
        results[output] = {
            'S1': Si['S1'].tolist(),
            'ST': Si['ST'].tolist(),
            'S2': Si['S2'].tolist(),
            'S1_conf': Si['S1_conf'].tolist(),
            'ST_conf': Si['ST_conf'].tolist()
        }
        print(f'Sensitivity analysis for {output} ({network_name} network):')
        print(Si)
    
    # Save results to a JSON file
    with open(f'dynamic_sensitivity_results_preferencesustainability_{network_name}.json', 'w') as f:
        json.dump(results, f)
# Out:
# Running GSA for Watts-Strogatz network...
# Running simulations for Watts-Strogatz:   0%|                                                 | 0/4608 [00:00<?, ?it/s]
# Running simulations for Watts-Strogatz:   0%|▏                                       | 16/4608 [00:00<02:34, 29.78it/s]
# Running simulations for Watts-Strogatz:   0%|▏                                       | 16/4608 [00:11<02:34, 29.78it/s]
# Running simulations for Watts-Strogatz:   1%|▎                                     | 32/4608 [01:22<3:52:09,  3.04s/it]
# Running simulations for Watts-Strogatz:   1%|▍                                     | 48/4608 [01:59<3:25:06,  2.70s/it]
# Running simulations for Watts-Strogatz:   1%|▌                                     | 64/4608 [02:50<3:38:21,  2.88s/it]
# Running simulations for Watts-Strogatz:   2%|▋                                     | 80/4608 [05:42<7:12:22,  5.73s/it]
# Running simulations for Watts-Strogatz:   2%|▊                                    | 96/4608 [09:31<10:49:32,  8.64s/it]
# Running simulations for Watts-Strogatz:   2%|▉                                   | 112/4608 [14:10<14:23:24, 11.52s/it]
# Running simulations for Watts-Strogatz:   3%|█                                   | 128/4608 [16:58<13:55:21, 11.19s/it]
# Running simulations for Watts-Strogatz:   3%|█▏                                  | 144/4608 [18:03<11:07:45,  8.98s/it]
# Running simulations for Watts-Strogatz:   3%|█▎                                  | 160/4608 [20:31<11:10:33,  9.05s/it]
# Running simulations for Watts-Strogatz:   4%|█▍                                  | 176/4608 [24:30<13:22:05, 10.86s/it]

# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

base_config = {
    'TP_percentage': 0.7,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['budget'],
    'seed': 42  # Seed for reproducibility
}

# Configuration for Watts-Strogatz network
watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


# Configuration for Barabasi-Albert network
barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

# Configuration for Random Regular network
random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

# Configuration for Holme-Kim network
holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})


network_configs = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

# Define the model inputs for each network type
network_problems = {
    'Watts-Strogatz': {
        'num_vars': 8,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon', 'min_increase_percentage','max_increase_percentage', 'k', 'p'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1], [1,10], [11,20], [2, 10], [0, 1]] 
    },
    'Barabasi-Albert': {
        'num_vars': 7,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold','epsilon','min_increase_percentage', 'max_increase_percentage', 'm'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1],[1,10], [11,20],[2, 10]]  
    },
    'Random Regular': {
        'num_vars': 7,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon','min_increase_percentage','max_increase_percentage','d'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1],[1,10], [11,20],[2, 10]]  
    },
    'Holme-Kim': {
        'num_vars': 8,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon','min_increase_percentage','max_increase_percentage','m', 'p'],
        'bounds': [[0, 1], [0, 1], [0, 1],[0,1], [1,10], [11,20],[2, 10], [0, 1]] 
    }
}
# Number of samples
num_samples = 256

# Generate samples for each network problem
samples = {}
for network_name, problem in network_problems.items():
    samples[network_name] = saltelli.sample(problem, num_samples)

from joblib import Parallel, delayed
import numpy as np
import pandas as pd
from tqdm import tqdm
from SALib.sample import saltelli
from SALib.analyze import sobol
import json

def collect_simulation_data(model, num_steps):
    collected_data = {
        'Step': [],
        'Adoption Rate': [],
        'Avg_F_Satisfaction': [],
        'Avg_S_Satisfaction': [],
        'Avg_P_Satisfaction': [],
        'Avg_F_Uncertainty': [],
        'Avg_S_Uncertainty': [],
        'Avg_P_Uncertainty': []
    }

    for step in range(num_steps):
        model.step()
        collected_data['Step'].append(step)
        collected_data['Adoption Rate'].append(model.calculate_true_price_adoption_rate())
        collected_data['Avg_F_Satisfaction'].append(np.mean([agent.F_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_S_Satisfaction'].append(np.mean([agent.S_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_P_Satisfaction'].append(np.mean([agent.P_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_F_Uncertainty'].append(np.mean([agent.F_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_S_Uncertainty'].append(np.mean([agent.S_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_P_Uncertainty'].append(np.mean([agent.P_uncertainty for agent in model.schedule.agents]))

    model_data = pd.DataFrame(collected_data)
    return model_data

def run_single_simulation(params, config, network_name, num_steps):
    config = config.copy()
    config['TP_percentage'] = params[0]
    config['satisfaction_threshold'] = params[1]
    config['uncertainty_threshold'] = params[2]
    config['epsilon'] = params[3]
    config['min_increase_percentage'] = params[4]
    config['max_increase_percentage'] = params[5]

    if network_name == 'Watts-Strogatz':
        config['network_params']['k'] = int(params[6])
        config['network_params']['p'] = params[7]
    elif network_name == 'Barabasi-Albert':
        config['network_params']['m'] = int(params[6])
    elif network_name == 'Random Regular':
        config['network_params']['d'] = int(params[6])
    elif network_name == 'Holme-Kim':
        config['network_params']['m'] = int(params[6])
        config['network_params']['p'] = params[7]

    model = ConsumatModel(config)
    model_data = collect_simulation_data(model, num_steps)
    final_step_data = model_data.iloc[-1]

    return [
        final_step_data['Adoption Rate'],
        final_step_data['Avg_F_Satisfaction'],
        final_step_data['Avg_S_Satisfaction'],
        final_step_data['Avg_P_Satisfaction'],
        final_step_data['Avg_F_Uncertainty'],
        final_step_data['Avg_S_Uncertainty'],
        final_step_data['Avg_P_Uncertainty']
    ]

def run_gsa_simulation_parallel(network_name, config, samples, num_steps, n_jobs=-1):
    all_results = Parallel(n_jobs=n_jobs)(
        delayed(run_single_simulation)(params, config, network_name, num_steps)
        for params in tqdm(samples, desc=f'Running simulations for {network_name}')
    )
    return np.array(all_results)

num_steps = 10

# Run GSA for each network
for network_name, config in network_configurations.items():
    print(f"Running GSA for {network_name} network...")
    config = base_config.copy()
    config.update(network_configs[network_name])
    all_results = run_gsa_simulation_parallel(network_name, config, samples[network_name], num_steps)
    
    results = {}
    
    # Perform Sobol sensitivity analysis
    for i, output in enumerate(['Adoption Rate', 'Avg_F_Satisfaction', 'Avg_S_Satisfaction', 'Avg_P_Satisfaction', 'Avg_F_Uncertainty', 'Avg_S_Uncertainty', 'Avg_P_Uncertainty']):
        Si = sobol.analyze(network_problems[network_name], all_results[:, i], print_to_console=True)
        results[output] = {
            'S1': Si['S1'].tolist(),
            'ST': Si['ST'].tolist(),
            'S2': Si['S2'].tolist(),
            'S1_conf': Si['S1_conf'].tolist(),
            'ST_conf': Si['ST_conf'].tolist()
        }
        print(f'Sensitivity analysis for {output} ({network_name} network):')
        print(Si)
    
    # Save results to a JSON file
    with open(f'dynamic_sensitivity_results_budget_{network_name}.json', 'w') as f:
        json.dump(results, f)
# Out:
# C:\Users\elpha\AppData\Local\Temp\ipykernel_9568\4110209560.py:102: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5. Please use `salib.sample.sobol`
#   samples[network_name] = saltelli.sample(problem, num_samples)
# Running GSA for Watts-Strogatz network...
# Running simulations for Watts-Strogatz:   0%|                                                 | 0/4608 [00:00<?, ?it/s]
# Running simulations for Watts-Strogatz:   1%|▏                                     | 24/4608 [00:25<1:22:36,  1.08s/it]
# Running simulations for Watts-Strogatz:   1%|▎                                     | 36/4608 [00:35<1:12:02,  1.06it/s]
# Running simulations for Watts-Strogatz:   1%|▍                                     | 48/4608 [00:44<1:06:35,  1.14it/s]
# Running simulations for Watts-Strogatz:   1%|▌                                       | 60/4608 [00:49<56:05,  1.35it/s]
# Running simulations for Watts-Strogatz:   2%|▌                                     | 72/4608 [01:14<1:28:35,  1.17s/it]
# Running simulations for Watts-Strogatz:   2%|▋                                     | 84/4608 [01:29<1:30:30,  1.20s/it]
# Running simulations for Watts-Strogatz:   2%|▊                                     | 96/4608 [01:38<1:19:32,  1.06s/it]
# Running simulations for Watts-Strogatz:   2%|▊                                    | 108/4608 [01:47<1:12:20,  1.04it/s]
# Running simulations for Watts-Strogatz:   3%|▉                                    | 120/4608 [02:13<1:38:47,  1.32s/it]
# Running simulations for Watts-Strogatz:   3%|█                                    | 132/4608 [02:37<1:55:00,  1.54s/it]
# Running simulations for Watts-Strogatz:   3%|█▏                                   | 144/4608 [02:48<1:39:33,  1.34s/it]
# Running simulations for Watts-Strogatz:   3%|█▎                                   | 156/4608 [03:00<1:33:20,  1.26s/it]
# Running simulations for Watts-Strogatz:   4%|█▎                                   | 168/4608 [03:12<1:26:06,  1.16s/it]
# Running simulations for Watts-Strogatz:   4%|█▍                                   | 180/4608 [03:22<1:18:35,  1.06s/it]
# Running simulations for Watts-Strogatz:   4%|█▌                                   | 192/4608 [03:51<1:48:30,  1.47s/it]
# Running simulations for Watts-Strogatz:   4%|█▋                                   | 204/4608 [04:18<2:04:54,  1.70s/it]
# Running simulations for Watts-Strogatz:   5%|█▋                                   | 216/4608 [04:45<2:17:42,  1.88s/it]
# Running simulations for Watts-Strogatz:   5%|█▊                                   | 228/4608 [04:56<1:55:47,  1.59s/it]
# Running simulations for Watts-Strogatz:  98%|███████████████████████████████████▎| 4512/4608 [1:35:37<02:28,  1.55s/it]
# Running simulations for Watts-Strogatz:  98%|███████████████████████████████████▎| 4524/4608 [1:36:00<02:20,  1.68s/it]
# Running simulations for Watts-Strogatz:  98%|███████████████████████████████████▍| 4536/4608 [1:36:10<01:42,  1.42s/it]
# Running simulations for Watts-Strogatz:  99%|███████████████████████████████████▌| 4548/4608 [1:36:37<01:40,  1.67s/it]
# Running simulations for Watts-Strogatz:  99%|███████████████████████████████████▋| 4560/4608 [1:37:01<01:25,  1.77s/it]
# Running simulations for Watts-Strogatz:  99%|███████████████████████████████████▋| 4572/4608 [1:37:26<01:06,  1.84s/it]
# Running simulations for Watts-Strogatz:  99%|███████████████████████████████████▊| 4584/4608 [1:37:36<00:37,  1.55s/it]
# Running simulations for Watts-Strogatz: 100%|███████████████████████████████████▉| 4596/4608 [1:37:42<00:14,  1.23s/it]
# Running simulations for Watts-Strogatz: 100%|████████████████████████████████████| 4608/4608 [1:38:09<00:00,  1.28s/it]
#                                ST   ST_conf
# TP_percentage            1.051326  0.145675
# satisfaction_threshold   0.103215  0.055502
# uncertainty_threshold    0.107389  0.062135
# epsilon                  0.033588  0.034528
# min_increase_percentage  0.012149  0.017571
# max_increase_percentage  0.064985  0.052430
# k                        0.044409  0.039775
# p                        0.082962  0.046632
#                                S1   S1_conf
# TP_percentage            0.888239  0.135275
# satisfaction_threshold   0.009545  0.061967
# uncertainty_threshold    0.038419  0.058833
# epsilon                  0.000577  0.030439
# min_increase_percentage -0.009136  0.016668
# max_increase_percentage -0.001755  0.046073
# k                       -0.018781  0.038223
# p                        0.015488  0.045928
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.029595  0.106770
# (TP_percentage, uncertainty_threshold)             -0.013092  0.102401
# (TP_percentage, epsilon)                            0.021012  0.095405
# (TP_percentage, min_increase_percentage)            0.013134  0.093663
# (TP_percentage, max_increase_percentage)            0.011609  0.103957
# (TP_percentage, k)                                  0.064634  0.090400
# (TP_percentage, p)                                 -0.013349  0.104092
# (satisfaction_threshold, uncertainty_threshold)     0.052634  0.086459
# (satisfaction_threshold, epsilon)                   0.050266  0.084916
# (satisfaction_threshold, min_increase_percentage)   0.046444  0.084978
# ...
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.157688  0.053259
# satisfaction_threshold   0.419380  0.124334
# uncertainty_threshold    0.729162  0.131512
# epsilon                  0.139090  0.062460
# min_increase_percentage  0.068196  0.051888
# max_increase_percentage  0.132795  0.072355
# m                        0.319257  0.103737
# p                        0.304984  0.125616
#                                S1   S1_conf
# TP_percentage            0.041278  0.074098
# satisfaction_threshold   0.138960  0.105899
# uncertainty_threshold    0.411485  0.167229
# epsilon                  0.017340  0.057448
# min_increase_percentage -0.010408  0.040573
# max_increase_percentage  0.020945  0.042151
# m                        0.072189  0.089281
# p                        0.080485  0.124557
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.024100  0.129541
# (TP_percentage, uncertainty_threshold)             -0.042681  0.099814
# (TP_percentage, epsilon)                            0.029785  0.104945
# (TP_percentage, min_increase_percentage)            0.028645  0.104506
# (TP_percentage, max_increase_percentage)            0.047896  0.109105
# (TP_percentage, m)                                  0.007321  0.102340
# (TP_percentage, p)                                 -0.006042  0.101530
# (satisfaction_threshold, uncertainty_threshold)    -0.057748  0.190007
# (satisfaction_threshold, epsilon)                  -0.080188  0.167625
# (satisfaction_threshold, min_increase_percentage)  -0.060540  0.159756
# (satisfaction_threshold, max_increase_percentage)  -0.090336  0.162142
# (satisfaction_threshold, m)                        -0.105817  0.156142
# (satisfaction_threshold, p)                        -0.143896  0.164403
# (uncertainty_threshold, epsilon)                   -0.029031  0.199391
# (uncertainty_threshold, min_increase_percentage)   -0.100127  0.215221
# (uncertainty_threshold, max_increase_percentage)   -0.114082  0.194470
# (uncertainty_threshold, m)                         -0.196574  0.203033
# (uncertainty_threshold, p)                         -0.140410  0.205280
# (epsilon, min_increase_percentage)                  0.033401  0.107039
# (epsilon, max_increase_percentage)                  0.049812  0.105118
# (epsilon, m)                                       -0.019626  0.085679
# (epsilon, p)                                       -0.015574  0.077067
# (min_increase_percentage, max_increase_percentage)  0.041685  0.063222
# (min_increase_percentage, m)                        0.024264  0.060553
# (min_increase_percentage, p)                        0.000285  0.070585
# (max_increase_percentage, m)                       -0.023854  0.077103
# (max_increase_percentage, p)                        0.009696  0.083157
# (m, p)                                             -0.007992  0.143966
# Sensitivity analysis for Avg_F_Uncertainty (Holme-Kim network):
# {'S1': array([ 0.0412776 ,  0.13896003,  0.41148494,  0.01733954, -0.0104076 ,
#         0.020945  ,  0.07218894,  0.08048472]), 'S1_conf': array([0.0740978 , 0.10589933, 0.16722941, 0.05744848, 0.04057289,
#        0.04215053, 0.0892815 , 0.12455664]), 'ST': array([0.15768815, 0.41937986, 0.72916249, 0.13909025, 0.06819587,
#        0.13279509, 0.31925684, 0.30498353]), 'ST_conf': array([0.05325869, 0.12433395, 0.13151184, 0.06245986, 0.05188758,
#        0.07235467, 0.10373676, 0.12561595]), 'S2': array([[        nan,  0.02410025, -0.04268091,  0.0297851 ,  0.02864475,
#          0.04789608,  0.00732143, -0.00604248],
#        [        nan,         nan, -0.05774835, -0.08018819, -0.06053998,
#         -0.09033615, -0.10581656, -0.14389592],
#        [        nan,         nan,         nan, -0.02903081, -0.10012669,
#         -0.11408193, -0.19657442, -0.14041032],
#        [        nan,         nan,         nan,         nan,  0.0334006 ,
#          0.04981173, -0.01962646, -0.01557435],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.04168475,  0.02426387,  0.00028483],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.02385439,  0.00969606],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan, -0.00799192],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.12954107, 0.09981362, 0.10494467, 0.10450592,
#         0.10910457, 0.10233963, 0.10152978],
#        [       nan,        nan, 0.19000699, 0.16762494, 0.15975616,
#         0.16214207, 0.15614168, 0.16440279],
#        [       nan,        nan,        nan, 0.19939113, 0.21522097,
#         0.19446994, 0.20303316, 0.20527957],
#        [       nan,        nan,        nan,        nan, 0.10703923,
#         0.10511842, 0.08567929, 0.07706669],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.06322244, 0.0605531 , 0.07058517],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.07710289, 0.08315664],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.14396643],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.662381  0.122842
# satisfaction_threshold   0.258663  0.092196
# uncertainty_threshold    0.461118  0.106131
# epsilon                  0.078563  0.048865
# min_increase_percentage  0.037473  0.032500
# max_increase_percentage  0.073954  0.059961
# m                        0.147558  0.068530
# p                        0.181665  0.072271
#                                S1   S1_conf
# TP_percentage            0.378812  0.121807
# satisfaction_threshold   0.038171  0.080252
# uncertainty_threshold    0.155714  0.110545
# epsilon                  0.000665  0.049741
# min_increase_percentage -0.012711  0.027963
# max_increase_percentage  0.005989  0.046408
# m                        0.026757  0.060382
# p                       -0.018095  0.061381
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.068107  0.148373
# (TP_percentage, uncertainty_threshold)              0.150745  0.128264
# (TP_percentage, epsilon)                            0.023415  0.122132
# (TP_percentage, min_increase_percentage)            0.014953  0.120682
# (TP_percentage, max_increase_percentage)            0.040919  0.120909
# (TP_percentage, m)                                  0.003660  0.115567
# (TP_percentage, p)                                 -0.005864  0.116707
# (satisfaction_threshold, uncertainty_threshold)    -0.042161  0.115455
# (satisfaction_threshold, epsilon)                  -0.026101  0.108195
# (satisfaction_threshold, min_increase_percentage)  -0.048184  0.100832
# (satisfaction_threshold, max_increase_percentage)  -0.046238  0.107074
# (satisfaction_threshold, m)                        -0.035924  0.112421
# (satisfaction_threshold, p)                        -0.034009  0.107109
# (uncertainty_threshold, epsilon)                   -0.025583  0.111749
# (uncertainty_threshold, min_increase_percentage)   -0.020202  0.109620
# (uncertainty_threshold, max_increase_percentage)   -0.020508  0.111288
# (uncertainty_threshold, m)                         -0.053952  0.122814
# (uncertainty_threshold, p)                         -0.009987  0.107627
# (epsilon, min_increase_percentage)                  0.039273  0.074712
# (epsilon, max_increase_percentage)                  0.037273  0.074326
# (epsilon, m)                                        0.038134  0.074705
# (epsilon, p)                                        0.047917  0.074904
# (min_increase_percentage, max_increase_percentage)  0.020941  0.036908
# (min_increase_percentage, m)                        0.018888  0.037152
# (min_increase_percentage, p)                        0.016247  0.038741
# (max_increase_percentage, m)                       -0.003334  0.062859
# (max_increase_percentage, p)                        0.007496  0.059023
# (m, p)                                             -0.018225  0.097472
# Sensitivity analysis for Avg_S_Uncertainty (Holme-Kim network):
# {'S1': array([ 0.37881206,  0.03817148,  0.15571444,  0.00066535, -0.01271126,
#         0.00598891,  0.02675745, -0.01809542]), 'S1_conf': array([0.1218068 , 0.08025168, 0.11054472, 0.04974069, 0.02796271,
#        0.04640799, 0.06038236, 0.06138103]), 'ST': array([0.6623812 , 0.25866302, 0.46111825, 0.07856278, 0.03747284,
#        0.07395384, 0.14755793, 0.18166485]), 'ST_conf': array([0.12284193, 0.09219566, 0.10613101, 0.0488647 , 0.03250003,
#        0.05996115, 0.06853018, 0.07227129]), 'S2': array([[        nan,  0.06810677,  0.15074454,  0.02341533,  0.01495254,
#          0.04091875,  0.00365986, -0.00586446],
#        [        nan,         nan, -0.04216133, -0.02610148, -0.04818388,
#         -0.0462382 , -0.0359235 , -0.03400928],
#        [        nan,         nan,         nan, -0.02558348, -0.02020213,
#         -0.02050828, -0.05395166, -0.00998674],
#        [        nan,         nan,         nan,         nan,  0.03927309,
#          0.03727291,  0.03813431,  0.04791682],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.02094063,  0.01888813,  0.01624709],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.00333367,  0.00749645],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan, -0.01822465],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.1483732 , 0.12826367, 0.12213167, 0.12068182,
#         0.12090871, 0.11556722, 0.11670689],
#        [       nan,        nan, 0.11545482, 0.10819481, 0.100832  ,
#         0.10707423, 0.1124206 , 0.10710859],
#        [       nan,        nan,        nan, 0.11174886, 0.10961954,
#         0.11128782, 0.12281423, 0.10762738],
#        [       nan,        nan,        nan,        nan, 0.07471211,
#         0.07432589, 0.07470512, 0.07490444],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.03690761, 0.0371518 , 0.03874138],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.06285883, 0.05902343],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.09747166],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.145536  0.107843
# satisfaction_threshold   0.671369  0.209803
# uncertainty_threshold    0.701549  0.169779
# epsilon                  0.386349  0.161598
# min_increase_percentage  0.269993  0.149924
# max_increase_percentage  0.328731  0.163993
# m                        0.728961  0.245161
# p                        0.603856  0.198448
#                                S1   S1_conf
# TP_percentage           -0.009381  0.048261
# satisfaction_threshold   0.156659  0.129711
# uncertainty_threshold    0.291396  0.184166
# epsilon                  0.022622  0.081662
# min_increase_percentage -0.031559  0.072011
# max_increase_percentage  0.002867  0.080425
# m                        0.123075  0.099559
# p                        0.110154  0.178639
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.049154  0.103754
# (TP_percentage, uncertainty_threshold)             -0.047111  0.123625
# (TP_percentage, epsilon)                            0.071934  0.094522
# (TP_percentage, min_increase_percentage)            0.071839  0.093672
# (TP_percentage, max_increase_percentage)            0.072276  0.098178
# (TP_percentage, m)                                 -0.010967  0.072175
# (TP_percentage, p)                                  0.017626  0.072387
# (satisfaction_threshold, uncertainty_threshold)    -0.105880  0.190656
# (satisfaction_threshold, epsilon)                  -0.078173  0.172340
# (satisfaction_threshold, min_increase_percentage)  -0.063880  0.160898
# (satisfaction_threshold, max_increase_percentage)  -0.041857  0.164790
# (satisfaction_threshold, m)                        -0.110546  0.166114
# (satisfaction_threshold, p)                        -0.082110  0.185517
# (uncertainty_threshold, epsilon)                   -0.105592  0.237746
# (uncertainty_threshold, min_increase_percentage)   -0.177464  0.222729
# (uncertainty_threshold, max_increase_percentage)   -0.121339  0.230988
# (uncertainty_threshold, m)                         -0.196626  0.252453
# (uncertainty_threshold, p)                         -0.181507  0.257166
# (epsilon, min_increase_percentage)                  0.099172  0.183526
# (epsilon, max_increase_percentage)                  0.103388  0.189432
# (epsilon, m)                                       -0.037698  0.117714
# (epsilon, p)                                       -0.018273  0.096523
# (min_increase_percentage, max_increase_percentage)  0.057047  0.073306
# (min_increase_percentage, m)                        0.040722  0.068536
# (min_increase_percentage, p)                       -0.010741  0.129250
# (max_increase_percentage, m)                       -0.035159  0.104314
# (max_increase_percentage, p)                        0.055294  0.135809
# (m, p)                                              0.050639  0.185704
# Sensitivity analysis for Avg_P_Uncertainty (Holme-Kim network):
# {'S1': array([-0.00938139,  0.15665932,  0.29139618,  0.02262209, -0.03155929,
#         0.00286688,  0.12307494,  0.1101542 ]), 'S1_conf': array([0.04826102, 0.1297113 , 0.18416569, 0.08166205, 0.072011  ,
#        0.08042452, 0.09955922, 0.17863899]), 'ST': array([0.14553581, 0.67136941, 0.70154857, 0.38634866, 0.26999298,
#        0.32873064, 0.72896072, 0.60385614]), 'ST_conf': array([0.10784311, 0.2098026 , 0.16977942, 0.16159839, 0.14992414,
#        0.16399309, 0.24516115, 0.19844767]), 'S2': array([[        nan,  0.04915388, -0.04711132,  0.07193362,  0.07183939,
#          0.07227615, -0.01096688,  0.01762581],
#        [        nan,         nan, -0.10588014, -0.07817274, -0.06387986,
#         -0.04185704, -0.11054634, -0.0821096 ],
#        [        nan,         nan,         nan, -0.10559232, -0.17746435,
#         -0.12133911, -0.19662626, -0.18150729],
#        [        nan,         nan,         nan,         nan,  0.09917239,
#          0.10338789, -0.03769788, -0.01827286],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.05704723,  0.04072215, -0.01074079],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.03515904,  0.05529365],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,  0.05063865],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.10375444, 0.12362497, 0.09452178, 0.09367239,
#         0.09817831, 0.0721749 , 0.0723874 ],
#        [       nan,        nan, 0.19065586, 0.17233998, 0.16089797,
#         0.16478965, 0.16611411, 0.18551688],
#        [       nan,        nan,        nan, 0.23774635, 0.22272908,
#         0.23098837, 0.25245294, 0.25716564],
#        [       nan,        nan,        nan,        nan, 0.18352595,
#         0.18943164, 0.11771382, 0.09652329],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.07330572, 0.06853606, 0.12924995],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.10431399, 0.13580877],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.18570429],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}

# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

base_config = {
    'TP_percentage': 0.7,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['preference_conformity'],
    'seed': 42  # Seed for reproducibility
}

# Configuration for Watts-Strogatz network
watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


# Configuration for Barabasi-Albert network
barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

# Configuration for Random Regular network
random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

# Configuration for Holme-Kim network
holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})


network_configs = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}
network_configurations = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}


# Define the model inputs for each network type
network_problems = {
    'Watts-Strogatz': {
        'num_vars': 8,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon', 'min_increase_percentage','max_increase_percentage', 'k', 'p'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1], [1,10], [11,20], [2, 10], [0, 1]] 
    },
    'Barabasi-Albert': {
        'num_vars': 7,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold','epsilon','min_increase_percentage', 'max_increase_percentage', 'm'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1],[1,10], [11,20],[2, 10]]  
    },
    'Random Regular': {
        'num_vars': 7,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon','min_increase_percentage','max_increase_percentage','d'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1],[1,10], [11,20],[2, 10]]  
    },
    'Holme-Kim': {
        'num_vars': 8,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon','min_increase_percentage','max_increase_percentage','m', 'p'],
        'bounds': [[0, 1], [0, 1], [0, 1],[0,1], [1,10], [11,20],[2, 10], [0, 1]] 
    }
}
# Number of samples
num_samples = 256

# Generate samples for each network problem
samples = {}
for network_name, problem in network_problems.items():
    samples[network_name] = saltelli.sample(problem, num_samples)

from joblib import Parallel, delayed
import numpy as np
import pandas as pd
from tqdm import tqdm
from SALib.sample import saltelli
from SALib.analyze import sobol
import json

def collect_simulation_data(model, num_steps):
    collected_data = {
        'Step': [],
        'Adoption Rate': [],
        'Avg_F_Satisfaction': [],
        'Avg_S_Satisfaction': [],
        'Avg_P_Satisfaction': [],
        'Avg_F_Uncertainty': [],
        'Avg_S_Uncertainty': [],
        'Avg_P_Uncertainty': []
    }

    for step in range(num_steps):
        model.step()
        collected_data['Step'].append(step)
        collected_data['Adoption Rate'].append(model.calculate_true_price_adoption_rate())
        collected_data['Avg_F_Satisfaction'].append(np.mean([agent.F_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_S_Satisfaction'].append(np.mean([agent.S_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_P_Satisfaction'].append(np.mean([agent.P_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_F_Uncertainty'].append(np.mean([agent.F_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_S_Uncertainty'].append(np.mean([agent.S_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_P_Uncertainty'].append(np.mean([agent.P_uncertainty for agent in model.schedule.agents]))

    model_data = pd.DataFrame(collected_data)
    return model_data

def run_single_simulation(params, config, network_name, num_steps):
    config = config.copy()
    config['TP_percentage'] = params[0]
    config['satisfaction_threshold'] = params[1]
    config['uncertainty_threshold'] = params[2]
    config['epsilon'] = params[3]
    config['min_increase_percentage'] = params[4]
    config['max_increase_percentage'] = params[5]

    if network_name == 'Watts-Strogatz':
        config['network_params']['k'] = int(params[6])
        config['network_params']['p'] = params[7]
    elif network_name == 'Barabasi-Albert':
        config['network_params']['m'] = int(params[6])
    elif network_name == 'Random Regular':
        config['network_params']['d'] = int(params[6])
    elif network_name == 'Holme-Kim':
        config['network_params']['m'] = int(params[6])
        config['network_params']['p'] = params[7]

    model = ConsumatModel(config)
    model_data = collect_simulation_data(model, num_steps)
    final_step_data = model_data.iloc[-1]

    return [
        final_step_data['Adoption Rate'],
        final_step_data['Avg_F_Satisfaction'],
        final_step_data['Avg_S_Satisfaction'],
        final_step_data['Avg_P_Satisfaction'],
        final_step_data['Avg_F_Uncertainty'],
        final_step_data['Avg_S_Uncertainty'],
        final_step_data['Avg_P_Uncertainty']
    ]

def run_gsa_simulation_parallel(network_name, config, samples, num_steps, n_jobs=-1):
    all_results = Parallel(n_jobs=n_jobs)(
        delayed(run_single_simulation)(params, config, network_name, num_steps)
        for params in tqdm(samples, desc=f'Running simulations for {network_name}')
    )
    return np.array(all_results)

num_steps = 10

# Run GSA for each network
for network_name, config in network_configurations.items():
    print(f"Running GSA for {network_name} network...")
    config = base_config.copy()
    config.update(network_configs[network_name])
    all_results = run_gsa_simulation_parallel(network_name, config, samples[network_name], num_steps)
    
    results = {}
    
    # Perform Sobol sensitivity analysis
    for i, output in enumerate(['Adoption Rate', 'Avg_F_Satisfaction', 'Avg_S_Satisfaction', 'Avg_P_Satisfaction', 'Avg_F_Uncertainty', 'Avg_S_Uncertainty', 'Avg_P_Uncertainty']):
        Si = sobol.analyze(network_problems[network_name], all_results[:, i], print_to_console=True)
        results[output] = {
            'S1': Si['S1'].tolist(),
            'ST': Si['ST'].tolist(),
            'S2': Si['S2'].tolist(),
            'S1_conf': Si['S1_conf'].tolist(),
            'ST_conf': Si['ST_conf'].tolist()
        }
        print(f'Sensitivity analysis for {output} ({network_name} network):')
        print(Si)
    
    # Save results to a JSON file
    with open(f'dynamic_sensitivity_results_preferenceconformity_{network_name}.json', 'w') as f:
        json.dump(results, f)
# Out:
# C:\Users\elpha\AppData\Local\Temp\ipykernel_9568\595342797.py:109: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5. Please use `salib.sample.sobol`
#   samples[network_name] = saltelli.sample(problem, num_samples)
# Running GSA for Watts-Strogatz network...
# Running simulations for Watts-Strogatz: 100%|████████████████████████████████████| 4608/4608 [1:40:40<00:00,  1.31s/it]
#                                ST   ST_conf
# TP_percentage            1.053004  0.152218
# satisfaction_threshold   0.080439  0.040887
# uncertainty_threshold    0.068657  0.036735
# epsilon                  0.004393  0.003313
# min_increase_percentage  0.031835  0.037776
# max_increase_percentage  0.015479  0.024699
# k                        0.048789  0.033864
# p                        0.050339  0.034070
#                                S1   S1_conf
# TP_percentage            0.917953  0.133047
# satisfaction_threshold   0.003046  0.047656
# uncertainty_threshold    0.014848  0.049038
# epsilon                  0.005780  0.011388
# min_increase_percentage  0.016195  0.028807
# max_increase_percentage -0.000753  0.023285
# k                        0.000665  0.037091
# p                       -0.015750  0.040662
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.068249  0.089942
# (TP_percentage, uncertainty_threshold)             -0.005507  0.079059
# (TP_percentage, epsilon)                           -0.001261  0.076063
# (TP_percentage, min_increase_percentage)           -0.030221  0.075243
# (TP_percentage, max_increase_percentage)            0.006934  0.073831
# (TP_percentage, k)                                  0.009031  0.083439
# (TP_percentage, p)                                  0.037465  0.098346
# (satisfaction_threshold, uncertainty_threshold)     0.028109  0.068854
# (satisfaction_threshold, epsilon)                   0.007719  0.070369
# (satisfaction_threshold, min_increase_percentage)   0.006640  0.070066
# (satisfaction_threshold, max_increase_percentage)   0.002150  0.069437
# (satisfaction_threshold, k)                         0.012604  0.071118
# (satisfaction_threshold, p)                         0.009140  0.071062
# (uncertainty_threshold, epsilon)                    0.003854  0.066812
# (uncertainty_threshold, min_increase_percentage)    0.001137  0.066610
# (uncertainty_threshold, max_increase_percentage)    0.002125  0.066526
# (uncertainty_threshold, k)                         -0.000472  0.066258
# (uncertainty_threshold, p)                          0.005236  0.068926
# (epsilon, min_increase_percentage)                  0.027286  0.028914
# (epsilon, max_increase_percentage)                  0.027039  0.028652
# (epsilon, k)                                        0.027735  0.028881
# (epsilon, p)                                        0.028164  0.028990
# (min_increase_percentage, max_increase_percentage) -0.017541  0.035532
# (min_increase_percentage, k)                       -0.017326  0.035273
# (min_increase_percentage, p)                       -0.016597  0.035796
# (max_increase_percentage, k)                        0.017097  0.037287
# (max_increase_percentage, p)                        0.017645  0.038015
# (k, p)                                              0.027340  0.052855
# Sensitivity analysis for Adoption Rate (Watts-Strogatz network):
# {'S1': array([ 9.17953084e-01,  3.04568690e-03,  1.48477802e-02,  5.78021357e-03,
#         1.61947728e-02, -7.53426286e-04,  6.64938007e-04, -1.57496085e-02]), 'S1_conf': array([0.13304709, 0.04765603, 0.04903777, 0.01138818, 0.0288074 ,
#        0.02328545, 0.03709121, 0.04066247]), 'ST': array([1.05300354, 0.08043929, 0.06865692, 0.00439331, 0.03183467,
#        0.01547882, 0.04878874, 0.05033858]), 'ST_conf': array([0.15221829, 0.04088729, 0.03673457, 0.00331289, 0.03777641,
#        0.02469896, 0.03386385, 0.03407037]), 'S2': array([[        nan,  0.06824856, -0.00550713, -0.00126078, -0.03022069,
#          0.00693436,  0.00903082,  0.03746539],
#        [        nan,         nan,  0.02810949,  0.00771883,  0.00664027,
#          0.00214984,  0.01260404,  0.00914011],
#        [        nan,         nan,         nan,  0.00385373,  0.00113743,
#          0.00212522, -0.00047181,  0.00523581],
#        [        nan,         nan,         nan,         nan,  0.02728581,
#          0.02703911,  0.02773549,  0.02816388],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.01754055, -0.01732647, -0.01659703],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.01709704,  0.01764496],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,  0.02733951],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.08994202, 0.07905944, 0.07606295, 0.0752426 ,
#         0.0738309 , 0.08343917, 0.0983462 ],
#        [       nan,        nan, 0.06885364, 0.07036869, 0.07006622,
#         0.0694373 , 0.07111758, 0.07106181],
#        [       nan,        nan,        nan, 0.06681231, 0.06661028,
#         0.06652621, 0.06625759, 0.06892607],
#        [       nan,        nan,        nan,        nan, 0.02891374,
#         0.02865201, 0.0288811 , 0.02898954],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.03553165, 0.03527334, 0.03579587],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.03728671, 0.03801456],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.05285454],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.112905  0.033569
# satisfaction_threshold   0.643202  0.139514
# uncertainty_threshold    0.484620  0.120657
# epsilon                  0.024799  0.011328
# min_increase_percentage  0.056827  0.083885
# max_increase_percentage  0.150755  0.205314
# k                        0.068348  0.029671
# p                        0.191844  0.084045
#                                S1   S1_conf
# TP_percentage           -0.016696  0.061953
# satisfaction_threshold   0.314695  0.137690
# uncertainty_threshold    0.113737  0.115111
# epsilon                 -0.010287  0.027224
# min_increase_percentage -0.024582  0.029963
# max_increase_percentage  0.007364  0.074204
# k                       -0.035141  0.041337
# p                        0.001890  0.068495
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.086811  0.095515
# (TP_percentage, uncertainty_threshold)              0.024069  0.103536
# (TP_percentage, epsilon)                           -0.002877  0.088911
# (TP_percentage, min_increase_percentage)            0.002946  0.094161
# (TP_percentage, max_increase_percentage)           -0.005289  0.088809
# (TP_percentage, k)                                 -0.011273  0.089597
# (TP_percentage, p)                                  0.002961  0.084343
# (satisfaction_threshold, uncertainty_threshold)     0.307842  0.183166
# (satisfaction_threshold, epsilon)                   0.116194  0.152801
# (satisfaction_threshold, min_increase_percentage)   0.160213  0.148419
# (satisfaction_threshold, max_increase_percentage)   0.033128  0.215433
# (satisfaction_threshold, k)                         0.157366  0.145219
# (satisfaction_threshold, p)                         0.173166  0.147397
# (uncertainty_threshold, epsilon)                    0.080566  0.144123
# (uncertainty_threshold, min_increase_percentage)    0.081202  0.137107
# (uncertainty_threshold, max_increase_percentage)    0.040919  0.146450
# (uncertainty_threshold, k)                          0.093171  0.151718
# (uncertainty_threshold, p)                          0.143696  0.159013
# (epsilon, min_increase_percentage)                 -0.013223  0.052401
# (epsilon, max_increase_percentage)                 -0.025699  0.053098
# (epsilon, k)                                       -0.022272  0.056540
# (epsilon, p)                                       -0.015277  0.051048
# (min_increase_percentage, max_increase_percentage)  0.020612  0.043594
# (min_increase_percentage, k)                        0.017417  0.045299
# (min_increase_percentage, p)                        0.032948  0.042625
# (max_increase_percentage, k)                        0.011965  0.081843
# (max_increase_percentage, p)                        0.018579  0.079797
# (k, p)                                              0.069874  0.139226
# Sensitivity analysis for Avg_F_Satisfaction (Watts-Strogatz network):
# {'S1': array([-0.01669644,  0.31469527,  0.11373711, -0.01028734, -0.02458176,
#         0.00736352, -0.0351409 ,  0.00188993]), 'S1_conf': array([0.0619526 , 0.13768986, 0.11511134, 0.02722363, 0.02996325,
#        0.07420439, 0.04133682, 0.06849486]), 'ST': array([0.1129046 , 0.64320161, 0.4846203 , 0.02479912, 0.0568273 ,
#        0.15075458, 0.06834756, 0.1918444 ]), 'ST_conf': array([0.03356929, 0.13951435, 0.12065718, 0.0113275 , 0.08388508,
#        0.20531421, 0.02967075, 0.08404451]), 'S2': array([[        nan,  0.08681058,  0.02406886, -0.00287669,  0.00294649,
#         -0.00528949, -0.01127289,  0.00296082],
#        [        nan,         nan,  0.30784244,  0.11619422,  0.16021318,
#          0.03312815,  0.15736631,  0.17316602],
#        [        nan,         nan,         nan,  0.08056565,  0.08120193,
#          0.0409192 ,  0.0931705 ,  0.14369559],
#        [        nan,         nan,         nan,         nan, -0.01322265,
#         -0.0256994 , -0.02227242, -0.0152768 ],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.02061228,  0.01741708,  0.03294757],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.01196532,  0.01857851],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,  0.06987401],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.09551459, 0.10353619, 0.08891075, 0.09416052,
#         0.08880907, 0.08959664, 0.08434343],
#        [       nan,        nan, 0.18316603, 0.15280085, 0.14841878,
#         0.21543324, 0.14521895, 0.14739738],
#        [       nan,        nan,        nan, 0.14412304, 0.13710703,
#         0.14645004, 0.15171845, 0.1590133 ],
#        [       nan,        nan,        nan,        nan, 0.05240094,
#         0.05309796, 0.05653981, 0.05104802],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.04359432, 0.04529917, 0.04262514],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.08184344, 0.07979721],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.13922635],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.162295  0.054328
# satisfaction_threshold   0.204296  0.078109
# uncertainty_threshold    0.164465  0.058010
# epsilon                  0.012276  0.008754
# min_increase_percentage  0.006764  0.006336
# max_increase_percentage  0.004169  0.004102
# k                        0.459363  0.149316
# p                        0.461700  0.143601
#                                S1   S1_conf
# TP_percentage            0.119673  0.066618
# satisfaction_threshold   0.070048  0.077081
# uncertainty_threshold   -0.010799  0.072337
# epsilon                  0.004656  0.019376
# min_increase_percentage -0.011330  0.014846
# max_increase_percentage -0.010514  0.009191
# k                        0.143452  0.145300
# p                        0.118115  0.130051
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.023548  0.116385
# (TP_percentage, uncertainty_threshold)             -0.002530  0.118936
# (TP_percentage, epsilon)                           -0.032715  0.109409
# (TP_percentage, min_increase_percentage)           -0.032464  0.102253
# (TP_percentage, max_increase_percentage)           -0.031786  0.106742
# (TP_percentage, k)                                  0.021233  0.108155
# (TP_percentage, p)                                 -0.025431  0.107555
# (satisfaction_threshold, uncertainty_threshold)     0.152334  0.122547
# (satisfaction_threshold, epsilon)                   0.069195  0.111134
# (satisfaction_threshold, min_increase_percentage)   0.077434  0.114234
# (satisfaction_threshold, max_increase_percentage)   0.081131  0.116197
# (satisfaction_threshold, k)                         0.003089  0.116614
# (satisfaction_threshold, p)                         0.063067  0.133655
# (uncertainty_threshold, epsilon)                    0.030002  0.106908
# (uncertainty_threshold, min_increase_percentage)    0.041452  0.100477
# (uncertainty_threshold, max_increase_percentage)    0.037832  0.103840
# (uncertainty_threshold, k)                          0.064783  0.093775
# (uncertainty_threshold, p)                          0.031852  0.088269
# (epsilon, min_increase_percentage)                 -0.007449  0.022025
# (epsilon, max_increase_percentage)                 -0.006743  0.022060
# (epsilon, k)                                       -0.013246  0.024399
# (epsilon, p)                                       -0.014399  0.031432
# (min_increase_percentage, max_increase_percentage)  0.011655  0.025382
# (min_increase_percentage, k)                        0.007098  0.025122
# (min_increase_percentage, p)                        0.008617  0.026678
# (max_increase_percentage, k)                        0.016556  0.022846
# (max_increase_percentage, p)                       -0.005468  0.022924
# (k, p)                                              0.243123  0.235940
# Sensitivity analysis for Avg_S_Satisfaction (Watts-Strogatz network):
# {'S1': array([ 0.11967308,  0.07004811, -0.01079919,  0.00465623, -0.01133044,
#        -0.01051422,  0.14345186,  0.11811519]), 'S1_conf': array([0.06661793, 0.07708146, 0.07233679, 0.0193759 , 0.01484552,
#        0.00919119, 0.14529972, 0.13005112]), 'ST': array([0.16229499, 0.2042955 , 0.16446534, 0.01227593, 0.00676384,
#        0.00416922, 0.45936327, 0.46170004]), 'ST_conf': array([0.05432769, 0.0781091 , 0.05800973, 0.00875385, 0.00633638,
#        0.00410168, 0.14931572, 0.14360076]), 'S2': array([[        nan,  0.02354788, -0.00253036, -0.03271462, -0.03246437,
#         -0.03178575,  0.02123251, -0.02543106],
#        [        nan,         nan,  0.15233445,  0.06919516,  0.07743366,
#          0.08113146,  0.00308937,  0.06306726],
#        [        nan,         nan,         nan,  0.03000244,  0.04145215,
#          0.0378318 ,  0.06478326,  0.03185226],
#        [        nan,         nan,         nan,         nan, -0.00744903,
#         -0.00674321, -0.01324598, -0.01439909],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.01165456,  0.00709778,  0.00861738],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.01655637, -0.00546809],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,  0.2431231 ],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.1163851 , 0.11893641, 0.10940904, 0.10225301,
#         0.1067423 , 0.10815495, 0.10755465],
#        [       nan,        nan, 0.12254717, 0.11113361, 0.11423389,
#         0.11619747, 0.11661392, 0.13365521],
#        [       nan,        nan,        nan, 0.10690846, 0.1004771 ,
#         0.1038396 , 0.09377466, 0.08826935],
#        [       nan,        nan,        nan,        nan, 0.02202529,
#         0.02205978, 0.02439936, 0.03143176],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.02538171, 0.02512161, 0.02667796],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.02284598, 0.02292406],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.23594033],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.083032  0.048247
# satisfaction_threshold   0.906294  0.181709
# uncertainty_threshold    0.422557  0.146781
# epsilon                  0.121897  0.091826
# min_increase_percentage  0.071985  0.059340
# max_increase_percentage  0.084252  0.066100
# k                        0.174130  0.094447
# p                        0.248269  0.078869
#                                S1   S1_conf
# TP_percentage           -0.000114  0.038026
# satisfaction_threshold   0.460047  0.143650
# uncertainty_threshold    0.053712  0.097834
# epsilon                 -0.002582  0.049518
# min_increase_percentage -0.011858  0.044071
# max_increase_percentage -0.013224  0.052554
# k                        0.019911  0.065923
# p                        0.036836  0.090704
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.021553  0.072774
# (TP_percentage, uncertainty_threshold)              0.057771  0.055168
# (TP_percentage, epsilon)                            0.024292  0.060218
# (TP_percentage, min_increase_percentage)            0.002000  0.060177
# (TP_percentage, max_increase_percentage)            0.012879  0.057714
# (TP_percentage, k)                                  0.028453  0.062353
# (TP_percentage, p)                                 -0.030754  0.077984
# (satisfaction_threshold, uncertainty_threshold)     0.164724  0.166235
# (satisfaction_threshold, epsilon)                   0.184166  0.152307
# (satisfaction_threshold, min_increase_percentage)   0.127965  0.159830
# (satisfaction_threshold, max_increase_percentage)   0.115257  0.159975
# (satisfaction_threshold, k)                         0.143327  0.157864
# (satisfaction_threshold, p)                         0.137877  0.188491
# (uncertainty_threshold, epsilon)                   -0.075992  0.106864
# (uncertainty_threshold, min_increase_percentage)   -0.058908  0.106481
# (uncertainty_threshold, max_increase_percentage)   -0.080138  0.113757
# (uncertainty_threshold, k)                         -0.056910  0.121842
# (uncertainty_threshold, p)                         -0.082318  0.134045
# (epsilon, min_increase_percentage)                 -0.039983  0.064954
# (epsilon, max_increase_percentage)                 -0.037811  0.069042
# (epsilon, k)                                       -0.028723  0.062663
# (epsilon, p)                                       -0.039534  0.087209
# (min_increase_percentage, max_increase_percentage)  0.023561  0.056420
# (min_increase_percentage, k)                        0.021541  0.058184
# (min_increase_percentage, p)                       -0.035659  0.081655
# (max_increase_percentage, k)                        0.025321  0.060551
# (max_increase_percentage, p)                       -0.021852  0.080621
# (k, p)                                             -0.043195  0.117743
# Sensitivity analysis for Avg_P_Satisfaction (Watts-Strogatz network):
# {'S1': array([-1.14236690e-04,  4.60046613e-01,  5.37122703e-02, -2.58205556e-03,
#        -1.18580414e-02, -1.32244615e-02,  1.99114794e-02,  3.68361676e-02]), 'S1_conf': array([0.03802593, 0.14364974, 0.09783353, 0.04951771, 0.04407094,
#        0.05255387, 0.06592312, 0.09070425]), 'ST': array([0.0830321 , 0.90629404, 0.42255741, 0.12189651, 0.07198483,
#        0.08425175, 0.17413029, 0.24826884]), 'ST_conf': array([0.04824684, 0.18170854, 0.14678095, 0.09182556, 0.05934005,
#        0.06610001, 0.09444723, 0.07886871]), 'S2': array([[        nan,  0.02155282,  0.05777138,  0.02429151,  0.00199965,
#          0.01287869,  0.02845303, -0.03075361],
#        [        nan,         nan,  0.16472392,  0.18416574,  0.12796541,
#          0.11525669,  0.14332675,  0.13787698],
#        [        nan,         nan,         nan, -0.07599186, -0.05890818,
#         -0.08013845, -0.05690961, -0.08231759],
#        [        nan,         nan,         nan,         nan, -0.03998271,
#         -0.03781085, -0.02872275, -0.03953355],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.02356121,  0.02154073, -0.03565879],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.02532132, -0.02185232],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan, -0.04319538],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.0727736 , 0.05516845, 0.06021766, 0.06017739,
#         0.05771396, 0.0623526 , 0.0779836 ],
#        [       nan,        nan, 0.16623521, 0.15230722, 0.15983014,
#         0.15997453, 0.15786426, 0.18849099],
#        [       nan,        nan,        nan, 0.10686425, 0.10648074,
#         0.11375685, 0.12184208, 0.13404537],
#        [       nan,        nan,        nan,        nan, 0.0649544 ,
#         0.06904192, 0.06266349, 0.0872092 ],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.05642008, 0.05818437, 0.08165518],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.06055062, 0.08062146],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.11774295],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.525932  0.133195
# satisfaction_threshold   0.418122  0.097746
# uncertainty_threshold    0.258250  0.075419
# epsilon                  0.092381  0.097766
# min_increase_percentage  0.304054  0.311437
# max_increase_percentage  0.349385  0.253716
# k                        0.283911  0.176085
# p                        0.478068  0.351014
#                                S1   S1_conf
# TP_percentage            0.289678  0.104145
# satisfaction_threshold   0.037388  0.097715
# uncertainty_threshold   -0.001719  0.063645
# epsilon                 -0.009018  0.031067
# min_increase_percentage -0.006127  0.035785
# max_increase_percentage  0.093234  0.127921
# k                       -0.023707  0.054444
# p                       -0.049577  0.133038
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.176520  0.181961
# (TP_percentage, uncertainty_threshold)              0.095467  0.128331
# (TP_percentage, epsilon)                            0.072042  0.134612
# (TP_percentage, min_increase_percentage)           -0.006618  0.142636
# (TP_percentage, max_increase_percentage)            0.037161  0.143477
# (TP_percentage, k)                                  0.083512  0.134736
# (TP_percentage, p)                                  0.158693  0.134694
# (satisfaction_threshold, uncertainty_threshold)     0.131311  0.158974
# (satisfaction_threshold, epsilon)                   0.127459  0.134425
# (satisfaction_threshold, min_increase_percentage)   0.161809  0.130485
# (satisfaction_threshold, max_increase_percentage)   0.082823  0.157889
# (satisfaction_threshold, k)                         0.158191  0.136600
# (satisfaction_threshold, p)                         0.117980  0.153147
# (uncertainty_threshold, epsilon)                   -0.031115  0.096378
# (uncertainty_threshold, min_increase_percentage)   -0.041595  0.092602
# (uncertainty_threshold, max_increase_percentage)   -0.097550  0.153285
# (uncertainty_threshold, k)                         -0.027945  0.107031
# (uncertainty_threshold, p)                          0.036458  0.128150
# (epsilon, min_increase_percentage)                  0.009771  0.075773
# (epsilon, max_increase_percentage)                  0.008796  0.067487
# (epsilon, k)                                        0.009234  0.070078
# (epsilon, p)                                        0.052970  0.098905
# (min_increase_percentage, max_increase_percentage) -0.002121  0.055592
# (min_increase_percentage, k)                       -0.006668  0.051128
# (min_increase_percentage, p)                       -0.025453  0.054564
# (max_increase_percentage, k)                       -0.064707  0.143202
# (max_increase_percentage, p)                       -0.061697  0.137489
# (k, p)                                              0.194129  0.289499
# Sensitivity analysis for Avg_F_Uncertainty (Watts-Strogatz network):
# {'S1': array([ 0.28967758,  0.03738794, -0.00171912, -0.00901786, -0.0061271 ,
#         0.09323401, -0.0237073 , -0.04957728]), 'S1_conf': array([0.1041447 , 0.09771521, 0.0636445 , 0.03106704, 0.03578487,
#        0.12792088, 0.05444428, 0.13303838]), 'ST': array([0.5259319 , 0.41812163, 0.25825011, 0.09238089, 0.30405364,
#        0.34938542, 0.28391057, 0.47806758]), 'ST_conf': array([0.13319541, 0.09774589, 0.07541889, 0.09776562, 0.31143733,
#        0.25371605, 0.17608529, 0.35101363]), 'S2': array([[        nan,  0.17651972,  0.09546684,  0.07204175, -0.00661849,
#          0.03716115,  0.08351174,  0.15869324],
#        [        nan,         nan,  0.1313114 ,  0.12745922,  0.16180906,
#          0.0828226 ,  0.15819109,  0.11797959],
#        [        nan,         nan,         nan, -0.03111475, -0.04159462,
#         -0.09755041, -0.02794499,  0.03645775],
#        [        nan,         nan,         nan,         nan,  0.00977108,
#          0.00879645,  0.00923418,  0.05297017],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.00212075, -0.0066679 , -0.02545263],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.06470715, -0.06169699],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,  0.19412949],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.18196054, 0.12833069, 0.1346118 , 0.14263613,
#         0.14347684, 0.1347363 , 0.13469392],
#        [       nan,        nan, 0.15897428, 0.13442511, 0.13048489,
#         0.15788908, 0.13659973, 0.15314666],
#        [       nan,        nan,        nan, 0.09637751, 0.09260175,
#         0.15328483, 0.10703088, 0.12814963],
#        [       nan,        nan,        nan,        nan, 0.07577272,
#         0.06748674, 0.07007759, 0.09890483],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.05559222, 0.05112755, 0.05456411],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.14320185, 0.13748898],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.28949949],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.838393  0.115289
# satisfaction_threshold   0.168474  0.083185
# uncertainty_threshold    0.167427  0.079924
# epsilon                  0.013751  0.012296
# min_increase_percentage  0.044946  0.039862
# max_increase_percentage  0.036226  0.046711
# k                        0.113510  0.063450
# p                        0.133231  0.062347
#                                S1   S1_conf
# TP_percentage            0.661160  0.147893
# satisfaction_threshold  -0.051017  0.080807
# uncertainty_threshold   -0.007402  0.077825
# epsilon                  0.007353  0.017747
# min_increase_percentage  0.017556  0.043151
# max_increase_percentage -0.001936  0.028413
# k                        0.016921  0.064277
# p                        0.023301  0.059263
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.148766  0.123672
# (TP_percentage, uncertainty_threshold)              0.035830  0.122411
# (TP_percentage, epsilon)                            0.045440  0.109949
# (TP_percentage, min_increase_percentage)            0.008875  0.127913
# (TP_percentage, max_increase_percentage)            0.057613  0.099898
# (TP_percentage, k)                                  0.034023  0.142296
# (TP_percentage, p)                                  0.052253  0.125717
# (satisfaction_threshold, uncertainty_threshold)     0.118174  0.086218
# (satisfaction_threshold, epsilon)                   0.086151  0.087892
# (satisfaction_threshold, min_increase_percentage)   0.086322  0.088414
# (satisfaction_threshold, max_increase_percentage)   0.083862  0.086868
# (satisfaction_threshold, k)                         0.085085  0.091096
# (satisfaction_threshold, p)                         0.054847  0.082995
# (uncertainty_threshold, epsilon)                    0.018529  0.097655
# (uncertainty_threshold, min_increase_percentage)    0.020155  0.096676
# (uncertainty_threshold, max_increase_percentage)    0.017133  0.097513
# (uncertainty_threshold, k)                          0.005759  0.097515
# (uncertainty_threshold, p)                          0.021437  0.094421
# (epsilon, min_increase_percentage)                  0.032084  0.050373
# (epsilon, max_increase_percentage)                  0.031291  0.049994
# (epsilon, k)                                        0.032447  0.051811
# (epsilon, p)                                        0.009662  0.036524
# (min_increase_percentage, max_increase_percentage) -0.019036  0.062877
# (min_increase_percentage, k)                       -0.013295  0.060938
# (min_increase_percentage, p)                       -0.020062  0.058858
# (max_increase_percentage, k)                        0.023406  0.060189
# (max_increase_percentage, p)                        0.008819  0.052188
# (k, p)                                             -0.001664  0.091293
# Sensitivity analysis for Avg_S_Uncertainty (Watts-Strogatz network):
# {'S1': array([ 0.66115969, -0.05101683, -0.00740205,  0.00735294,  0.01755552,
#        -0.0019362 ,  0.01692091,  0.02330113]), 'S1_conf': array([0.14789322, 0.08080741, 0.0778248 , 0.01774729, 0.04315143,
#        0.02841297, 0.06427664, 0.05926296]), 'ST': array([0.83839344, 0.16847388, 0.16742745, 0.01375074, 0.044946  ,
#        0.03622564, 0.11351024, 0.13323103]), 'ST_conf': array([0.11528932, 0.08318473, 0.07992427, 0.01229556, 0.03986154,
#        0.04671105, 0.06344988, 0.06234657]), 'S2': array([[        nan,  0.14876604,  0.03583029,  0.04543999,  0.00887464,
#          0.05761331,  0.03402283,  0.0522531 ],
#        [        nan,         nan,  0.118174  ,  0.08615138,  0.08632229,
#          0.08386186,  0.08508529,  0.05484719],
#        [        nan,         nan,         nan,  0.01852891,  0.02015453,
#          0.01713261,  0.00575874,  0.02143729],
#        [        nan,         nan,         nan,         nan,  0.03208442,
#          0.03129123,  0.03244712,  0.00966217],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.01903578, -0.01329475, -0.0200621 ],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.02340603,  0.00881896],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan, -0.00166402],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.12367202, 0.12241083, 0.109949  , 0.12791349,
#         0.0998984 , 0.14229598, 0.12571699],
#        [       nan,        nan, 0.08621841, 0.08789159, 0.08841379,
#         0.08686754, 0.09109598, 0.08299535],
#        [       nan,        nan,        nan, 0.09765467, 0.09667617,
#         0.0975134 , 0.097515  , 0.09442066],
#        [       nan,        nan,        nan,        nan, 0.05037277,
#         0.0499937 , 0.0518114 , 0.03652384],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.06287708, 0.06093835, 0.05885811],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.06018916, 0.05218821],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.09129323],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.120678  0.121605
# satisfaction_threshold   0.715668  0.169361
# uncertainty_threshold    0.685243  0.231943
# epsilon                  0.063636  0.045662
# min_increase_percentage  0.163570  0.188928
# max_increase_percentage  0.141277  0.107728
# k                        0.392985  0.253609
# p                        0.418259  0.134273
#                                S1   S1_conf
# TP_percentage            0.025359  0.056044
# satisfaction_threshold   0.231691  0.162251
# uncertainty_threshold    0.215816  0.123261
# epsilon                 -0.004591  0.047089
# min_increase_percentage  0.016048  0.058925
# max_increase_percentage -0.059350  0.044868
# k                        0.017617  0.093993
# p                       -0.016773  0.134145
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.006861  0.083669
# (TP_percentage, uncertainty_threshold)             -0.039443  0.083921
# (TP_percentage, epsilon)                           -0.039736  0.069774
# (TP_percentage, min_increase_percentage)           -0.053514  0.076309
# (TP_percentage, max_increase_percentage)           -0.045183  0.073877
# (TP_percentage, k)                                 -0.035420  0.077417
# (TP_percentage, p)                                 -0.012222  0.077272
# (satisfaction_threshold, uncertainty_threshold)     0.092045  0.180867
# (satisfaction_threshold, epsilon)                   0.011473  0.156056
# (satisfaction_threshold, min_increase_percentage)   0.008753  0.147399
# (satisfaction_threshold, max_increase_percentage)   0.002554  0.141361
# (satisfaction_threshold, k)                        -0.023171  0.153612
# (satisfaction_threshold, p)                         0.068487  0.192251
# (uncertainty_threshold, epsilon)                   -0.105223  0.156910
# (uncertainty_threshold, min_increase_percentage)   -0.120056  0.157525
# (uncertainty_threshold, max_increase_percentage)   -0.103902  0.156281
# (uncertainty_threshold, k)                         -0.141234  0.163579
# (uncertainty_threshold, p)                         -0.086154  0.160850
# (epsilon, min_increase_percentage)                 -0.076217  0.119190
# (epsilon, max_increase_percentage)                 -0.077479  0.116485
# (epsilon, k)                                       -0.073006  0.113932
# (epsilon, p)                                        0.018446  0.093538
# (min_increase_percentage, max_increase_percentage) -0.077256  0.097298
# (min_increase_percentage, k)                       -0.073945  0.098133
# (min_increase_percentage, p)                       -0.018326  0.081696
# (max_increase_percentage, k)                       -0.009952  0.096854
# (max_increase_percentage, p)                        0.082350  0.076192
# (k, p)                                              0.012460  0.132759
# Sensitivity analysis for Avg_P_Uncertainty (Watts-Strogatz network):
# {'S1': array([ 0.02535936,  0.23169127,  0.21581642, -0.00459099,  0.01604761,
#        -0.05934966,  0.0176172 , -0.01677253]), 'S1_conf': array([0.0560442 , 0.16225104, 0.1232612 , 0.04708862, 0.05892487,
#        0.04486796, 0.09399332, 0.13414487]), 'ST': array([0.12067837, 0.71566769, 0.68524335, 0.06363561, 0.16356972,
#        0.14127745, 0.39298491, 0.4182589 ]), 'ST_conf': array([0.12160532, 0.16936068, 0.23194303, 0.0456619 , 0.1889278 ,
#        0.10772767, 0.25360872, 0.13427267]), 'S2': array([[        nan, -0.00686054, -0.03944335, -0.03973649, -0.05351354,
#         -0.04518289, -0.03542005, -0.01222228],
#        [        nan,         nan,  0.09204457,  0.01147291,  0.00875273,
#          0.00255389, -0.02317063,  0.06848695],
#        [        nan,         nan,         nan, -0.10522341, -0.12005628,
#         -0.10390167, -0.14123438, -0.08615432],
#        [        nan,         nan,         nan,         nan, -0.07621736,
#         -0.07747851, -0.07300607,  0.01844604],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.07725592, -0.07394493, -0.01832578],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.00995167,  0.08234991],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,  0.01245962],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.08366948, 0.08392097, 0.06977412, 0.07630925,
#         0.07387741, 0.07741726, 0.07727242],
#        [       nan,        nan, 0.18086703, 0.15605619, 0.14739874,
#         0.1413607 , 0.15361163, 0.19225128],
#        [       nan,        nan,        nan, 0.15690992, 0.15752464,
#         0.15628128, 0.16357905, 0.16084996],
#        [       nan,        nan,        nan,        nan, 0.11918992,
#         0.11648502, 0.11393186, 0.0935384 ],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.09729824, 0.09813282, 0.08169641],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.09685435, 0.07619245],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.13275895],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
# Running GSA for Barabasi-Albert network...
# Running simulations for Barabasi-Albert: 100%|███████████████████████████████████| 4096/4096 [2:42:10<00:00,  2.38s/it]
#                                ST   ST_conf
# TP_percentage            0.795915  0.133089
# satisfaction_threshold   0.157993  0.056581
# uncertainty_threshold    0.215174  0.065591
# epsilon                  0.046046  0.032731
# min_increase_percentage  0.000049  0.000026
# max_increase_percentage  0.017281  0.024918
# m                        0.153768  0.070502
#                                S1   S1_conf
# TP_percentage            0.538057  0.129084
# satisfaction_threshold   0.027533  0.062103
# uncertainty_threshold    0.015842  0.083729
# epsilon                 -0.004691  0.040129
# min_increase_percentage -0.000785  0.001353
# max_increase_percentage -0.002338  0.019914
# m                       -0.006801  0.067306
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.046700  0.146040
# (TP_percentage, uncertainty_threshold)              0.060964  0.144463
# (TP_percentage, epsilon)                            0.019262  0.135684
# (TP_percentage, min_increase_percentage)            0.013738  0.133497
# (TP_percentage, max_increase_percentage)            0.019651  0.129539
# (TP_percentage, m)                                  0.005280  0.151262
# (satisfaction_threshold, uncertainty_threshold)    -0.065402  0.081608
# (satisfaction_threshold, epsilon)                  -0.086975  0.087245
# (satisfaction_threshold, min_increase_percentage)  -0.090498  0.086591
# (satisfaction_threshold, max_increase_percentage)  -0.090950  0.087050
# (satisfaction_threshold, m)                        -0.078009  0.085251
# (uncertainty_threshold, epsilon)                    0.064074  0.103356
# (uncertainty_threshold, min_increase_percentage)    0.043920  0.109877
# (uncertainty_threshold, max_increase_percentage)    0.043376  0.109818
# (uncertainty_threshold, m)                          0.063348  0.102520
# (epsilon, min_increase_percentage)                  0.004721  0.056475
# (epsilon, max_increase_percentage)                  0.004114  0.056722
# (epsilon, m)                                        0.022192  0.060211
# (min_increase_percentage, max_increase_percentage)  0.001682  0.002106
# (min_increase_percentage, m)                        0.001053  0.002036
# (max_increase_percentage, m)                       -0.035477  0.052012
# Sensitivity analysis for Adoption Rate (Barabasi-Albert network):
# {'S1': array([ 0.53805666,  0.02753318,  0.01584222, -0.00469133, -0.00078489,
#        -0.00233815, -0.00680117]), 'S1_conf': array([0.12908377, 0.06210339, 0.08372874, 0.04012855, 0.00135305,
#        0.01991445, 0.06730606]), 'ST': array([7.95915243e-01, 1.57993310e-01, 2.15173636e-01, 4.60462932e-02,
#        4.93861365e-05, 1.72811375e-02, 1.53767842e-01]), 'ST_conf': array([1.33088603e-01, 5.65814241e-02, 6.55912096e-02, 3.27305871e-02,
#        2.59224964e-05, 2.49184415e-02, 7.05015671e-02]), 'S2': array([[        nan,  0.04669952,  0.06096371,  0.01926215,  0.01373769,
#          0.01965146,  0.00528002],
#        [        nan,         nan, -0.06540211, -0.08697463, -0.09049821,
#         -0.09094992, -0.07800861],
#        [        nan,         nan,         nan,  0.06407384,  0.04391973,
#          0.04337561,  0.06334754],
#        [        nan,         nan,         nan,         nan,  0.00472118,
#          0.00411382,  0.02219177],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.00168193,  0.00105339],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.03547652],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.14603985, 0.1444625 , 0.13568394, 0.13349686,
#         0.12953912, 0.15126204],
#        [       nan,        nan, 0.08160806, 0.0872446 , 0.08659109,
#         0.08704984, 0.08525132],
#        [       nan,        nan,        nan, 0.10335605, 0.10987692,
#         0.10981785, 0.10251986],
#        [       nan,        nan,        nan,        nan, 0.0564748 ,
#         0.05672163, 0.06021053],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.00210645, 0.00203574],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.05201231],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.129381  0.051814
# satisfaction_threshold   0.524134  0.141436
# uncertainty_threshold    0.635436  0.173830
# epsilon                  0.052361  0.026704
# min_increase_percentage  0.002340  0.001756
# max_increase_percentage  0.033881  0.023173
# m                        0.302762  0.150921
#                                S1   S1_conf
# TP_percentage            0.011789  0.068258
# satisfaction_threshold   0.358448  0.121091
# uncertainty_threshold    0.426159  0.144802
# epsilon                 -0.011562  0.039259
# min_increase_percentage -0.003313  0.008934
# max_increase_percentage -0.008004  0.026415
# m                        0.029183  0.151150
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.026067  0.088785
# (TP_percentage, uncertainty_threshold)              0.033923  0.086571
# (TP_percentage, epsilon)                            0.028826  0.088011
# (TP_percentage, min_increase_percentage)            0.029920  0.086798
# (TP_percentage, max_increase_percentage)            0.021739  0.091170
# (TP_percentage, m)                                  0.050310  0.105696
# (satisfaction_threshold, uncertainty_threshold)     0.024994  0.165356
# (satisfaction_threshold, epsilon)                  -0.035724  0.159609
# (satisfaction_threshold, min_increase_percentage)  -0.023061  0.148432
# (satisfaction_threshold, max_increase_percentage)  -0.005660  0.152856
# (satisfaction_threshold, m)                         0.067671  0.232907
# (uncertainty_threshold, epsilon)                    0.000557  0.121772
# (uncertainty_threshold, min_increase_percentage)   -0.006811  0.123179
# (uncertainty_threshold, max_increase_percentage)   -0.003069  0.117201
# (uncertainty_threshold, m)                          0.029668  0.169518
# (epsilon, min_increase_percentage)                  0.062851  0.057867
# (epsilon, max_increase_percentage)                  0.066046  0.058630
# (epsilon, m)                                        0.071655  0.067506
# (min_increase_percentage, max_increase_percentage)  0.007132  0.011464
# (min_increase_percentage, m)                        0.010455  0.011632
# (max_increase_percentage, m)                       -0.032416  0.123582
# Sensitivity analysis for Avg_F_Satisfaction (Barabasi-Albert network):
# {'S1': array([ 0.01178869,  0.35844752,  0.42615882, -0.01156213, -0.00331309,
#        -0.00800357,  0.02918349]), 'S1_conf': array([0.06825801, 0.12109072, 0.1448019 , 0.03925897, 0.00893423,
#        0.02641513, 0.15115038]), 'ST': array([0.12938145, 0.52413414, 0.63543613, 0.05236084, 0.00233993,
#        0.03388118, 0.30276167]), 'ST_conf': array([0.05181429, 0.14143616, 0.17382968, 0.02670362, 0.00175579,
#        0.02317303, 0.15092087]), 'S2': array([[        nan,  0.02606695,  0.03392333,  0.02882557,  0.02992049,
#          0.02173917,  0.05030964],
#        [        nan,         nan,  0.02499448, -0.03572383, -0.02306114,
#         -0.0056603 ,  0.06767124],
#        [        nan,         nan,         nan,  0.00055727, -0.0068111 ,
#         -0.00306929,  0.02966805],
#        [        nan,         nan,         nan,         nan,  0.06285142,
#          0.06604633,  0.07165479],
#        [        nan,         nan,         nan,         nan,         nan,
#          0.00713213,  0.01045452],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.03241582],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan]]), 'S2_conf': array([[       nan, 0.08878498, 0.08657088, 0.08801087, 0.08679832,
#         0.09117012, 0.1056962 ],
#        [       nan,        nan, 0.16535552, 0.15960861, 0.14843208,
#         0.15285642, 0.23290695],
#        [       nan,        nan,        nan, 0.12177244, 0.12317859,
#         0.11720108, 0.1695181 ],
#        [       nan,        nan,        nan,        nan, 0.05786692,
#         0.05863026, 0.0675059 ],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.01146371, 0.01163163],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.1235817 ],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.434123  0.115669
# satisfaction_threshold   0.587868  0.117095
# uncertainty_threshold    0.708061  0.161063
# epsilon                  0.107134  0.068622
# min_increase_percentage  0.001825  0.001071
# max_increase_percentage  0.003874  0.002875
# m                        0.080044  0.037437
#                                S1   S1_conf
# TP_percentage            0.213017  0.118127
# satisfaction_threshold   0.138610  0.183807
# uncertainty_threshold    0.165621  0.142220
# epsilon                 -0.014495  0.034305
# min_increase_percentage  0.001453  0.006833
# max_increase_percentage  0.003640  0.008289
# m                        0.054797  0.040491
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.002798  0.163699
# (TP_percentage, uncertainty_threshold)              0.117749  0.185840
# (TP_percentage, epsilon)                           -0.006747  0.147809
# (TP_percentage, min_increase_percentage)           -0.000761  0.150698
# (TP_percentage, max_increase_percentage)           -0.004025  0.150077
# (TP_percentage, m)                                 -0.009699  0.156655
# (satisfaction_threshold, uncertainty_threshold)     0.179957  0.250020
# (satisfaction_threshold, epsilon)                  -0.128750  0.161383
# (satisfaction_threshold, min_increase_percentage)  -0.149757  0.157918
# (satisfaction_threshold, max_increase_percentage)  -0.145885  0.158536
# (satisfaction_threshold, m)                        -0.159775  0.154323
# (uncertainty_threshold, epsilon)                   -0.058281  0.122209
# ...
# min_increase_percentage  0.059368  0.049849
# max_increase_percentage  0.178690  0.114641
# m                        0.363118  0.129700
# p                        0.313992  0.135058
#                                S1   S1_conf
# TP_percentage            0.057076  0.080333
# satisfaction_threshold   0.218429  0.144930
# uncertainty_threshold    0.252540  0.142555
# epsilon                  0.001315  0.075543
# min_increase_percentage  0.009401  0.042831
# max_increase_percentage  0.021428  0.070612
# m                        0.010257  0.085446
# p                        0.084612  0.089725
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.000074  0.114092
# (TP_percentage, uncertainty_threshold)              0.034529  0.121381
# (TP_percentage, epsilon)                            0.034584  0.122311
# (TP_percentage, min_increase_percentage)            0.001513  0.120105
# (TP_percentage, max_increase_percentage)            0.021773  0.115551
# (TP_percentage, m)                                  0.000515  0.127279
# (TP_percentage, p)                                 -0.017558  0.113141
# (satisfaction_threshold, uncertainty_threshold)    -0.101460  0.227326
# (satisfaction_threshold, epsilon)                   0.035553  0.169233
# (satisfaction_threshold, min_increase_percentage)   0.065588  0.159860
# (satisfaction_threshold, max_increase_percentage)  -0.010587  0.170151
# (satisfaction_threshold, m)                         0.039015  0.166493
# (satisfaction_threshold, p)                        -0.093661  0.200479
# (uncertainty_threshold, epsilon)                   -0.086980  0.182559
# (uncertainty_threshold, min_increase_percentage)   -0.045353  0.185564
# (uncertainty_threshold, max_increase_percentage)   -0.058546  0.176800
# (uncertainty_threshold, m)                         -0.067676  0.195158
# (uncertainty_threshold, p)                         -0.084158  0.186340
# (epsilon, min_increase_percentage)                  0.060561  0.135920
# (epsilon, max_increase_percentage)                  0.060353  0.133801
# (epsilon, m)                                        0.004223  0.123445
# (epsilon, p)                                        0.046379  0.129688
# (min_increase_percentage, max_increase_percentage) -0.001939  0.088706
# (min_increase_percentage, m)                       -0.019005  0.086161
# (min_increase_percentage, p)                        0.008738  0.089261
# (max_increase_percentage, m)                        0.021151  0.101152
# (max_increase_percentage, p)                        0.001878  0.093466
# (m, p)                                              0.021439  0.127111
# Sensitivity analysis for Avg_F_Uncertainty (Holme-Kim network):
# {'S1': array([0.05707563, 0.21842919, 0.25254024, 0.00131538, 0.00940093,
#        0.02142797, 0.01025695, 0.08461239]), 'S1_conf': array([0.08033252, 0.14493018, 0.14255473, 0.07554271, 0.04283105,
#        0.07061179, 0.0854462 , 0.08972502]), 'ST': array([0.17889534, 0.58919478, 0.56767537, 0.21073576, 0.05936803,
#        0.17869002, 0.36311779, 0.31399187]), 'ST_conf': array([0.05210675, 0.14234482, 0.12411869, 0.10519788, 0.04984923,
#        0.1146407 , 0.1296998 , 0.13505753]), 'S2': array([[            nan,  7.35704980e-05,  3.45288691e-02,
#          3.45837664e-02,  1.51349575e-03,  2.17730243e-02,
#          5.15213147e-04, -1.75575142e-02],
#        [            nan,             nan, -1.01460376e-01,
#          3.55528632e-02,  6.55884234e-02, -1.05870786e-02,
#          3.90146998e-02, -9.36606789e-02],
#        [            nan,             nan,             nan,
#         -8.69798382e-02, -4.53526722e-02, -5.85463317e-02,
#         -6.76761425e-02, -8.41580172e-02],
#        [            nan,             nan,             nan,
#                     nan,  6.05613139e-02,  6.03527787e-02,
#          4.22320375e-03,  4.63794897e-02],
#        [            nan,             nan,             nan,
#                     nan,             nan, -1.93864924e-03,
#         -1.90048853e-02,  8.73779413e-03],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#          2.11506738e-02,  1.87754911e-03],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,  2.14387197e-02],
#        [            nan,             nan,             nan,
#                     nan,             nan,             nan,
#                     nan,             nan]]), 'S2_conf': array([[       nan, 0.11409215, 0.12138105, 0.12231118, 0.1201051 ,
#         0.11555056, 0.1272791 , 0.11314083],
#        [       nan,        nan, 0.22732584, 0.16923311, 0.15985962,
#         0.17015121, 0.166493  , 0.20047897],
#        [       nan,        nan,        nan, 0.1825586 , 0.18556363,
#         0.17680031, 0.19515832, 0.18634013],
#        [       nan,        nan,        nan,        nan, 0.13591952,
#         0.13380095, 0.12344471, 0.12968844],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.08870561, 0.08616057, 0.08926104],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.10115224, 0.09346604],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.12711139],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.724780  0.132348
# satisfaction_threshold   0.301421  0.090113
# uncertainty_threshold    0.345930  0.088525
# epsilon                  0.121864  0.063567
# min_increase_percentage  0.050448  0.039239
# max_increase_percentage  0.046218  0.036233
# m                        0.159118  0.058465
# p                        0.153328  0.073669
#                                S1   S1_conf
# TP_percentage            0.469317  0.137638
# satisfaction_threshold  -0.013906  0.094900
# uncertainty_threshold    0.067462  0.095555
# epsilon                  0.006172  0.059117
# min_increase_percentage  0.017992  0.026098
# max_increase_percentage -0.001262  0.026981
# m                        0.058387  0.057134
# p                        0.054377  0.061781
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)             0.086561  0.130472
# (TP_percentage, uncertainty_threshold)              0.114344  0.140880
# (TP_percentage, epsilon)                           -0.033155  0.132865
# (TP_percentage, min_increase_percentage)           -0.017377  0.125633
# (TP_percentage, max_increase_percentage)           -0.013872  0.115494
# (TP_percentage, m)                                 -0.036929  0.130560
# (TP_percentage, p)                                 -0.066018  0.127038
# (satisfaction_threshold, uncertainty_threshold)     0.051830  0.128983
# (satisfaction_threshold, epsilon)                  -0.018592  0.123610
# (satisfaction_threshold, min_increase_percentage)  -0.048805  0.104200
# (satisfaction_threshold, max_increase_percentage)  -0.015144  0.109987
# (satisfaction_threshold, m)                        -0.057339  0.113670
# (satisfaction_threshold, p)                        -0.051252  0.110479
# (uncertainty_threshold, epsilon)                   -0.019853  0.129354
# (uncertainty_threshold, min_increase_percentage)   -0.026867  0.125851
# (uncertainty_threshold, max_increase_percentage)   -0.008095  0.126213
# (uncertainty_threshold, m)                         -0.040399  0.130697
# (uncertainty_threshold, p)                         -0.026420  0.125433
# (epsilon, min_increase_percentage)                  0.017470  0.068961
# (epsilon, max_increase_percentage)                  0.019955  0.070603
# (epsilon, m)                                        0.006830  0.067942
# (epsilon, p)                                        0.015509  0.068580
# (min_increase_percentage, max_increase_percentage) -0.034176  0.048612
# (min_increase_percentage, m)                       -0.042858  0.046901
# (min_increase_percentage, p)                       -0.038790  0.046545
# (max_increase_percentage, m)                        0.009030  0.049518
# (max_increase_percentage, p)                        0.005462  0.049417
# (m, p)                                             -0.083818  0.084610
# Sensitivity analysis for Avg_S_Uncertainty (Holme-Kim network):
# {'S1': array([ 0.46931749, -0.01390589,  0.06746175,  0.00617192,  0.01799199,
#        -0.00126196,  0.05838653,  0.05437698]), 'S1_conf': array([0.13763808, 0.09490038, 0.09555495, 0.05911727, 0.02609767,
#        0.02698101, 0.05713419, 0.06178117]), 'ST': array([0.72478006, 0.30142135, 0.34592994, 0.12186398, 0.05044823,
#        0.04621798, 0.15911792, 0.153328  ]), 'ST_conf': array([0.13234836, 0.09011326, 0.08852468, 0.0635672 , 0.03923913,
#        0.03623265, 0.05846496, 0.07366908]), 'S2': array([[        nan,  0.08656112,  0.11434422, -0.03315529, -0.01737683,
#         -0.01387157, -0.03692937, -0.06601784],
#        [        nan,         nan,  0.05182978, -0.01859222, -0.04880472,
#         -0.01514428, -0.05733855, -0.05125217],
#        [        nan,         nan,         nan, -0.01985287, -0.02686659,
#         -0.00809527, -0.04039912, -0.02642006],
#        [        nan,         nan,         nan,         nan,  0.0174699 ,
#          0.0199551 ,  0.00682974,  0.01550877],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.0341756 , -0.04285797, -0.03879033],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,  0.00903013,  0.00546177],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan, -0.08381798],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.1304718 , 0.14087964, 0.13286547, 0.1256326 ,
#         0.11549391, 0.13055976, 0.12703752],
#        [       nan,        nan, 0.12898313, 0.12361019, 0.10419974,
#         0.10998676, 0.11367031, 0.11047912],
#        [       nan,        nan,        nan, 0.12935418, 0.12585144,
#         0.12621337, 0.13069675, 0.12543331],
#        [       nan,        nan,        nan,        nan, 0.06896138,
#         0.07060315, 0.06794169, 0.0685799 ],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.04861193, 0.04690091, 0.04654467],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.04951798, 0.04941731],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.08460969],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}
#                                ST   ST_conf
# TP_percentage            0.108412  0.073653
# satisfaction_threshold   0.636282  0.189727
# uncertainty_threshold    0.661999  0.138397
# epsilon                  0.352295  0.158978
# min_increase_percentage  0.210254  0.148179
# max_increase_percentage  0.302467  0.158058
# m                        0.578523  0.184969
# p                        0.566525  0.205450
#                                S1   S1_conf
# TP_percentage            0.057566  0.053230
# satisfaction_threshold   0.218833  0.144200
# uncertainty_threshold    0.262595  0.159968
# epsilon                  0.095335  0.096166
# min_increase_percentage  0.052318  0.066660
# max_increase_percentage  0.045042  0.081835
# m                        0.153064  0.108521
# p                        0.177589  0.104983
#                                                           S2   S2_conf
# (TP_percentage, satisfaction_threshold)            -0.040791  0.084758
# (TP_percentage, uncertainty_threshold)             -0.067249  0.093004
# (TP_percentage, epsilon)                           -0.018845  0.073785
# (TP_percentage, min_increase_percentage)           -0.016200  0.077180
# (TP_percentage, max_increase_percentage)           -0.017828  0.074911
# (TP_percentage, m)                                 -0.031553  0.071669
# (TP_percentage, p)                                 -0.011751  0.073029
# (satisfaction_threshold, uncertainty_threshold)    -0.067363  0.233457
# (satisfaction_threshold, epsilon)                  -0.122024  0.170484
# (satisfaction_threshold, min_increase_percentage)  -0.019228  0.173090
# (satisfaction_threshold, max_increase_percentage)  -0.064945  0.172135
# (satisfaction_threshold, m)                        -0.079940  0.193229
# (satisfaction_threshold, p)                        -0.164080  0.178248
# (uncertainty_threshold, epsilon)                   -0.138695  0.177025
# (uncertainty_threshold, min_increase_percentage)   -0.123397  0.177268
# (uncertainty_threshold, max_increase_percentage)   -0.117021  0.181547
# (uncertainty_threshold, m)                         -0.161888  0.223623
# (uncertainty_threshold, p)                         -0.110992  0.201642
# (epsilon, min_increase_percentage)                  0.052805  0.160141
# (epsilon, max_increase_percentage)                  0.046178  0.160902
# (epsilon, m)                                       -0.056015  0.133558
# (epsilon, p)                                       -0.009515  0.126729
# (min_increase_percentage, max_increase_percentage) -0.053671  0.072973
# (min_increase_percentage, m)                       -0.058064  0.070531
# (min_increase_percentage, p)                       -0.043322  0.075697
# (max_increase_percentage, m)                       -0.024628  0.113201
# (max_increase_percentage, p)                       -0.013581  0.115269
# (m, p)                                             -0.108783  0.157533
# Sensitivity analysis for Avg_P_Uncertainty (Holme-Kim network):
# {'S1': array([0.05756579, 0.21883273, 0.26259487, 0.09533528, 0.05231781,
#        0.04504183, 0.1530639 , 0.17758858]), 'S1_conf': array([0.05323042, 0.1441997 , 0.15996778, 0.09616591, 0.06666   ,
#        0.08183456, 0.10852071, 0.10498258]), 'ST': array([0.1084122 , 0.63628153, 0.66199879, 0.3522952 , 0.21025438,
#        0.30246714, 0.57852293, 0.56652511]), 'ST_conf': array([0.07365341, 0.18972736, 0.13839702, 0.15897787, 0.14817935,
#        0.15805824, 0.18496875, 0.20545047]), 'S2': array([[        nan, -0.04079065, -0.06724932, -0.0188454 , -0.01619986,
#         -0.01782842, -0.0315529 , -0.01175101],
#        [        nan,         nan, -0.06736298, -0.12202442, -0.01922815,
#         -0.06494473, -0.07993974, -0.16407993],
#        [        nan,         nan,         nan, -0.13869522, -0.12339666,
#         -0.11702051, -0.16188801, -0.11099197],
#        [        nan,         nan,         nan,         nan,  0.05280541,
#          0.04617786, -0.05601535, -0.00951469],
#        [        nan,         nan,         nan,         nan,         nan,
#         -0.05367142, -0.05806382, -0.04332247],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan, -0.02462766, -0.01358111],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan, -0.10878252],
#        [        nan,         nan,         nan,         nan,         nan,
#                 nan,         nan,         nan]]), 'S2_conf': array([[       nan, 0.08475766, 0.09300358, 0.07378456, 0.07718011,
#         0.07491079, 0.07166908, 0.07302885],
#        [       nan,        nan, 0.233457  , 0.17048373, 0.17308996,
#         0.17213454, 0.19322925, 0.17824848],
#        [       nan,        nan,        nan, 0.17702484, 0.17726788,
#         0.181547  , 0.22362272, 0.20164194],
#        [       nan,        nan,        nan,        nan, 0.16014101,
#         0.16090217, 0.13355826, 0.12672909],
#        [       nan,        nan,        nan,        nan,        nan,
#         0.07297253, 0.07053113, 0.07569658],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan, 0.11320097, 0.11526932],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan, 0.1575334 ],
#        [       nan,        nan,        nan,        nan,        nan,
#                nan,        nan,        nan]])}

# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

base_config = {
    'TP_percentage': 0.7,
    'satisfaction_threshold': 0.5,
    'uncertainty_threshold': 0.5,
    'product_price_range': (5, 10),
    'min_increase_percentage': 4,
    'max_increase_percentage': 10,
    'num_products': 20,
    'inflation_rate': 3,
    'epsilon': 0.5,
    'comparison_attributes': ['preference_conformity', 'budget', 'preference_sustainability'],
    'seed': 42  # Seed for reproducibility
}

# Configuration for Watts-Strogatz network
watts_strogatz_config = base_config.copy()
watts_strogatz_config.update({
    'network_type': 'watts_strogatz',
    'network_params': {
        'n': 1600,
        'k': 8,
        'p': 0.3
    }
})


# Configuration for Barabasi-Albert network
barabasi_albert_config = base_config.copy()
barabasi_albert_config.update({
    'network_type': 'barabasi_albert',
    'network_params': {
        'n': 1600,
        'm': 8
    }
})

# Configuration for Random Regular network
random_regular_config = base_config.copy()
random_regular_config.update({
    'network_type': 'random_regular',
    'network_params': {
        'n': 1600,
        'd': 8
    }
})

# Configuration for Holme-Kim network
holme_kim_config = base_config.copy()
holme_kim_config.update({
    'network_type': 'holme_kim',
    'network_params': {
        'n': 1600,
        'm': 8,
        'p': 0.3
    }
})

network_configurations = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

network_configs = {
    'Watts-Strogatz': watts_strogatz_config,
    'Barabasi-Albert': barabasi_albert_config,
    'Random Regular': random_regular_config,
    'Holme-Kim': holme_kim_config
}

# Define the model inputs for each network type
network_problems = {
    'Watts-Strogatz': {
        'num_vars': 8,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon', 'min_increase_percentage','max_increase_percentage', 'k', 'p'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1], [1,10], [11,20], [2, 10], [0, 1]] 
    },
    'Barabasi-Albert': {
        'num_vars': 7,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold','epsilon','min_increase_percentage', 'max_increase_percentage', 'm'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1],[1,10], [11,20],[2, 10]]  
    },
    'Random Regular': {
        'num_vars': 7,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon','min_increase_percentage','max_increase_percentage','d'],
        'bounds': [[0, 1], [0, 1], [0, 1], [0,1],[1,10], [11,20],[2, 10]]  
    },
    'Holme-Kim': {
        'num_vars': 8,
        'names': ['TP_percentage', 'satisfaction_threshold', 'uncertainty_threshold', 'epsilon','min_increase_percentage','max_increase_percentage','m', 'p'],
        'bounds': [[0, 1], [0, 1], [0, 1],[0,1], [1,10], [11,20],[2, 10], [0, 1]] 
    }
}
# Number of samples
num_samples = 256

# Generate samples for each network problem
samples = {}
for network_name, problem in network_problems.items():
    samples[network_name] = saltelli.sample(problem, num_samples)

from joblib import Parallel, delayed
import numpy as np
import pandas as pd
from tqdm import tqdm
from SALib.sample import saltelli
from SALib.analyze import sobol
import json

def collect_simulation_data(model, num_steps):
    collected_data = {
        'Step': [],
        'Adoption Rate': [],
        'Avg_F_Satisfaction': [],
        'Avg_S_Satisfaction': [],
        'Avg_P_Satisfaction': [],
        'Avg_F_Uncertainty': [],
        'Avg_S_Uncertainty': [],
        'Avg_P_Uncertainty': []
    }

    for step in range(num_steps):
        model.step()
        collected_data['Step'].append(step)
        collected_data['Adoption Rate'].append(model.calculate_true_price_adoption_rate())
        collected_data['Avg_F_Satisfaction'].append(np.mean([agent.F_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_S_Satisfaction'].append(np.mean([agent.S_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_P_Satisfaction'].append(np.mean([agent.P_satisfaction for agent in model.schedule.agents]))
        collected_data['Avg_F_Uncertainty'].append(np.mean([agent.F_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_S_Uncertainty'].append(np.mean([agent.S_uncertainty for agent in model.schedule.agents]))
        collected_data['Avg_P_Uncertainty'].append(np.mean([agent.P_uncertainty for agent in model.schedule.agents]))

    model_data = pd.DataFrame(collected_data)
    return model_data

def run_single_simulation(params, config, network_name, num_steps):
    config = config.copy()
    config['TP_percentage'] = params[0]
    config['satisfaction_threshold'] = params[1]
    config['uncertainty_threshold'] = params[2]
    config['epsilon'] = params[3]
    config['min_increase_percentage'] = params[4]
    config['max_increase_percentage'] = params[5]

    if network_name == 'Watts-Strogatz':
        config['network_params']['k'] = int(params[6])
        config['network_params']['p'] = params[7]
    elif network_name == 'Barabasi-Albert':
        config['network_params']['m'] = int(params[6])
    elif network_name == 'Random Regular':
        config['network_params']['d'] = int(params[6])
    elif network_name == 'Holme-Kim':
        config['network_params']['m'] = int(params[6])
        config['network_params']['p'] = params[7]

    model = ConsumatModel(config)
    model_data = collect_simulation_data(model, num_steps)
    final_step_data = model_data.iloc[-1]

    return [
        final_step_data['Adoption Rate'],
        final_step_data['Avg_F_Satisfaction'],
        final_step_data['Avg_S_Satisfaction'],
        final_step_data['Avg_P_Satisfaction'],
        final_step_data['Avg_F_Uncertainty'],
        final_step_data['Avg_S_Uncertainty'],
        final_step_data['Avg_P_Uncertainty']
    ]

def run_gsa_simulation_parallel(network_name, config, samples, num_steps, n_jobs=-1):
    all_results = Parallel(n_jobs=n_jobs)(
        delayed(run_single_simulation)(params, config, network_name, num_steps)
        for params in tqdm(samples, desc=f'Running simulations for {network_name}')
    )
    return np.array(all_results)

num_steps = 10

# Run GSA for each network
for network_name, config in network_configurations.items():
    print(f"Running GSA for {network_name} network...")
    config = base_config.copy()
    config.update(network_configs[network_name])
    all_results = run_gsa_simulation_parallel(network_name, config, samples[network_name], num_steps)
    
    results = {}
    
    # Perform Sobol sensitivity analysis
    for i, output in enumerate(['Adoption Rate', 'Avg_F_Satisfaction', 'Avg_S_Satisfaction', 'Avg_P_Satisfaction', 'Avg_F_Uncertainty', 'Avg_S_Uncertainty', 'Avg_P_Uncertainty']):
        Si = sobol.analyze(network_problems[network_name], all_results[:, i], print_to_console=True)
        results[output] = {
            'S1': Si['S1'].tolist(),
            'ST': Si['ST'].tolist(),
            'S2': Si['S2'].tolist(),
            'S1_conf': Si['S1_conf'].tolist(),
            'ST_conf': Si['ST_conf'].tolist()
        }
        print(f'Sensitivity analysis for {output} ({network_name} network):')
        print(Si)
    
    # Save results to a JSON file
    with open(f'dynamic_sensitivity_results_all_{network_name}.json', 'w') as f:
        json.dump(results, f)
# Out:
# C:\Users\elpha\AppData\Local\Temp\ipykernel_9568\1121850198.py:108: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5. Please use `salib.sample.sobol`
#   samples[network_name] = saltelli.sample(problem, num_samples)
# Running GSA for Watts-Strogatz network...
# Running simulations for Watts-Strogatz:  18%|██████▋                              | 840/4608 [18:45<1:17:38,  1.24s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 192
#     190 config = base_config.copy()
#     191 config.update(network_configs[network_name])
# --> 192 all_results = run_gsa_simulation_parallel(network_name, config, samples[network_name], num_steps)
#     194 results = {}
#     196 # Perform Sobol sensitivity analysis
#
# Cell In[8], line 179, in run_gsa_simulation_parallel(network_name, config, samples, num_steps, n_jobs)
#     178 def run_gsa_simulation_parallel(network_name, config, samples, num_steps, n_jobs=-1):
# --> 179     all_results = Parallel(n_jobs=n_jobs)(
#     180         delayed(run_single_simulation)(params, config, network_name, num_steps)
#     181         for params in tqdm(samples, desc=f'Running simulations for {network_name}')
#     182     )
#     183     return np.array(all_results)
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reach the first `yield` statement. This starts the aynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:
